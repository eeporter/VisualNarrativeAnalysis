# %%
import numpy as np
import pandas as pd
pd.options.display.max_columns = 100

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sb
sb.set_style('whitegrid')

import json, unicodedata, os

from collections import Counter

import networkx as nx

from scipy.spatial.distance import euclidean, cosine

#_dir = '/Users/briankeegan/Dropbox/Workspace/Wikipedia_images/'
_dir = 'E:/Dropbox/Workspace/Wikipedia_images/'

# %%
class MyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(MyEncoder, self).default(obj)

# %% [markdown]
# ## Coup baseline analysis

# %%
historical_coups_df = pd.read_csv('coups_by_country.txt',sep='\t')
historical_coups_df['date'] = pd.to_datetime(historical_coups_df.apply(lambda x:'{0:02d}-{1:02d}-{2:02d}'.format(x['year'],x['month'],x['day']),axis=1))
historical_coups_df.head()
# Out:
#   country  ccode  year  month  day  coup      version       date
# 0    Cuba     40  1952      3   10     2  V2016.07.20 1952-03-10
# 1    Cuba     40  1957      9    5     1  V2016.07.20 1957-09-05
# 2   Haiti     41  1950      5   10     2  V2016.07.20 1950-05-10
# 3   Haiti     41  1956     12   12     2  V2016.07.20 1956-12-12
# 4   Haiti     41  1957      4    2     2  V2016.07.20 1957-04-02

# %%
annual_coups_df = historical_coups_df.groupby(['year','coup']).agg({'country':len})['country'].unstack().fillna(0)
annual_coups_df.rename(columns={1:'Failed coup',2:'Successful coup'},inplace=True)

# Plot
ax = annual_coups_df.plot(kind='area',stacked=True,legend=False,lw=3)
ax.set_xlabel('Year')
ax.set_ylabel('Coup attempts')
#ax.set_ylim((0,18))
ax.legend()

# %%
historical_coups_df.groupby('country').agg({'year':[np.min,np.max,len]})['year'].sort_values('amax',ascending=False).head()
# Out:
#               amin  amax  len
# country
# Turkey        1960  2016    6
# Burkina Faso  1966  2015    8
# Burundi       1965  2015   11
# Ukraine       2014  2014    1
# Lesotho       1986  2014    4

# %% [markdown]
# ## Coup revisions

# %%
rev_df = pd.read_csv('all_coups_revisions.csv',encoding='utf8')
rev_df['timestamp'] = pd.to_datetime(rev_df['timestamp'],format='%Y-%m-%dT%H:%M:%SZ')
rev_df['year'] = rev_df['timestamp'].apply(lambda x:x.year)
rev_df.head()
# Out:
# /Users/emilyporter/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                          parent_topic anon lang  \
# 0  1979 Equatorial Guinea coup d'état  NaN   fr
# 1  1979 Equatorial Guinea coup d'état  NaN   fr
# 2  1979 Equatorial Guinea coup d'état  NaN   fr
# 3  1979 Equatorial Guinea coup d'état  NaN   es
# 4  1979 Equatorial Guinea coup d'état  NaN   es
#
#                                            page   parentid  rev_num  \
# 0     Coup d'État de 1979 en Guinée équatoriale  130702092        0
# 1     Coup d'État de 1979 en Guinée équatoriale  130702041        1
# 2     Coup d'État de 1979 en Guinée équatoriale          0        2
# 3  Golpe de Estado en Guinea Ecuatorial de 1979   97851838        0
# 4  Golpe de Estado en Guinea Ecuatorial de 1979   97851124        1
#
#        revid                                      sha1 sha1hidden    size  \
# 0  130707374  ab4b056d773524c4c4a6c7b0e5fbd67a75a84e05        NaN     602
# 1  130702092  8b540a85b0754eade080782115c37907dc6b7f91        NaN     592
# 2  130702041  78f5fe6f240741c4b77c760a61ce5dd857aa167c        NaN     566
# 3   97871893  867199a33b32a94e9e42beada8bc17ecdfa4dff0        NaN  128875
# 4   97851838  587c16af7a77b63fa4ab615dc59ba8b1c9e686f9        NaN  128456
#
#             timestamp         user userhidden  year
# 0 2016-10-15 21:21:17  OrlodrimBot        NaN  2016
# 1 2016-10-15 18:39:13  Rashinseita        NaN  2016
# 2 2016-10-15 18:37:36  Rashinseita        NaN  2016
# 3 2017-03-26 21:41:13    Marval703        NaN  2017
# 4 2017-03-26 03:20:30    Marval703        NaN  2017

# %%
len(rev_df['page'].unique()), len(rev_df['parent_topic'].unique()), len(rev_df['lang'].unique())
# Out:
# (1137, 169, 97)

# %%
_agg_func = {'user':pd.Series.nunique,'sha1':pd.Series.nunique,'size':np.max,'timestamp':np.min, 'year':np.min}
summary_df = rev_df.groupby(['parent_topic','page']).agg(_agg_func)
summary_df.rename(columns={'sha1':'Revisions','user':'Editors','size':'Size', 'year':'Year'},inplace=True)
summary_df = summary_df.median(level=0)

summary_df['Languages'] = rev_df.groupby('parent_topic').agg({'lang':pd.Series.nunique}).sort_values('lang',ascending=False)['lang']

summary_df = summary_df[['Languages','Revisions','Editors','Size','Year']]
summary_df.sort_values('Languages',ascending=False).head(10)
# Out:
#                                     Languages  Revisions  Editors     Size  \
# parent_topic
# 2016 Turkish coup d'état attempt           61       25.0      7.0  14397.0
# Carnation Revolution                       44       41.0     24.0   7376.0
# 1991 Soviet coup d'état attempt            43       51.0     30.5  14353.0
# Romanian Revolution                        39       67.0     32.0  12880.0
# 1973 Chilean coup d'état                   31       37.0     20.0   9632.0
# 2013 Egyptian coup d'état                  31       32.0     13.0  13820.0
# Tulip Revolution                           28       34.0     21.0   4775.0
# 1953 Iranian coup d'état                   28       59.0     26.0   8404.0
# 1993 Russian constitutional crisis         28       35.5     22.0  11048.5
# Saur Revolution                            25       21.0     14.0   7131.0
#
#                                       Year
# parent_topic
# 2016 Turkish coup d'état attempt    2016.0
# Carnation Revolution                2007.0
# 1991 Soviet coup d'état attempt     2009.0
# Romanian Revolution                 2007.5
# 1973 Chilean coup d'état            2011.0
# 2013 Egyptian coup d'état           2013.0
# Tulip Revolution                    2007.0
# 1953 Iranian coup d'état            2009.0
# 1993 Russian constitutional crisis  2010.0
# Saur Revolution                     2011.0

# %%
print(summary_df.sort_values('Languages',ascending=False).head(10).to_latex(encoding='ascii'))
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Languages &  Revisions &  Editors &     Size &    Year \\
# parent\_topic                       &            &            &          &          &         \\
# \midrule
# 2016 Turkish coup d'état attempt   &         61 &       25.0 &      7.0 &  14397.0 &  2016.0 \\
# Carnation Revolution               &         44 &       41.0 &     24.0 &   7376.0 &  2007.0 \\
# 1991 Soviet coup d'état attempt    &         43 &       51.0 &     30.5 &  14353.0 &  2009.0 \\
# Romanian Revolution                &         39 &       67.0 &     32.0 &  12880.0 &  2007.5 \\
# 1973 Chilean coup d'état           &         31 &       37.0 &     20.0 &   9632.0 &  2011.0 \\
# 2013 Egyptian coup d'état          &         31 &       32.0 &     13.0 &  13820.0 &  2013.0 \\
# Tulip Revolution                   &         28 &       34.0 &     21.0 &   4775.0 &  2007.0 \\
# 1953 Iranian coup d'état           &         28 &       59.0 &     26.0 &   8404.0 &  2009.0 \\
# 1993 Russian constitutional crisis &         28 &       35.5 &     22.0 &  11048.5 &  2010.0 \\
# Saur Revolution                    &         25 &       21.0 &     14.0 &   7131.0 &  2011.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Inter-language links

# %%
with open("all_coups_interlanguage_links.json",'r') as f:
    coup_interlanguage_links = json.load(f)

# %%
articles_across_languages_count = 0
languages_represented = set()
for topic, topic_d in coup_interlanguage_links.items():
    articles_across_languages_count += len(topic_d)
    languages_represented = languages_represented | set(topic_d.keys())
print("There are {0:,} articles across {1:,} languages about the {2:,} seed topics".format(articles_across_languages_count,
                                                                                           len(languages_represented),
                                                                                           len(coup_interlanguage_links)))
# Out:
# There are 1,164 articles across 97 languages about the 168 seed topics

# %%
ill_counts_d = {}

for topic, topic_d in coup_interlanguage_links.items():
    ill_counts_d[topic] = {}
    for lang, lang_d in topic_d.items():
        ill_counts_d[topic][lang] = len(lang_d)

topic_lang_links_df = pd.DataFrame(ill_counts_d).stack().reset_index()
topic_lang_links_df.columns = ['lang','topic','link count']
topic_lang_links_df.head()
# Out:
#   lang                        topic  link count
# 0   af    2013 Egyptian coup d'état         2.0
# 1   am  1960 Ethiopian coup attempt        64.0
# 2   ar           17 July Revolution        12.0
# 3   ar   1953 Colombian coup d'état         5.0
# 4   ar     1953 Iranian coup d'état        30.0

# %% [markdown]
# ## Categories

# %%
with open('commons_category_file_members.json','r') as f:
    commons_category_file_members_dict = json.load(f)
    
with open('all_coups_file_image_usage.json','r') as f:
    all_coups_image_usage = json.load(f)

# %%
all_coups_image_usage["1987 Fijian coups d'état"]['en']
# Out:
# {'File:Arms of Fiji 2.png': ['History of Fiji',
#   "Timeline of the 2000 Fijian coup d'état",
#   "1987 Fijian coups d'état",
#   'Fiji Week, 2004',
#   '1977 Fijian constitutional crisis',
#   "2000 Fijian coup d'état",
#   "Mutinies of the 2000 Fijian coup d'état",
#   "Aftermath of the 2000 Fijian coup d'état",
#   'Discovery of Fiji',
#   'Fiji during the time of Cakobau',
#   'Colony of Fiji',
#   'Modern history of Fiji',
#   'Nuanced voices on the Reconciliation, Tolerance, and Unity Bill',
#   'Yellow Ribbon campaign (Fiji)',
#   'Blue Ribbon campaign (Fiji)',
#   "Military unrest following the 2000 Fijian coup d'état",
#   'Military opposition to the Reconciliation, Tolerance, and Unity Bill',
#   'Fiji Week, 2005',
#   "Investigations since the 2000 Fijian coup d'état",
#   "Trials since the 2000 Fijian coup d'état",
#   'Military–church relations in Fiji',
#   'International reaction to the Reconciliation, Tolerance, and Unity Bill',
#   'Reconciliation, Tolerance, and Unity Bill',
#   'Fijian mercenaries in Bougainville',
#   'Religious reaction to the Reconciliation, Tolerance, and Unity Bill',
#   'Counter Revolutionary Warfare Unit Court Martial, Fiji',
#   '2005–06 Fijian political crisis',
#   'Removal of Ratu Mara, 2000',
#   'Dominion of Fiji',
#   'Timeline of the 2005–06 Fijian political crisis',
#   'Reaction to the 2005–06 Fijian political crisis',
#   'Instruments of Independence',
#   "2006 Fijian coup d'état",
#   'Alleged plot against Ratu Iloilo, 2000',
#   '2009 Fijian constitutional crisis']}

# %%
_s1 = pd.Series({cat:len(members) for cat, members in commons_category_file_members_dict.items()})
hist1 = np.histogram(_s1.values,bins=np.logspace(0,5,31))
hist1_s = pd.Series(dict(zip(hist1[1][1:],hist1[0])))

# %%
image_count_by_lang = {}
for topic, topic_d in all_coups_image_usage.items():
    for lang, lang_d in topic_d.items():
        for file, filelist in lang_d.items():
            try:
                image_count_by_lang[file.split(':')[1]] += 1
            except KeyError:
                image_count_by_lang[file.split(':')[1]] = 1
                
hist2_s = pd.Series(image_count_by_lang)
hist2_s = hist2_s.value_counts().sort_index()

# %%
pd.Series(image_count_by_lang).sort_values(ascending=False).head()
# Out:
# Romanian Revolution 1989 Demonstrators.jpg      25
# Golpe de Estado 1973.jpg                        25
# Coruche mural 25 Abril.jpg                      21
# Boris Yeltsin 19 August 1991-1.jpg              21
# Thai-coup-detat-2014-social-media-banner.jpg    20
# dtype: int64

# %%
image_usage_across_project = {}
for topic, topic_d in all_coups_image_usage.items():
    for lang, lang_d in topic_d.items():
        for file, filelist in lang_d.items():
            try:
                image_usage_across_project[file.split(':')[1]] += len(filelist)
            except KeyError:
                image_usage_across_project[file.split(':')[1]] = len(filelist)
                
hist3_s = pd.Series(image_usage_across_project)
hist3_s = hist3_s.value_counts().sort_index()

pd.Series(image_usage_across_project).sort_values(ascending=False).head()
# Out:
# Apollo 11.jpg                                          2500
# Habs un headquarters.jpg                               2000
# PithHelmetTruman.jpg                                   1000
# Eugène Delacroix - La liberté guidant le peuple.jpg     997
# P history.png                                           982
# dtype: int64

# %%
len(image_usage_across_project), len(image_count_by_lang)
# Out:
# (747, 747)

# %%
# Start figure
f,axs = plt.subplots(1,3,figsize=(12,4))

# Left figure
hist1_s.plot(lw=4,logx=True,ax=axs[0])
axs[0].set_xlim((1e0,1e5))
#axs[0].set_xscale('log')
axs[0].set_ylim((0,120))

axs[0].set_xlabel('Images in category',fontsize=14)
axs[0].set_ylabel('Number of categories',fontsize=14)
axs[0].text(x=4e4,y=110,s='A',fontsize=20)

# Center figure
hist2_s.reset_index().plot(kind='scatter',x='index',y=0,lw=4,logy=True,ax=axs[1])
axs[1].set_xlim((0,30))
axs[1].set_ylim((1e0,1e3))
axs[1].set_xlabel('Number of languages',fontsize=14)
axs[1].set_ylabel('Number of images',fontsize=14)
axs[1].text(x=28,y=5.5e2,s='B',fontsize=20)

# Center figure
hist3_s.reset_index().plot(kind='scatter',x='index',y=0,lw=4,logx=True,logy=True,ax=axs[2])
axs[2].set_xlim((1e0,1e4))
axs[2].set_ylim((1e0,1e3))
axs[2].set_xlabel('Number of articles',fontsize=14)
axs[2].set_ylabel('Number of images',fontsize=14)
axs[2].text(x=5e3,y=5.25e2,s='C',fontsize=20)

#
plt.tight_layout()
plt.savefig('category_file_members.pdf',bbox_inches='tight')

# %%
unique_images_in_categories = len(set([m for cat, members in commons_category_file_members_dict.items() for m in members]))
unique_categories = len(commons_category_file_members_dict)

print("There are {0:,} unique images in {1:,} categories".format(unique_images_in_categories,unique_categories))
# Out:
# There are 149,038 unique images in 1,112 categories

# %% [markdown]
# ## Image usage

# %%
with open('all_coups_file_image_usage.json','r') as f:
    all_coups_image_usage = json.load(f)

# %%
topic_lang_image_counts_d = {}

for topic, topic_d in all_coups_image_usage.items():
    topic_lang_image_counts_d[topic] = {}
    for lang, lang_d in topic_d.items():
        topic_lang_image_counts_d[topic][lang] = len(lang_d)

topic_lang_image_counts_df = pd.DataFrame(topic_lang_image_counts_d).stack().reset_index()
topic_lang_image_counts_df.columns = ['lang','topic','image count']
topic_lang_image_counts_df.sort_values(['topic','lang']).head()
# Out:
#     lang               topic  image count
# 2     ar  17 July Revolution          0.0
# 75    bn  17 July Revolution          0.0
# 187   en  17 July Revolution          0.0
# 367   es  17 July Revolution          0.0
# 635   ja  17 July Revolution          0.0

# %%
all_coups_image_usage["2013 Egyptian coup d'état"]['en']
# Out:
# {'File:Anti Morsi protest march at 28th June 2013.jpg': ['Mohamed Morsi',
#   "2013 Egyptian coup d'état",
#   'June 2013 Egyptian protests'],
#  'File:Damietta protests.jpg': ["2013 Egyptian coup d'état",
#   'Post-coup unrest in Egypt (2013–2014)'],
#  'File:Dead bodies in RABIA Massacre (3).jpg': ["2013 Egyptian coup d'état"],
#  'File:General Al Sisi.jpg': ['Egypt', "2013 Egyptian coup d'état"],
#  'File:Morsi supporter after mass killings of 27-July-2013.jpg': ["2013 Egyptian coup d'état"],
#  'File:Secretary of Defense Chuck Hagel meets with Egyptian President Mohamed Morsy in Cairo, Egypt, April 24, 2013.jpg': ['Chuck Hagel',
#   'Mohamed Morsi',
#   "2013 Egyptian coup d'état"],
#  'File:Soldier in Tahrir.jpg': ['Egyptian revolution of 2011',
#   'Egyptian crisis (2011–14)',
#   'Timeline of the Egyptian Crisis under the Supreme Council of the Armed Forces',
#   'Sinai insurgency',
#   '2012–13 Egyptian protests',
#   "2013 Egyptian coup d'état",
#   'June 2013 Egyptian protests',
#   'Post-coup unrest in Egypt (2013–2014)',
#   'Insurgency in Egypt (2013–present)']}

# %%
no_image_articles = []

for topic, topic_d in all_coups_image_usage.items():
    for lang, lang_d in topic_d.items():
        if len(lang_d) == 0:
            no_image_articles.append((topic,lang))
            
print("There are {0:,} multi-lingual articles containing no images".format(len(no_image_articles)))
# Out:
# There are 537 multi-lingual articles containing no images

# %%
no_image_any_lang = []
for (topic,lang1) in no_image_articles:
    image_sum = sum(len(lang_d) for lang2, lang_d in all_coups_image_usage[topic].items())
    if image_sum == 0 and topic not in no_image_any_lang:
        no_image_any_lang.append(topic)

print("There are {0:,} seed topics where no language edition has an image".format(len(no_image_any_lang)))
# Out:
# There are 71 seed topics where no language edition has an image

# %%
all_coups_image_usage["November 1966 Burundian coup d'état"]
# Out:
# {'en': {}, 'fr': {}, 'pt': {}}

# %%
alternative_images = {}
for (topic,lang1) in no_image_articles:
    if any(len(lang_d) == 0 for lang2, lang_d in all_coups_image_usage[topic].items()):
        for lang2, lang_d in all_coups_image_usage[topic].items():
            if len(lang_d) > 0:
                alternative_images[topic] = [file.split(':')[1] for file, file_list in lang_d.items()]
            
len(alternative_images)
# Out:
# 79

# %%
pd.Series({k:len(set(v)) for k,v in alternative_images.items()}).max()
# Out:
# 7

# %% [markdown]
# ## Category network

# %%
with open('image_category_memberships.json','r') as f:
    image_category_memberships = json.load(f)

# %%
image_category_memberships['en']['File:Nasser Qaddafi Atassi 1969.jpg']
# Out:
# [{'Category:1969 in Libya': '2013-09-17T15:56:45Z'},
#  {'Category:Arab nationalists': '2010-03-13T21:23:03Z'},
#  {'Category:Gamal Abdel Nasser with Arab leaders': '2013-07-30T23:54:04Z'},
#  {'Category:Muammar Gaddafi and Gamal Abdel Nasser': '2013-06-20T22:24:01Z'},
#  {'Category:Muammar Gaddafi with national leaders': '2011-10-20T16:37:21Z'},
#  {'Category:Nureddin al-Atassi': '2010-03-23T19:45:54Z'},
#  {'Category:Relations of Egypt and Syria': '2013-11-02T22:58:06Z'},
#  {'Category:Relations of Libya and Syria': '2013-11-02T22:58:06Z'}]

# %%
simple_l = []

for lang, lang_d in image_category_memberships.items():
    for file, cat_l in lang_d.items():
        for cat_d in cat_l:
            for cat_name, ts in cat_d.items():
                simple_l.append({'lang':lang,'file':file,'category':cat_name})

lang_cat_df = pd.DataFrame(simple_l)
lang_cat_gb = lang_cat_df.groupby(['category','lang']).agg({'file':len}).reset_index()
lang_cat_gb.rename(columns={'file':'weight'},inplace=True)
lang_cat_gb.sort_values('weight',ascending=False).head()
# Out:
#                                                category lang  weight
# 268               Category:2006 coup d'état in Thailand   en      15
# 300               Category:2009 coup d'état in Honduras   pl       7
# 215   Category:1991 coup d'état attempt in the Sovie...   no       6
# 272               Category:2006 coup d'état in Thailand   gl       5
# 2856                      Category:Revolução dos Cravos   pt       5

# %%
lang_cat_langs = lang_cat_gb['lang'].unique()
lang_cat_cats = lang_cat_gb['category'].unique()
lang_cat_g = nx.from_pandas_dataframe(source='lang',target='category',edge_attr=['weight'],df=lang_cat_gb)

print("There are {0:,} languages, {1:,} categories, and {2:,} edges in the network".format(len(lang_cat_langs),
                                                                                      len(lang_cat_cats),
                                                                                      lang_cat_g.number_of_edges()))

for lang in lang_cat_langs:
    lang_cat_g.add_node(lang,kind='language')
    
for cat in lang_cat_cats:
    lang_cat_g.add_node(cat,kind='category')

nx.write_gexf(lang_cat_g,'lang_cat_bipartite.gexf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-ace7695f82a6> in <module>()
#       1 lang_cat_langs = lang_cat_gb['lang'].unique()
#       2 lang_cat_cats = lang_cat_gb['category'].unique()
# ----> 3 lang_cat_g = nx.from_pandas_dataframe(source='lang',target='category',edge_attr=['weight'],df=lang_cat_gb)
#       4
#       5 print("There are {0:,} languages, {1:,} categories, and {2:,} edges in the network".format(len(lang_cat_langs),
#
# AttributeError: module 'networkx' has no attribute 'from_pandas_dataframe'

# %%
proj_lang_cat_g = nx.bipartite.weighted_projected_graph(lang_cat_g.to_undirected(),lang_cat_langs)

print("There are {0:,} nodes and {1:,} edges in the network".format(proj_lang_cat_g.number_of_nodes(),
                                                                    proj_lang_cat_g.number_of_edges()))

# %%
proj_lang_cat_g.edges(data=True)[:5]

# %%
_s = lang_cat_df.groupby('lang').agg({'file':len})['file']
_s.sort_values(ascending=False)

# %% [markdown]
# ## Tag network

# %%
cols = ['IT-Active Image', 'IT-Passive Image',
        'D-Adult Male', 'D-Adult Female', 'D-Child Male', 'D-Child Female', 'D-Non-human', 
        'FE-Frown', 'FE-Smile', 
        'FPI-Foriegn Leaders', 'FPI-Foriegn Symbols',
        'GT-Alleged Atrocities', 'GT-Buildings', 'GT-Celebration', 'GT-Protest/Demonstration', 'GT-Destruction', 'GT-Diplomatic and Other Official Actions', 'GT-Documents/Communications', 'GT-Humanitarian Aid', 'GT-Locations/Maps/Infographics', 'GT-Memorials', 'GT-Military Actions', 'GT-Military Technology and Weaponry', 'GT-POWs', 'GT-Policing', 'GT-Portrait', 'GT-Signs/Symbols', 'GT-Suffering',
        'IF-Individual', 'IF-Group', 'IF-Individual in Relation to the Group', 'IF-Non-human',
        'TOP-Civilians', 'TOP-Journalists', 'TOP-Military or Political Leaders', 'TOP-Military Personnel', 'TOP-Police',
        'VI-Non-violent Image', 'VI-Violent Image']

# %%
#filedir = 'E:/Dropbox/Workspace/Wikipedia images/'
filedir = '/Users/briankeegan/Dropbox/Workspace/Wikipedia images/'

jon_b0_df = pd.read_excel(filedir + 'XLS Batches/Coup_Project Jon.xls', sheetname='Sheet1')
jon_b1_df = pd.read_excel(filedir + 'XLS Batches/Coup_Project Batch 1.xls', sheetname='Sheet1')
jon_b2_df = pd.read_excel(filedir + 'XLS Batches/Coup_Project Batch 2.xls', sheetname='Sheet1')
jon_b3_df = pd.read_excel(filedir + 'XLS Batches/Coup_Project Batch 3.xls', sheetname='Sheet1')

all_jon_df = pd.concat([jon_b0_df,jon_b1_df,jon_b2_df,jon_b3_df],axis=1)
jon_cols = list(set(all_jon_df.columns))
all_jon_df = all_jon_df.loc[cols,jon_cols]

print(len(all_jon_df.columns))

# %%
image_tags_dict = all_jon_df.T.to_dict('index')
with open('image_tags.json','w') as f:
    json.dump(image_tags_dict,f,cls=MyEncoder)

# %%
tag_file_el = all_jon_df.unstack().reset_index()
tag_file_el.rename(columns={'level_0':'file','level_1':'tag',0:'tie'},inplace=True)
tag_file_el = tag_file_el[tag_file_el['tie'] > 0].reset_index(drop=True)

tag_file_files = tag_file_el['file'].unique()
tag_file_tags = tag_file_el['tag'].unique()

file_tag_g = nx.from_pandas_dataframe(source='file',target='tag',edge_attr=['tie'],df=tag_file_el)

print("There are {0:,} files, {1:,} tags, and {2:,} edges in the network".format(len(tag_file_files),
                                                                                 len(tag_file_tags),
                                                                                 file_tag_g.number_of_edges()))

for file in tag_file_files:
    file_tag_g.add_node(file,kind='file')
    
for tag in tag_file_tags:
    file_tag_g.add_node(tag,kind='tag')

nx.write_gexf(file_tag_g,'tag_file_bipartite.gexf')

# %% [markdown]
# ## Language-tag similarity

# %% [raw]
# topics_parent_lang_df = pd.read_csv('topics_parent_lang.csv',encoding='utf8',header=None,index_col=0)
# topics_parent_lang_dict = topics_parent_lang_df[1].to_dict()
# topics_parent_lang_dict
#
# with open('topics_parent_lang.json','w') as f:
#     json.dump(topics_parent_lang_dict,f)

# %%
with open('image_tags.json','r') as f:
    image_tags_dict = json.load(f)
    
with open('topics_parent_lang.json','r') as f:
    topics_parent_lang_dict = json.load(f)
    
with open('all_coups_file_image_usage.json','r') as f:
    all_coups_image_usage = json.load(f)

# Keys are decomposed unicode strings, values are composed unicode strings
with open('tagged_scraped_disjoint_filenamesEmilyTag_match.json','r') as f:
    unicode_mapping_json = json.load(f)
    
unicode_mapping_json_rv = {v.encode('utf8'):k.encode('utf8') for k,v in unicode_mapping_json.items()}

# %%
for k,v in list(image_tags_dict.items()):
    composed_k = unicodedata.normalize('NFKC',k).encode('utf8')
    image_tags_dict[composed_k] = v
    del image_tags_dict[k]

# %%
'Marahoué'.encode('utf8') == unicodedata.normalize('NFKC','Marahoué').encode('utf8')

# %%
list(unicode_mapping_json.items())[:5]

# %% [markdown]
# Get the names of all the images.

# %%
all_image_filenames = list(set(os.listdir('/Users/briankeegan/Dropbox/Workspace/Wikipedia images/Images/')) | set(os.listdir('/Users/briankeegan/Dropbox/Workspace/Wikipedia images/Error Images/')))
all_image_filenames = [unicodedata.normalize('NFKC',i) for i in all_image_filenames]

print("There are {0:,} images downloaded to disk we can use for coding".format(len(all_image_filenames)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-e01912aa3a65> in <module>()
# ----> 1 all_image_filenames = list(set(os.listdir('/Users/briankeegan/Dropbox/Workspace/Wikipedia images/Images/')) | set(os.listdir('/Users/briankeegan/Dropbox/Workspace/Wikipedia images/Error Images/')))
#       2 all_image_filenames = [unicodedata.normalize('NFKC',i) for i in all_image_filenames]
#       3
#       4 print("There are {0:,} images downloaded to disk we can use for coding".format(len(all_image_filenames)))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/briankeegan/Dropbox/Workspace/Wikipedia images/Images/'

# %%
set(all_image_filenames) - set(image_tags_dict.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-2d4f6bb5910f> in <module>()
# ----> 1 set(all_image_filenames) - set(image_tags_dict.keys())
#
# NameError: name 'all_image_filenames' is not defined

# %% [markdown]
# We want to align the `image_tags_dict` and files in `lang_images`, but there are Unicode normalization issues that happened when writing the filenames to disk as compared to how they're encoded on Wikipedia. It appears that writing to disk decomposed into characters and modifiers and Wikipedia has the composed representation.
#
# See also:
# * https://stackoverflow.com/questions/14682397/can-somone-explain-how-unicodedata-normalizeform-unistr-work-with-examples
# * https://docs.python.org/2/library/unicodedata.html#unicodedata.normalize

# %%
'4.19 혁명.jpg'.encode('utf8'), '4.19 혁명.jpg'.encode('utf8'), unicodedata.normalize('NFKC','4.19 혁명.jpg').encode('utf8')
# Out:
# (b'4.19 \xed\x98\x81\xeb\xaa\x85.jpg',
#  b'4.19 \xe1\x84\x92\xe1\x85\xa7\xe1\x86\xa8\xe1\x84\x86\xe1\x85\xa7\xe1\x86\xbc.jpg',
#  b'4.19 \xed\x98\x81\xeb\xaa\x85.jpg')

# %%
list(image_tags_dict.keys())[0].decode('utf8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-b0cf687b5353> in <module>()
# ----> 1 list(image_tags_dict.keys())[0].decode('utf8')
#
# NameError: name 'image_tags_dict' is not defined

# %%
#for image,tag_dict in list(image_tags_dict.items()):
#    if image in unicode_mapping_json_rv.keys():
#        new_image = unicode_mapping_json_rv[image]
#        image_tags_dict[new_image] = image_tags_dict[image]
#        del image_tags_dict[image]

for image,tag_dict in list(image_tags_dict.items()):
    image_decoded = image.decode('utf8')
    new_image_name = unicodedata.normalize('NFKC',image_decoded)
    if new_image_name in unicode_mapping_json_rv.keys():
        new_image_name = new_image_name.replace('_',' ')
        image_tags_dict[new_image_name] = image_tags_dict[image_decoded]

        del image_tags_dict[image_decoded]

# %%
lang_images = {lang:[] for topic, topic_d in all_coups_image_usage.items() for lang, lang_d in topic_d.items() if len(lang_d) > 0}

for topic, topic_d in all_coups_image_usage.items():
    for lang, lang_d in topic_d.items():
        for file, filelist in lang_d.items():
            lang_images[lang].append(file.split(':')[1])

# %% [markdown]
# These are images that were downloaded and tagged but apparently don't appear in any languages.

# %%
set(image_tags_dict.keys()) - set([f for lang,files in lang_images.items() for f in files])
# Out:
# {b'"De Historische Strijd" Herdenkingsmonument revolutie 25 februari 1980 - Nieuw-Amsterdam - 20418126 - RCE.jpg',
#  b'-De_Historische_Strijd-_Herdenkingsmonument_revolutie_25_februari_1980_-_Nieuw-Amsterdam_-_20418127_-_RCE.jpg',
#  b'11 septiembre 1976- manifestacion pro Pinochet.jpg',
#  b'14 July revolution - mutilated corpse.jpg',
#  b'15 July-Erdo\xc4\x9fan SMS.jpg',
#  b'15 Temmuz \xc5\x9eehitler Park\xc4\xb1 tabelas\xc4\xb1.jpg',
#  b'1920UnitedFruitCompanyEntrance.jpg',
#  b"1962 Burmese coup d'\xc3\xa9tat.jpg",
#  b"1962 Burmese coup d'\xc3\xa9tat2.jpg",
#  b'1973Babadinca0048.jpg',
#  b'1989 December 16. sug\xc3\xa1r\xc3\xbat \xc3\xa9s a Tudor Vladimirescu \xc3\xbat keresztez\xc5\x91d\xc3\xa9se. Fortepan 31892.jpg',
#  b'1989 Iliescu television.jpg',
#  b'1991 CPA 6367.jpg',
#  b'1991 CPA 6368.jpg',
#  b'1991 CPA 6369.jpg',
#  b'1991 CPA 6370.jpg',
#  b'1991 coup attempt1.jpg',
#  b'1991 coup attempt4.jpg',
#  b'1991 coup attempt5.jpg',
#  b'1991-August-Moscow.jpg',
#  b'1991-Barrikad-BelyDom.jpg',
#  b'1991_coup_yeltsin.jpg',
#  b"1992 Venezuelan coup d'\xc3\xa9tat attempts Hugo Ch\xc3\xa1vez speech.jpg",
#  b"1992 Venezuelan coup d'\xc3\xa9tat attempts Miraflores.jpg",
#  b"1992 Venezuelan coup d'\xc3\xa9tat attempts collage.png",
#  b'1993_Rusya_anayasa_krizi_s\xc4\xb1ras\xc4\xb1nda_Parlamento_yanl\xc4\xb1s\xc4\xb1_g\xc3\xb6stericiler.jpg',
#  b'1993_Tanks_before_Russian_White_house.jpg',
#  b'1_Mart_1997_-_Cumhuriyet.jpg',
#  b"2002 Venezuelan coup d'\xc3\xa9tat attempt collage.jpg",
#  b"2002 Venezuelan coup d'\xc3\xa9tat attempt uprising.jpg",
#  b'200535.jpg',
#  b'2006 09 12 sarkozy 600.jpg',
#  b'2006 Thailand Coup 006.jpg',
#  b'2006-06-22 12-36-38 Seychelles Cascade Cascade.jpg',
#  b'2007ManilaPenSiegeMap.jpg',
#  b'2009 Honduran demonstration against Zelaya and Chavez 1.jpg',
#  b'2009 Honduras political crisis 11.jpg',
#  b'2009 Honduras political crisis 2.jpg',
#  b'2009 Honduras political crisis 3.jpg',
#  b'2009 Honduras political crisis 4.jpg',
#  b'2009 Honduras political crisis 5.jpg',
#  b'2009 Honduras political crisis 9.jpg',
#  b'2013 Taksim Gezi Park protests (15th June).jpg',
#  b'2014 0526 Thailand coup Chang Phueak Gate Chiang Mai 01.jpg',
#  b'2014 0526 Thailand coup Chang Phueak Gate Chiang Mai 02.jpg',
#  b'2014 0526 Thailand coup Chang Phueak Gate Chiang Mai 03.jpg',
#  b'2014 0527 Thailand coup Thaphae Gate.jpg',
#  b'2014 Suchum, Siedziba rz\xc4\x85du i prezydenta Republiki Abchazji (04).jpg',
#  b'2014-02-02 Silom protest site 01.jpg',
#  b'2015 Asia Pacific Parliamentary Forum (1).jpg',
#  b'2016 T\xc3\xbcrkiye Darbe Giri\xc5\x9fimi - Ankara.jpg',
#  b"20th anniversary of 1953 Iranian coup d'\xc3\xa9tat.jpg",
#  b'21438_010.jpg',
#  b'24. Rupturas al cese al fuego.png',
#  b'247783721 10e33ed8c9 o.jpg',
#  b'24_\xd0\xb6\xd0\xbd\xd1\x96\xd1\x9e\xd0\xbd\xd1\x8f_1991.jpg',
#  b'25 Abril 1983 Porto by Henrique Matos 01.jpg',
#  b'25 de Abril sempre Henrique Matos.jpg',
#  b'27_May\xc4\xb1s_Darbesi_sembol\xc3\xbc.png',
#  b'28Amordad1332 Toopkhaneh.jpg',
#  b'28mordad1332.jpg',
#  b'34-o Anivers\xc3\xa1rio Revolu\xc3\xa7\xc3\xa3o dos Cravos, Lisboa.jpg',
#  b'4.19 \xed\x98\x81\xeb\xaa\x85.jpg',
#  b'4TD4-500x250.jpg',
#  b'4_Ekim_1993_Rusya_Parlamento_binas\xc4\xb1_alevler_i\xc3\xa7inde.jpg',
#  b'5.16 Coup Park Chung-hee.jpg',
#  b'5011-0004-reverse.png',
#  b'59mossadeghprime_minister1951.jpg',
#  b'757landing-toncontin.jpg',
#  b'A. Pinochet Stamp.jpg',
#  b'ABI100 KingFerdinandMuseum.jpg',
#  b'AIOC741330.jpg',
#  b'AUT Hadersdorf-Kammern COA.jpg',
#  b'Abadanraffinerie.jpg',
#  b'Abd Rabbuh Mansur Hadi 2013.jpg',
#  b'Abd al-Karim death.jpg',
#  b'Abd al-Wahab Shawaf.png',
#  b'Abdul Fatah Khalil Al-Sisi 2013-03-03.jpg',
#  b'Abdul Rahman Arif.jpg',
#  b'Abdul-salam-arif.jpg',
#  b'Abolghasem Kashani.jpg',
#  b'Ad-Duri.jpg',
#  b'Adib al-Shishakli.jpg',
#  b'Adnan Menderes VI. Yasama D\xc3\xb6nemi.jpg',
#  b'Africa satellite orthographic.jpg',
#  b'After burning the Muslim brotherhood stage in front of the mosque.jpg',
#  b'After coup nightly demonstartion of president Erdogan supporters. Istanbul, Turkey, Eastern Europe and Western Asia. 22 July,2016.jpg',
#  b'Ahmad Hassan el Bakr.jpg',
#  b'AhmadGhavam2.jpg',
#  b'Ahmed el-Tayeb May 2015 (17963337671).jpg',
#  b'Air Commodore Kaiser Tufail receiving a memento from Commander of the Turkish Air Force General Akin Ozturk (cropped).jpg',
#  b'Air Commodore Kaiser Tufail receiving a memento from Commander of the Turkish Air Force General Akin Ozturk.jpg',
#  b'Al Fujimori.jpg',
#  b'Alatoo.jpg',
#  b'Alegria rafael.jpg',
#  b'Alejandro Agust\xc3\xadn Lanusse.jpg',
#  b'Alexander Ankvab - 06.10.2011.jpg',
#  b'Algiers_putsch_1961.jpg',
#  b'Ali salih.jpg',
#  b'Alix Pasquet.jpg',
#  b'Allen w dulles.jpg',
#  b'Allende supporters.jpg',
#  b'Allende.jpg',
#  b'Allende_son.jpg',
#  b'Alte. Carlos G. N. Coda.jpg',
#  b'Alte. Pedro Gnavi.jpg',
#  b'Amadou Toumani Tour\xc3\xa9 30 November 2011.jpg',
#  b'AmauryKruel.jpg',
#  b'Angkor Wat W-Seite.jpg',
#  b'AngkorWat Delaporte1880.jpg',
#  b'Anti Morsi protest march at 28th June 2013.jpg',
#  b'Anti coup Mauritania.jpg',
#  b'Anti-Coup Demokrasi N\xc3\xb6beti K\xc4\xb1z\xc4\xb1lay Square.jpg',
#  b'Anti-Morsi poster in a car.jpg',
#  b'Anti-Morsi protester june 2013.jpg',
#  b'Anti-Morsi protests June 2013 in Egypt.jpg',
#  b'Anti-coup sit-in at Rabaa Adiweya mosque 2013.jpg',
#  b'Ant\xc3\xb3nio de Oliveira Salazar, drawing.jpg',
#  b'Apollo 11.jpg',
#  b'Arafat Darwish Habash.jpg',
#  b'Arafat in Jordan.jpg',
#  b'Araya-Allende.jpg',
#  b'Aref with Qasim.png',
#  b'Arif.jpg',
#  b'Arturo Illia.jpg',
#  b'Asia map.jpg',
#  b'Askar Akaev MoscowRia 08-2016.jpg',
#  b'Askar Akayev.jpg',
#  b'Assad Tlass war 1973.jpg',
#  b'AssaltonaMatadaSanga....jpg',
#  b'Assemblee Nationale Burkina Faso.jpg',
#  b'August 1991 Kalininski prospect.jpg',
#  b'Augusto Pinochet - 1995.jpg',
#  b'Augusto Pinochet 1986.jpg',
#  b'Augusto Pinochet foto oficial.jpg',
#  b'Augusto Pinochet.jpg',
#  b'Awqati1.jpg',
#  b'Ayatmohagheghi.jpg',
#  b'BBC Asian Network Studio The Mailbox Birmingham 20041228.jpg',
#  b'BKK21090604.jpg',
#  b'BKK22090601.jpg',
#  b'BKK24090601.jpg',
#  b'BKK24090602.jpg',
#  b'BKK24090603.jpg',
#  b'BKK24090612.jpg',
#  b'BKK24090613.jpg',
#  b'BKK24090615.jpg',
#  b'BKK24090616.jpg',
#  b'BKK24090618.jpg',
#  b'BP200906-2.jpg',
#  b'BTR-60PB DA-ST-89-06597.jpg',
#  b'BTR_25_april.jpg',
#  b'Baath National Command.jpg',
#  b'Baath Party founder Michel Aflaq with Iraqi President Ahmad Hasan al-Bakr in Baghdad in 1968.jpg',
#  b'Bakkir.jpg',
#  b'Bangkokplaces.png',
#  b'Barack Obama at Cairo University cropped.jpg',
#  b'Bashar al-Assad (cropped).jpg',
#  b'BenzinBon-1.jpg',
#  b'Binali Y\xc4\xb1ld\xc4\xb1r\xc4\xb1m headshot.jpg',
#  b'Black May 1992.jpg',
#  b'Black_May_Thailand.jpg',
#  b'Blaise Compaor\xc3\xa9 2014 White House.png',
#  b'Blargos1.jpg',
#  b'Blok wschodni pl.png',
#  b'Boeing 727-2B6, Royal Air Maroc - RAM AN1217763.jpg',
#  b'Bokassa portrait.jpg',
#  b'Bophuthatswana_coup_Execution.jpg',
#  b'Boris Yeltsin 19 August 1991-1.jpg',
#  b'Boris Yeltsin 1993.jpg',
#  b'Boris Yeltsin 21 February 1989-1.jpg',
#  b'Boris Yeltsin 22 August 1991-1.jpg',
#  b'Boris Yeltsin-2.jpg',
#  b'Bo\xc4\x9faz\xc4\xb1n tek y\xc3\xb6nl\xc3\xbc kapat\xc4\xb1lmas\xc4\xb1.png',
#  b'Bucur Obor (1986).jpg',
#  b'BuiQuangThan.jpg',
#  b'Bundesarchiv B 145 Bild-F013047-0040, M\xc3\xbcnchen, Staatsbesuch Pr\xc3\xa4sident von Zypern.jpg',
#  b'Bundesarchiv Bild 183-1989-1120-036, Berlin, Schweigemarsch f\xc3\xbcr Rum\xc3\xa4nien.jpg',
#  b'Bundesarchiv Bild 183-1989-1215-038, Berlin, Demonstration f\xc3\xbcr Rum\xc3\xa4nien.jpg',
#  b'Bundesarchiv Bild 183-1989-1220-032, Berlin, Demonstration f\xc3\xbcr Rum\xc3\xa4nien, Mahnwache.jpg',
#  b'Bundesarchiv Bild 183-1989-1221-032, Berlin, Demonstration f\xc3\xbcr Rum\xc3\xa4nien.jpg',
#  b'Bundesarchiv Bild 183-1989-1223-006, Berlin, Brandenburger Tor, Transparte zu Rum\xc3\xa4nien.jpg',
#  b'Bundesarchiv_Bild_183-55823-0005,_Berlin,_Karl-Marx-Allee,_-Deutsche_Sporthalle-.jpg',
#  b'Burkina Faso Protests.png',
#  b'Burkina Faso carte.png',
#  b'Burkinabe Col. Gilbert Diend\xc3\xa9r\xc3\xa9, 2010.jpg',
#  b'Burkinab\xc3\xa9_uprising_at_Place_de_la_Nation.jpg',
#  b'Burnt out buildings on nothern edge of Revolution Square, Bucharest.jpg',
#  b'Bush Gorba P15623-25A.jpg',
#  b'By-map.png',
#  b'B\xc3\xbclent Ecevit Cropped.jpg',
#  b'CFSN Revolution Roumaine.jpg',
#  b'Cairo pro-Mursi-protests July-August 2013 ARAB2.jpg',
#  b'CamGen.jpg',
#  b'Car of history.jpg',
#  b'Cardinal Jaime Sin in 1988.jpg',
#  b'Carlos Gomes Junior.jpg',
#  b'Carte gabon.png',
#  b'Castelo de Guimar\xc3\xa3es (Portugal).jpg',
#  b'Castelobranco.jpg',
#  b'Ceausescu, Nicolae.jpg',
#  b'Central african republic sm04.png',
#  b'Central african republic sm04ESP.jpg',
#  b'Centro SB.jpg',
#  b'Chamlong Srimuang 2008-12-27.jpg',
#  b'Chan o cha Portrait.jpg',
#  b'Chan_o_cha_Portrait.jpg',
#  b'Chancery.jpg',
#  b"Chang Myon 194804'.png",
#  b'Chavez-WSF2005.jpg',
#  b'Chavez_ba\xc5\x9far\xc4\xb1s\xc4\xb1z_darbeden_sonra_g\xc3\xb6reve_d\xc3\xb6nerken_13_Nisan_2002.jpg',
#  b'ChenGuatemala.jpg',
#  b'Chest badge Guards Russian Federation.png',
#  b'Chile - Pal\xc3\xa1cio de La Moneda - by S\xc3\xa9rgio Schmiegelow.jpg',
#  b'Chile- el pueblo vencera cropped.jpg',
#  b'Chile_Junta001.jpg',
#  b'Choi Kyu Ha.png',
#  b'Civilian with PM Md. 1963 during the Romanian Revolution of 1989.jpg',
#  b'Color Revolutions Map.png',
#  b'CongressBuilding SEATO.jpg',
#  b'Conmemoraci\xc3\xb3n 40 a\xc3\xb1os Museo de la Memoria 2.jpg',
#  b'Conmemoraci\xc3\xb3n de 40 a\xc3\xb1os del Golpe Militar 1.jpg',
#  b'Corazon Aquino 1986.jpg',
#  b'Corazon Aquino inauguration.jpg',
#  b'Cordobazo.jpg',
#  b'Coruche mural 25 Abril.jpg',
#  b'Cory Aquino during a ceremony honoring US Air Force.jpg',
#  b"Coup-d'etat-11-web-cnni.jpg",
#  b"Coup-d'etat-14-web-cnni.jpg",
#  b"Coup-d'etat-15-web-cnni.jpg",
#  b"Coup-d'etat-17.jpg",
#  b"Coup-d'etat-2-web-cnni.jpg",
#  b"Coup-d'etat-24-web-cnni.jpg",
#  b"Coup-d'etat-3-web-cnni.jpg",
#  b"Coup-d'etat-5-web-cnni.jpg",
#  b"Coup-d'etat-6-web-cnni.jpg",
#  b"Coup-d'etat-9-web-cnni.jpg",
#  b'CoupDarbe.jpg',
#  b'CriseConstitucionalRussaDe1993.png',
#  b'Cristina y Patricia Rodas.jpg',
#  b'Crop-Nicolae Ceaucescu 1978.jpg',
#  b'Curfew08142013.png',
#  b'DF-SC-83-08526.jpg',
#  b'DYazov1989.jpg',
#  b'Damietta protests.jpg',
#  b'Darbe kar\xc5\x9f\xc4\xb1t\xc4\xb1 protesto Tokat.jpg',
#  b'David Ben Gurion - General Ne Win PM of Burma 1959.jpg',
#  b'David Dacko 1962 crop.jpg',
#  b'David Haba Guinean army 2005-199.jpg',
#  b'Dawsonfieldcamels.jpg',
#  b'Day after Saur revolution in Kabul (773).jpg',
#  b'De Gaulle-OWI.jpg',
#  b'Dead No Coup 2016.jpg',
#  b'Dead bodies in RABIA Massacre (3).jpg',
#  b'Defense.gov News Photo 040304-F-2828D-065.jpg',
#  b'Demirel.jpg',
#  b'Desi Bouterse.jpg',
#  b'Diego Rivera 1932 b.jpg',
#  b'Diem dead.jpg',
#  b'Dinh doc lap bi doi bom.jpg',
#  b'Dioncounda Traore photo officielle de campagne 3 Mali 2012.jpg',
#  b'Division20.jpg',
#  b'Dvorec 27 12 79.jpg',
#  b'E preciso salvar Abril Henrique Matos.jpg',
#  b'EB Haiti.jpg',
#  b'EDSA People Power historical marker.jpg',
#  b'EDSA_Revolution_pic1.jpg',
#  b'Edmond Jouhaud 1961.jpg',
#  b'Egyptian Minister of Defense Abdel Fatah Al Sisi.jpg',
#  b'El Tres de Mayo, by Francisco de Goya, from Prado in Google Earth.jpg',
#  b'El presidente Rafael Correa escoltado en el 30S.jpg',
#  b'ElBaradei 030110.jpg',
#  b'Elena Ceausescu portrait.jpg',
#  b'Erdo\xc4\x9fan, 2012 (cropped).jpg',
#  b'Estadio nacional-Chile.jpg',
#  b'Eug\xc3\xa8ne Delacroix - La libert\xc3\xa9 guidant le peuple.jpg',
#  b'Evstafiev-40th army HQ-Amin-palace-Kabul.jpg',
#  b'Evstafiev-Valentin Varennikov 11AUG94.jpg',
#  b'Evstafiev-alexander-rutskoy-w.jpg',
#  b'Evstafiev-spetsnaz-prepare-for-mission.jpg',
#  b'Ex General Efrain Rios Montt testifying during the trial.jpg',
#  b'FETO attack EGM Building.jpg',
#  b'FUA manifestaci\xc3\xb3n 70s-2.jpg',
#  b'FUNCINPEC logo 2006-2015.jpg',
#  b'Faisal 4.jpg',
#  b'Faisal hussein.jpg',
#  b'Fatin R\xc3\xbc\xc5\x9ft\xc3\xbc Zorlu.jpg',
#  b'Fazlollah zahedi.jpg',
#  b'Ferdinand & Imelda Marcos in Leyte 1984-10-20.jpg',
#  b'Fethullah Army EGM attack.jpg',
#  b'Fethullah G\xc3\xbclen 2016.jpg',
#  b'Fethullah G\xc3\xbclen cropped (cropped) (cropped).jpg',
#  b'Fethullah G\xc3\xbclen cropped (cropped).jpg',
#  b'Fethullah G\xc3\xbclen cropped.jpg',
#  b'Fifties jukebox.png',
#  b'Fijitimes-120706.jpg',
#  b'Fireworks at Anti-Morsi protests.jpg',
#  b'First Majlis MPs.jpg',
#  b'Francisco-Macias-Nguema personality cult photo.jpg',
#  b'Francois_Duvalier_during_1958_coup_attempt.jpg',
#  b'Frank Bainimarama September 2014.jpg',
#  b'Freedom_and_Justice_Party_(Egypt).jpg',
#  b'Gabinete allende 2 1024.jpg',
#  b'Gailani.jpg',
#  b'Gandhi Salt March.jpg',
#  b'Gaziosmanpa\xc5\x9fa meydan\xc4\xb1 protesto.jpg',
#  b'Gebze Square No Coup protests.jpg',
#  b'Gen William C Westmoreland.jpg',
#  b'General Al Sisi.jpg',
#  b'General Hafez al-Assad in 1970, during the Syrian Corrective Revolution.jpg',
#  b'General Salah Jadid.jpg',
#  b'General Shamim Alam Khan receiving the Hilal-i-Imtiaz.jpg',
#  b'General_Al-Sisi,_announcing_the_removal_of_President_Morsi.png',
#  b'General_el_Sisi_Mursiyi_g\xc3\xb6revden_al\xc4\xb1nd\xc4\xb1\xc4\x9f\xc4\xb1n\xc4\xb1_a\xc3\xa7\xc4\xb1klarken.png',
#  b'Genesis_FUBELT.jpg',
#  b'George H. W. Bush and Boris Yeltsin 1993.jpg',
#  b'Germame Neway.jpg',
#  b'Gloria Macapagal Arroyo.jpg',
#  b'Gloria Macapagal-Arroyo, Davos.jpg',
#  b'Gnassingbe Eyadema detail1 DF-SC-84-10025.jpg',
#  b'Golpe Estado Tailandia.jpg',
#  b'Golpe de Estado 1973.jpg',
#  b'Golpe_de_1964.jpg',
#  b'Goulartcentral.jpg',
#  b'Grave of Nicolae Ceausescu - Ghencea Civil Cemetery - Bucharest - Romania.jpg',
#  b'Guanabarasandbag.jpg',
#  b'Guarbadge.png',
#  b'Guatemala-CIA WFB Map.png',
#  b'Guinea Bissaus interim President Raimundo Pereira (cropped).jpg',
#  b'Guinea bissau sm03.png',
#  b'GulagulLaRomani.jpg',
#  b"G\xc3\xa9n\xc3\xa9ral de corps d'arm\xc3\xa9e Salou Djibo.jpg",
#  b'H.E. Mr. Mothetjoa Metsing, Deputy Prime Minister, Kingdom of Lesotho (8008839925) (cropped).jpg',
#  b'HN999sRamon 2obreros-.jpg',
#  b'Habs un headquarters.jpg',
#  b'Hafizullah Amin.jpg',
#  b'Hakar (28338755964).jpg',
#  b'Hameed.png',
#  b'Harold Wilson Number 10 official.jpg',
#  b'Hasan Polatkan.jpg',
#  b"Hashem al Atta, 1971 Sudanese coup d'\xc3\xa9tat.jpg",
#  b"Hashem al Atta, Khalid Hassan Abbas, 1971 Sudanese coup d'\xc3\xa9tat.jpg",
#  b'Hastear da bandeira da Guin\xc3\xa9 Bissau ap\xc3\xb3s o arrear da de Portugal.jpg',
#  b'Hazem Beblawy.jpg',
#  b'Hazim jiwad.jpg',
#  b'Henry Kissinger.png',
#  b'Heo Jeong.png',
#  b'Hiillary Clinton and Manuel Zelaya.jpg',
#  b'Honduras golpe protesta.jpg',
#  b'Horace Vernet-Barricade rue Soufflot.jpg',
#  b'Hossein Fatemi Body.jpg',
#  b'HosseinFatemi2.jpg',
#  b'Houthi_Declaration_6-2-2015.png',
#  b'Hugo Chavez in Guatemala.jpg',
#  b'Hugo Ch\xc3\xa1vez (02-04-2010).jpg',
#  b'Hulusi Akar (cropped version).jpg',
#  b'Hulusi Akar (cropped).jpg',
#  b'Hun Sen crop.jpg',
#  b'Hussein 1978.jpg',
#  b'H\xc3\xa9micycle 2 Palais Bourbon scropped and smaller.jpg',
#  b'Ikhwan-logo.jpg',
#  b'Iliescu si Bush.jpg',
#  b'Image0 ST.jpg',
#  b"In_People's_Name.jpg",
#  b'Inonu Ismet.jpg',
#  b'Iran_NF.jpg',
#  b'Iraq, Saddam Hussein (222).jpg',
#  b'Iraq14.jpg',
#  b'Iskander Mirza.jpg',
#  b'Istanbul -H\xc3\xbcrriyet- 2000 by RaBoe 02.jpg',
#  b'Istor portal.png',
#  b'Ivato Intl Airport Antananarivo Madagascar.jpg',
#  b'Ja3far askari.jpg',
#  b'Janio Quadros.png',
#  b'Jassem Alwan.jpg',
#  b'Jean Ping 080202-F-1644L-081 0YWDF.jpg',
#  b'Jo-map (German).png',
#  b'Joao IV proclaimed king.jpg',
#  b'Joe baxter.jpg',
#  b'John L Throckmorton.jpg',
#  b'Jorge Videla 1976.jpg',
#  b'Joseph estrada 2000.jpg',
#  b'Jos\xc3\xa9 Afonso by Henrique Matos 001.jpg',
#  b'Jos\xc3\xa9 Toribio Merino Castro cropped.jpg',
#  b'Jo\xc3\xa3o Goulart NYWTS.jpg',
#  b'Jo\xc3\xa3o Goulart nos Estados Unidos em 1962.jpg',
#  b'Juan Maria Bordaberry.jpg',
#  b'July1.jpg',
#  b'Juntagobierno1944.jpg',
#  b'Juntagovernativa1969.png',
#  b'Juv\xc3\xa9nal Habyarimana (1980).jpg',
#  b'Juv\xc3\xa9nal Habyarimana (Andrews Air Force Base, Maryland, USA - 1980).jpg',
#  b'Kairo Pro-Mursi-Proteste Juli-August 2013.jpg',
#  b'Karim01 small.jpg',
#  b'Kennedy and Goulart review troops 1962.jpg',
#  b'King Hassan II.jpg',
#  b'King_CDRM_L.jpg',
#  b'Kingdom of Fez.jpg',
#  b'Kirgizija.jpg',
#  b'Kongress in valparaiso.jpg',
#  b'Konstitucion\xc4\x81lais_likums_Par_Latvijas_Republikas_valstisko_statusu.jpg',
#  b'Kurmanbek Bakiyev.jpg',
#  b'K\xc4\xb1rklareli TSK crop.jpg',
#  b'K\xc4\xb1z\xc4\xb1lay - democracy and tanks.png',
#  b'LBJ nhu.jpg',
#  b'LRAP_un_MP_1991._gada_19._augusta_pazi\xc5\x86ojums.jpg',
#  b'La Mano memory 40 years Chile dictatorship 1.jpg',
#  b'Ladgham_arafat.jpg',
#  b'Lansana Conte 27 July 2001a.jpg',
#  b'Last_day_qasim.jpg',
#  b'Lbj mnhu.jpg',
#  b'Ldpr.png',
#  b'Leaders of July 14 1958 Revolution.jpg',
#  b'Lechfeld Elite 2008 144 (2663713634).jpg',
#  b'Lee Han-lim.jpg',
#  b'Les alli\xc3\xa9s dal-Qaida d\xc3\xa9truisent un tombeau sacr\xc3\xa9 \xc3\xa0 Tombouctou (8142142738).jpg',
#  b'Lisboa Monumento 25 Abril.jpg',
#  b'Lissabon_25_april.jpg',
#  b'Location of Abkhazia in Europe2.png',
#  b'LocationKyrgyzstan.png',
#  b'LocationPortugal.png',
#  b'Logo_for_Liberal_Democratic_Party_of_Russia.png',
#  b'LonNol.jpg',
#  b'Lon_Nol,_Sisowath_Sirik_Matak,_In_Tam.jpg',
#  b'Lt-map.png',
#  b'Lucio Guti\xc3\xa9rrez.jpg',
#  b"L\xc3\xa9on M'ba 1964.jpg",
#  b'MBKT\xc3\xbcrke\xc5\x9f.jpg',
#  b'Madame Ng\xc3\xb4 \xc4\x90\xc3\xacnh Nhu and Lyndon Baines Johnson.jpg',
#  b'Maflaq.jpg',
#  b'Mahamadou Issoufou VOA 150 4dec04.jpg',
#  b'Major-general-lansdale.jpg',
#  b'Makarios III and Robert F. Wagner NYWTS cropped.jpg',
#  b'Makatisiege_ajescreenshot.jpg',
#  b'Malian Soldiers.jpg',
#  b'Manifest_revolutie_1989.jpg',
#  b'Manifestation \xc3\xa0 Nouadhibou-2008.jpg',
#  b'ManilaPenn.jpg',
#  b'Manuel Zelaya detail, ABR August 07, 2007.jpg',
#  b'Mao Sihanouk.jpg',
#  b'Marcello caetano.jpg',
#  b'Marche sel.jpg',
#  b'Marcos visit Reagan 1982.jpg',
#  b'Maria Corina Machado (Sumate) meets George W. Bush (2002).jpg',
#  b'Mariinsky Palace Saint Petersburg.jpg',
#  b'Masacre de Ezeiza - persona subiendo al palco.jpg',
#  b'Mass on the street 1989.jpg',
#  b'Mauritania gov ould taya 210 eng 30apr05.jpg',
#  b"Mauritanie-Coup d'Etat 2008.jpg",
#  b'Maxwell D Taylor official portrait.jpg',
#  b'May 16th Coup dEtat (1961) 5.16 \xea\xb5\xb0\xec\x82\xac\xed\x98\x81\xeb\xaa\x85 (5591601384).jpg',
#  b"May\xc4\xb1s_1981_Kenan_Evren_Ankarag\xc3\xbcc\xc3\xbc_kaptan\xc4\xb1_Adil_Eri\xc3\xa7'e_T\xc3\xbcrkiye_Kupas\xc4\xb1'n\xc4\xb1_veriyor.jpg",
#  b'Md2002 kramar.jpg',
#  b'Memorial to Jordanian soldiers (Karameh, Jordan).jpg',
#  b'Mengistu Neway.jpg',
#  b'Mengistu_&_Merid.jpg',
#  b'Mengistu_and_germame_Neway.jpg',
#  b'Mercator Africa 037.jpg',
#  b'Mhdawi.jpg',
#  b'MichaelKafando.jpg',
#  b'Michel Aflaq and Salah Jadid in 1963.jpg',
#  b'Military Committee celebrates 1963 coup.jpg',
#  b'Mohamad Reza Shah Pahlavi in hospital 1949 jpeg.jpg',
#  b'Mohamed Morsi-05-2013.jpg',
#  b'Mohammad Mosaddeq, Ahmadabad 1965.jpg',
#  b'Mohammad-reza-shah.jpg',
#  b'MohammadMossadeqAdibBoroumand.jpg',
#  b'Morande 80 11 septiembre 2009.jpg',
#  b'Moroccan Air Force.png',
#  b'Morsi supporter after mass killings of 27-July-2013.jpg',
#  b"Morsi's ouster celebrations Tahrir 20130707-4.jpg",
#  b'Mosaddegh Kashani123.jpg',
#  b'Mossadeghmohammad.jpg',
#  b'Mossadeghmohammadrezashah.jpg',
#  b'Muammar al-Gaddafi 1-1.jpg',
#  b'Muhammad Zia-ul-Haq 1982.jpg',
#  b'Muhammad al-Rubaiai.jpg',
#  b'Mural2.jpg',
#  b'MuricyMourao.jpg',
#  b'Museo Aeron\xc3\xa1utico 2.jpg',
#  b'Mustafa Kemal Atat\xc3\xbcrk.jpg',
#  b'Mwambutsa 1962.jpg',
#  b'NF 1978 - 1980.jpg',
#  b'Naguib.jpg',
#  b'Nasser Qaddafi Atassi 1969.jpg',
#  b'Nasser brokering ceasefire with Chairman Arafat and King Hussein.jpg',
#  b'Nasser, Hussein and Amer before signing Egyptian-Jordanian defense pact.jpg',
#  b'Nasser, al-Bakr and Atassi, 1963.jpg',
#  b'Nasser-Faisal-Arafat-1970.jpg',
#  b'National Revolutionary Command Council (Sudan).jpg',
#  b'Naval Battle of Navarino by Garneray.jpg',
#  b'Necmettin Erbakan.jpg',
#  b'Newsweek_22_Eyl\xc3\xbcl_1980_kapak.jpg',
#  b'Ngo Dinh Diem - Thumbnail - ARC 542189.png',
#  b'Nguyen Cao Ky.jpg',
#  b'Nguyen Van Thieu with map (cropped).jpg',
#  b'Nguy\xe1\xbb\x85n Kh\xc3\xa1nh 1964.jpg',
#  b'Nh\xc3\xa0 th\xe1\xbb\x9d Cha Tam.jpg',
#  b'Nick_Faeldon_2007.jpg',
#  b'Nicolae Ceaucescu 1978.jpg',
#  b'Nicolae Ceausescu.jpg',
#  b'Nicolae Ceau\xc8\x99escu Mormant.jpg',
#  b'Niger mk.jpg',
#  b"Ninoy_Aquino's_-Testament_from_Prison_Cell-_signed_by_Cory_Aquino_in_1983.jpg",
#  b'Niwatthamrong Boonsongpaisan at Ministerial Conference 2013 crop.jpg',
#  b'Nixon 30-0316a.jpg',
#  b'Nochavezortega.jpg',
#  b'Northrop F-5B (SN 63-8438, the first production -B model) 060905-F-1234S-005.jpg',
#  b'Northrop F-5E (Tail No. 11419) (cropped).jpg',
#  b'Northrop YF-5A (SN 59-4987) with a full load of bombs 060905-F-1234S-002.jpg',
#  b'Nouakchott-mosquee.jpg',
#  b'Nuamthong.jpg',
#  b'Oakwood, Makati, Glorietta - panoramio.jpg',
#  b'Obama meets with coalition Chiefs of Defense 141014-D-KC128-186.jpg',
#  b'Omar Bongo crop.jpg',
#  b'Ongan\xc3\xada-Levingston-Lanusse (Revoluci\xc3\xb3n Argentina).jpg',
#  b'Operacio_marverde.jpg',
#  b'Operationajax.jpg',
#  b'Opera\xc3\xa7\xc3\xa3o Vag\xc3\xb4 - memorial no Cemit\xc3\xa9rio dos Prazeres.jpg',
#  b'Order of Saur Revolution1979.jpg',
#  b'Order of the Red Banner.jpg',
#  b'Order of the Red Banner.png',
#  b'Otelo.jpg',
#  b'Oubangui-Chari.jpg',
#  b'PAIGC posto de controlo.jpg',
#  b'PFLP-group-1969.jpg',
#  b'PSRS_Valsts_padomes_l\xc4\x93mums_par_Latvijas_Republikas_neatkar\xc4\xabbas_atz\xc4\xab\xc5\xa1anu.jpg',
#  b'Palacio Carondelet en la noche.jpg',
#  b'Palacio Nacional de la Cultura.jpg',
#  b'Palacio de La Moneda.png',
#  b'Park Chung hee.jpg',
#  b'Park Chung-hee, 1961-August-21.jpg',
#  b'Parlamentspalast_in_Bukarest.jpg',
#  b'Pedro_Carmona_2002_darbesinden_sonra_yemin_t\xc3\xb6reninde.jpg',
#  b'People_Power_Revolution_commemorative_10-peso_coin_obverse_and_reverse.png',
#  b'Pepe Lobo 2010-01-27.jpg',
#  b'Pervez Musharraf 2004.jpg',
#  b'PervezMusharraf.jpg',
#  b'Philippine History Collage.jpg',
#  b'Php bill 200 back.jpg',
#  b'Picture 032.jpg',
#  b'Pinochet en 1974.jpg',
#  b'Pisagua3.jpg',
#  b'PithHelmetTruman.jpg',
#  b'Plevne_Mar\xc5\x9f\xc4\xb1_pul.jpg',
#  b'Ponte25Abril1.jpg',
#  b'Popular-Front-for-the-Liberation-of-Palestine-general-command.png',
#  b'Port-au-Prince med.jpg',
#  b'Portail Arm\xc3\xa9e fran\xc3\xa7aise.png',
#  b'Portrait officiel Bourguiba.png',
#  b'Portugallia et Algarbia.jpg',
#  b'Povo_mfa.jpg',
#  b'PozeRevolutia1989clujByRazvanRotta02.jpg',
#  b'PozeRevolutia1989clujByRazvanRotta13.jpg',
#  b'Prayuth Jan-ocha 2010-06-17 Cropped.jpg',
#  b'Pra\xc3\xa7a 25 de Abril.jpg',
#  b'President Abd al-Salam Arif.jpg',
#  b'President Ali Abdullah Saleh.jpg',
#  b'President Barack Obama meets with members of his national security team, including Defense Secretary Chuck Hagel, to discuss the situation in Egypt, in the Situation Room of the White House, July 3, 2013.jpg',
#  b'President Direct Election Movement Ming-te Shih Yi-hsiung Lin and Hsin-liang Hsu.jpg',
#  b'President Eisenhower and John Foster Dulles in 1956.jpg',
#  b'President Nguyen Van Thieu.jpg',
#  b'President Obama on the phone in the Oval Office with Secretary Kerry regarding the situation in Turkey (27716300004).jpg',
#  b'President Obiang.jpg',
#  b'President of Kyrgyzstan, Kurmanbek Bakiyev crop.jpg',
#  b'Prime Minister of Turkey Recep Tayyip Erdogan cropped.jpg',
#  b'PrimeMinisterNawazSharif.jpg',
#  b'Project 571 Outline.jpg',
#  b'Propaganda del govierno en a\xc3\xb1os posteriores.jpg',
#  b'Propaganda poster Ceausescu.jpg',
#  b'Protestors issues Morsi a red card..jpg',
#  b'Protests No Coup 2016.jpg',
#  b'Protests in Egypt January 2013.jpg',
#  b'Puente LLaguno.jpg',
#  b'Qasim2.jpg',
#  b'Qasim_arif.jpg',
#  b'Queens Palace (5300182685).jpg',
#  b'Quema de libros.jpg',
#  b'Quetzaltenango farm highlands 2009.jpg',
#  b'R4bia sign used in solidarity with victims of Rabaa crackdown 23-Aug-2013.jpg',
#  b'RIAN archive 848095 Signing the Agreement to eliminate the USSR and establish the Commonwealth of Independent States.jpg',
#  b'RO B University square rally.jpg',
#  b'Rabaa al-Adawiya.png',
#  b'Rafael Correa presidenciagovar 15ENE07.jpg',
#  b'Rafaelcorrea08122006.jpg',
#  b'Rafiq1.jpg',
#  b'RafiqArif.jpg',
#  b'Rama IX on his Throne.jpg',
#  b'RangoonStreetView.jpg',
#  b"Rapport droits de l'homme 1989 01.jpg",
#  b'Reagan and Gorbachev signing.jpg',
#  b'Recep Tayyip Erdo\xc4\x9fan.jpg',
#  b'RecepTayyipErdo\xc4\x9fan (cropped).jpg',
#  b'Reform_the_Armed_Forces_Movement_logo_circa_1990s.png',
#  b'Regimiento Tacna No1.jpg',
#  b'Revolutie-strada-multime.jpg',
#  b'Reza Pahlavi I.jpg',
#  b'RichardNixon.jpg',
#  b'Rifle AKS MON.jpg',
#  b'Rikabi.jpg',
#  b'Roberto micheletti 01.jpg',
#  b'Rodrigo de Rato y Figaredo.jpg',
#  b'Romania, Transylvania, Timisoara Fortepan 31879.jpg',
#  b'Romanian Revlution 1989 2.jpg',
#  b'Romanian Revolution 1989 1.jpg',
#  b'Romanian Revolution 1989 4.jpg',
#  b'Romanian Revolution 1989 5.jpg',
#  b'Romanian Revolution 1989 Corpses.jpg',
#  b'Romanian Revolution 1989 Demonstrators.jpg',
#  b'Romanian Revolution 1989 WeWillWin.jpg',
#  b'Romanian ration-card for bread, 1989.jpg',
#  b'Rom\xc3\xa1n Nemzeti Sz\xc3\xadnh\xc3\xa1z \xc3\xa9s Operah\xc3\xa1z, T-55 harckocsi. Rom\xc3\xa1niai forradalom. Fortepan 31905.jpg',
#  b'Royal Palace, Rabat.jpg',
#  b'Rumo a liberdade Henrique Matos.jpg',
#  b'Russian Congressional Fractions 1992.png',
#  b'Russian Congressional Fractions 1993.png',
#  b'SD visits Turkey 1000w q95.jpg',
#  b'Saadi.jpg',
#  b'Salah Bitar.jpg',
#  b'Salammq.png',
#  b'Sallama.png',
#  b'Salvador_Alyendenin_son_foto_\xc5\x9f\xc9\x99kili.jpg',
#  b'Samuel_K._Doe_During_the_1980_Coup.png',
#  b'San Carlos military stockade - Venezuela.jpg',
#  b'Sana.jpg',
#  b'Satellite image of Cyprus, cropped.jpg',
#  b'Secalbright.jpg',
#  b'Secretary Kerry Bids Farewell To Egyptian Minister of Defense General al-Sisi.jpg',
#  b'Secretary Kerry and Pakistani Advisor Aziz Address Reporters.jpg',
#  b'Secretary of Defense Chuck Hagel meets with Egyptian President Mohamed Morsy in Cairo, Egypt, April 24, 2013.jpg',
#  b'Sekou Toure usgov-83-08641.jpg',
#  b'Selassie restored.jpg',
#  b'Sempreatentos...aoperigo!.jpg',
#  b'Senior officials in the Baath Party in a rare un-official photograph with Salah Jadid from 1969.jpg',
#  b'Separate division operational use.jpg',
#  b'Serie Portugal, verkiezingsstrijd in Lissabon (begin 1975); straatbeelden met verkiezingsaffiches.jpg',
#  b'Set20060921.jpg',
#  b'Shaabanbimokh.jpg',
#  b'ShahSorayaPM.jpg',
#  b'Shahanshah1333.jpg',
#  b'Sheikh mujibur rahman1950 140x190.jpg',
#  b'Shield of the Kingdom of Portugal (1481-1910).png',
#  b'Siam Paragon Bangkok 1.jpg',
#  b'Sibiu - Piata Mare - 1989 memorial.jpg',
#  b'Sidi Mohamed Ould Cheikh Abdallahi.jpg',
#  b"Sincan'dan_ge\xc3\xa7en_tanklar.jpg",
#  b'Sincan_tanks.jpg',
#  b'Siri3.jpg',
#  b'Soldados en la calle Chile-1973.png',
#  b'Soldier in Tahrir.jpg',
#  b'Soviet Guards badge.png',
#  b'Soviet Union Administrative Divisions 1989.jpg',
#  b'SovietInvasionAfghanistanMap.png',
#  b'Sputnik asm.jpg',
#  b'Stamp Fiji 1959 2 6 Nadi Airport.jpg',
#  b'Stamp Salvador Allende.jpg',
#  b'Stamp of Afghanistan (1979) - Saur Revolution.jpg',
#  b'Statul Major General.jpg',
#  b'Stema Statului Major al Fortelor Terestre.jpg',
#  b'Strait of gibraltar-rightee.jpg',
#  b'Supreme Court of Pakistan,Islamabad by Usman Ghani.jpg',
#  b'Supreme_Soviet_of_Russia_meeting_(1993).png',
#  b'Sylvanus Olympio.jpg',
#  b'Syria.BasharAlAssad.02.jpg',
#  b'Syrian Baath Logo.jpg',
#  b'Syrien 1961 0003.jpg',
#  b'T-72 tank in Moscow, August 1991.jpg',
#  b'TBMM coup attempt 15 June 2016.png',
#  b'TPAjax.jpg',
#  b'TRT Ankara.jpg',
#  b'Tabaqchali1.jpg',
#  b'Taher_yahya.jpg',
#  b'Tahrir Square on November 27 2012 (Morning).jpg',
#  b'Taman.png',
#  b'Tandja in Nigeria June 2007.jpg',
#  b'Tanks_approach_the_Ataturk_airport.jpg',
#  b'Tanks_before_Russian_White_house.jpg',
#  b'Tanques_Venezuela_1958.jpg',
#  b'Tawadros II of Alexandria.jpg',
#  b'Teniente General(R)PistariniPascual.jpg',
#  b'Tentativa_de_golpe_de_Estado_na_Turquia.jpg',
#  b'Thai coup soldier.jpg',
#  b'Thai-coup-detat-2014-social-media-banner.jpg',
#  b'Thailand Army(9-24-2006).jpg',
#  b'Thailand Ministry of Information and Communication Technology 2014 Censorship Image.jpg',
#  b'Thaksin crop.jpg',
#  b'Thaksin.jpg',
#  b'The Four Voyages of Columbus 1492-1503 - Project Gutenberg etext 18571.jpg',
#  b'The philosopher Zaki al-Arsuzi.jpg',
#  b'The_Bangkok_Post,_September_20,_2006.jpg',
#  b'The_nation_200506.jpg',
#  b'Thi and thieu.jpg',
#  b'TimbruNicolaeCeausescu.png',
#  b'TimbruRevolutie.png',
#  b'TimisoaraCatedrala.jpg',
#  b'Togoland.png',
#  b'Tokat darbe kar\xc5\x9f\xc4\xb1tlar\xc4\xb1.png',
#  b'Tom Thabane cropped.jpg',
#  b'Tom Thabane.jpg',
#  b'Toure-folklife.jpg',
#  b'Toure-folklife2.jpg',
#  b'Translation2.png',
#  b'Trial_iraq.jpg',
#  b'Truman initiating Korean involvement.jpg',
#  b'Tsn-1962.jpg',
#  b'Tte.Gral. (R) J. Videla.jpg',
#  b'Tulip 2.jpg',
#  b'Tulip.jpg',
#  b'Turcja, 15-16.07.2016r. Pr\xc3\xb3ba zamachu.png',
#  b'Turgut \xc3\x96zal cropped.jpg',
#  b'Turkey - Air Force Lockheed C-130E Hercules Bakema.jpg',
#  b'Turkey topo.jpg',
#  b'Turkish CoastMAK.png',
#  b'Turkish protesters in Istanbul.jpg',
#  b'T\xc5\x91k\xc3\xa9sL.jpg',
#  b'US Air Force C-22B (727-100).jpg',
#  b'US Marine charges through Japanese machine gun fire on Okinawa.jpg',
#  b'USS Jesse L. Brown (FF-1089) off Maine.jpg',
#  b'UXP Unidad Popular.png',
#  b'Un-guatemala.png',
#  b'Un-pakistan.png',
#  b'Unasur BsAs Crisis Ecuador.jpg',
#  b'Unidad Popular 1973.png',
#  b'V._Landsbergis._Vie\xc5\xa1oji_informacija.jpg',
#  b'Videla Sociedad Rural.jpg',
#  b'Viennese Illuminated Chronicle Posada.jpg',
#  b'Viva a liberdade Henrique Matos.jpg',
#  b'Vladimir Putin and Recep Tayyip Erdo\xc4\x9fan (2015-06-13) 3.jpg',
#  b'Vympel special forces.png',
#  b'Watanyin.jpg',
#  b"William Knox D'Arcy.jpg",
#  b'World Factbook (1982) Seychelles.jpg',
#  b'Yalta summit 1945 with Churchill, Roosevelt, Stalin.jpg',
#  b'Yameogo stamp 1960.png',
#  b'Yanaon.jpg',
#  b'Yankee go home graffiti.png',
#  b'Yeltsin 1993 cropped.jpg',
#  b'Yemen war detailed map.png',
#  b'Yun Bo1.jpg',
#  b'ZSU-23-4-Camp-Pendleton.jpg',
#  b'Zahedifirman.jpg',
#  b'Zelaya con sombrero.jpg',
#  b'Zelaya in Brazil.jpg',
#  b'Zine El Abidine Ben Ali cropped.jpg',
#  b'Zulfikar Ali Bhutto.jpg',
#  b'\xc3\x81lvaro Cunhal Henrique Matos 02.jpg',
#  b'\xc3\x87evik Bir DD-SD-00-01007.jpg',
#  b'\xc3\x93scar Arias (2009).jpg',
#  b'\xc3\x9clk\xc3\xbc Ocaklar\xc4\xb1 E\xc4\x9fitim ve K\xc3\xbclt\xc3\xbcr Vakf\xc4\xb1 Logosu.png',
#  b'\xc5\x9eanl\xc4\xb1urfa 2016.jpg',
#  b'\xce\x9d\xce\xb9\xce\xba\xce\xbf\xcf\x82 \xce\xa3\xce\xb1\xce\xbc\xcf\x88\xcf\x8e\xce\xbd.jpg',
#  b'\xd0\x91\xd0\xbe\xd1\x80\xd0\xb8\xd1\x81 \xd0\x9d\xd0\xb8\xd0\xba\xd0\xbe\xd0\xbb\xd0\xb0\xd0\xb5\xd0\xb2\xd0\xb8\xd1\x87 \xd0\x95\xd0\xbb\xd1\x8c\xd1\x86\xd0\xb8\xd0\xbd.jpg',
#  b'\xd0\x91\xd1\x96\xd1\x88\xd0\xba\xd0\xb5\xd0\xba 28 \xd0\xb1\xd0\xb5\xd1\x80\xd0\xb5\xd0\xb7\xd0\xbd\xd1\x8f 2005.jpg',
#  b'\xd0\x93\xd0\xb2\xd0\xb0\xd1\x80\xd0\xb4\xd0\xb8\xd1\x8f.png',
#  b'\xd0\x94\xd0\xb2\xd0\xbe\xd1\x80\xd0\xb5\xd1\x86 \xd1\x81\xd0\xbe \xd1\x81\xd1\x82\xd0\xbe\xd1\x80\xd0\xbe\xd0\xbd\xd1\x8b \xd0\xbf\xd1\x80\xd0\xb0\xd0\xb2\xd0\xbe\xd0\xb3\xd0\xbe \xd0\xba\xd1\x80\xd1\x8b\xd0\xbb\xd0\xb0 27 12 79.jpg',
#  b'\xd0\x97\xd0\xb0\xd1\x89\xd0\xb8\xd1\x82\xd0\xbd\xd0\xba\xd0\xb8 \xd0\x91\xd0\xb5\xd0\xbb\xd0\xbe\xd0\xb3\xd0\xbe \xd0\x94\xd0\xbe\xd0\xbc\xd0\xb0 1.jpg',
#  b'\xd0\x9a\xd0\xb0\xd0\xb7\xd0\xbd\xd1\x8c_\xd0\x9a\xd0\xb0\xd1\x81\xd0\xb5\xd0\xbc\xd0\xb0.jpg',
#  b'\xd0\x9a\xd0\xbe\xd0\xba\xd0\xb0\xd1\x80\xd0\xb4\xd0\xb0 \xd1\x80\xd1\x8f\xd0\xb4\xd0\xbe\xd0\xb2\xd0\xbe\xd0\xb3\xd0\xbe \xd0\xb8 \xd1\x81\xd0\xb5\xd1\x80\xd0\xb6\xd0\xb0\xd0\xbd\xd1\x82\xd1\x81\xd0\xba\xd0\xbe\xd0\xb3\xd0\xbe \xd1\x81\xd0\xbe\xd1\x81\xd1\x82\xd0\xb0\xd0\xb2\xd0\xb0 \xd0\xa1\xd0\xbe\xd0\xb2\xd0\xb5\xd1\x82\xd1\x81\xd0\xba\xd0\xbe\xd0\xb9 \xd0\x90\xd1\x80\xd0\xbc\xd0\xb8\xd0\xb8.jpg',
#  b'\xd0\xa0\xd0\xb0\xd1\x81\xd1\x81\xd1\x82\xd1\x80\xd0\xb5\xd0\xbb_\xd0\xb1\xd0\xb5\xd0\xbb\xd0\xbe\xd0\xb3\xd0\xbe_\xd0\xb4\xd0\xbe\xd0\xbc\xd0\xb0_\xd0\xb2_1993_\xd0\xb3\xd0\xbe\xd0\xb4\xd1\x83.jpg',
#  b'\xd0\xa0\xd1\x83\xd1\x81\xd1\x81\xd0\xba\xd0\xbe\xd0\xb5 \xd0\x9d\xd0\xb0\xd1\x86\xd0\xb8\xd0\xbe\xd0\xbd\xd0\xb0\xd0\xbb\xd1\x8c\xd0\xbd\xd0\xbe\xd0\xb5 \xd0\x95\xd0\xb4\xd0\xb8\xd0\xbd\xd1\x81\xd1\x82\xd0\xb2\xd0\xbe.jpg',
#  b'\xd0\xa8\xd0\xb5\xd0\xb2\xd1\x80\xd0\xbe\xd0\xbd 4-\xd0\xb9 \xd0\xb3\xd0\xb2\xd0\xb0\xd1\x80\xd0\xb4\xd0\xb5\xd0\xb9\xd1\x81\xd0\xba\xd0\xbe\xd0\xb9 \xd1\x82\xd0\xb0\xd0\xbd\xd0\xba\xd0\xbe\xd0\xb2\xd0\xbe\xd0\xb9 \xd0\xb4\xd0\xb8\xd0\xb2\xd0\xb8\xd0\xb7\xd0\xb8\xd0\xb8.jpg',
#  b'\xd8\xa7\xd8\xb9\xd8\xaf\xd8\xa7\xd9\x85 \xd8\xb9\xd8\xa8\xd8\xaf \xd8\xa7\xd9\x84\xd9\x83\xd8\xb1\xd9\x8a\xd9\x85 \xd9\x82\xd8\xa7\xd8\xb3\xd9\x85 \xd9\x88\xd8\xb5\xd8\xad\xd8\xa8\xd9\x87 \xd9\x81\xd9\x8a \xd8\xaf\xd8\xa7\xd8\xb1 \xd8\xa7\xd9\x84\xd8\xa7\xd8\xb0\xd8\xa7\xd8\xb9\xd8\xa9.jpg',
#  b'\xd8\xa7\xd9\x84\xd8\xaa\xd8\xac\xd9\x85\xd8\xb9_\xd8\xa7\xd9\x84\xd9\x8a\xd9\x85\xd9\x86\xd9\x8a_\xd9\x84\xd9\x84\xd8\xa7\xd8\xb5\xd9\x84\xd8\xa7\xd8\xad.jpg',
#  b'\xd8\xad\xd8\xb2\xd8\xa8_\xd8\xa7\xd9\x84\xd8\xad\xd8\xb1\xd9\x8a\xd8\xa9_\xd9\x88\xd8\xa7\xd9\x84\xd8\xb9\xd8\xaf\xd8\xa7\xd9\x84\xd8\xa9.png',
#  b'\xd8\xb5\xd9\x88\xd8\xb1\xd8\xa9_\xd8\xaf\xd8\xa8\xd8\xa7\xd8\xa8\xd8\xa7\xd8\xaa_\xd8\xa7\xd9\x84\xd8\xa5\xd9\x86\xd9\x82\xd9\x84\xd8\xa7\xd8\xa8\xd9\x8a\xd9\x8a\xd9\x86_\xd8\xa7\xd9\x84\xd8\xb9\xd8\xb3\xd9\x83\xd8\xb1\xd9\x8a\xd9\x8a\xd9\x86_\xd8\xa7\xd9\x84\xd8\xaa\xd8\xb1\xd9\x83\xd9\x8a\xd9\x8a\xd9\x86.jpg',
#  b'\xd9\x85\xd8\xb0\xd9\x8a\xd8\xb9\xd8\xa9_\xd9\x82\xd9\x86\xd8\xa7\xd8\xa9_\xd8\xaa\xd9\x8a_\xd8\xa2\xd8\xb1_\xd8\xaa\xd9\x8a.jpg',
#  b'\xda\xa9\xd9\x88\xd8\xaf\xd8\xaa\xd8\xa7\xda\x86\xdb\x8c\xd8\xa7\xd9\x86.jpg',
#  b'22_\xe0\xb8\x9e\xe0\xb8\xa4\xe0\xb8\xa9\xe0\xb8\xa0\xe0\xb8\xb2\xe0\xb8\x84\xe0\xb8\xa1_2557.png',
#  b'\xe1\x83\xa1\xe1\x83\x90\xe1\x83\x9b\xe1\x83\xae\xe1\x83\x94\xe1\x83\x93\xe1\x83\xa0\xe1\x83\x9d_\xe1\x83\x92\xe1\x83\x90\xe1\x83\x93\xe1\x83\x90\xe1\x83\xa2\xe1\x83\xa0\xe1\x83\x98\xe1\x83\x90\xe1\x83\x9a\xe1\x83\x94\xe1\x83\x91\xe1\x83\x98\xe1\x83\xa1_\xe1\x83\x9b\xe1\x83\xaa\xe1\x83\x93\xe1\x83\x94\xe1\x83\x9a\xe1\x83\x9d\xe1\x83\x91\xe1\x83\x90.png',
#  b'\xe3\x83\x99\xe3\x83\xbc\xe3\x83\xab\xe3\x82\xa4\xe3\x83\x89\xe3\x83\xbc\xe3\x83\xa0.jpg',
#  b'\xe8\x87\xba\xe7\x81\xa3\xe7\xb6\xa0\xe5\xb3\xb6\xe4\xba\xba\xe6\xac\x8a\xe7\xb4\x80\xe5\xbf\xb5\xe7\xa2\x91Monument for Human Rights on Lyudao (GreenIsland) of Taiwan.jpg',
#  b'\xec\x9c\xa4\xec\xb9\x98\xec\x98\x81 1961.jpg',
#  b'\xec\x9e\xa5\xeb\x8f\x84\xec\x98\x81, \xeb\xb0\x95\xec\xa0\x95\xed\x9d\xac 1961\xeb\x85\x84 5.16 \xea\xb5\xb0\xec\x82\xac\xec\xa0\x95\xeb\xb3\x80.jpg',
#  b'\xec\x9e\xa5\xeb\x8f\x84\xec\x98\x81.jpg'}

# %%
set([unicodedata.normalize('NFKC',f).replace('_',' ') for lang,files in lang_images.items() for f in files]) - set(image_tags_dict.keys())
# Out:
# {'"De Historische Strijd" Herdenkingsmonument revolutie 25 februari 1980 - Nieuw-Amsterdam - 20418126 - RCE.jpg',
#  '1 Turkish lira-Deads in 15 July.jpg',
#  '11 septiembre 1976- manifestacion pro Pinochet.jpg',
#  '14 July revolution - mutilated corpse.jpg',
#  '15 July-Erdoğan SMS.jpg',
#  '15 Temmuz Şehitler Parkı tabelası.jpg',
#  '1920UnitedFruitCompanyEntrance.jpg',
#  "1962 Burmese coup d'état.jpg",
#  "1962 Burmese coup d'état2.jpg",
#  '1973Babadinca0048.jpg',
#  '1989 December 16. sugárút és a Tudor Vladimirescu út kereszteződése. Fortepan 31892.jpg',
#  '1989 Iliescu television.jpg',
#  '1991 CPA 6367.jpg',
#  '1991 CPA 6368.jpg',
#  '1991 CPA 6369.jpg',
#  '1991 CPA 6370.jpg',
#  '1991 coup attempt1.jpg',
#  '1991 coup attempt4.jpg',
#  '1991 coup attempt5.jpg',
#  '1991 coup yeltsin.jpg',
#  '1991-August-Moscow.jpg',
#  '1991-Barrikad-BelyDom.jpg',
#  "1992 Venezuelan coup d'état attempts Hugo Chávez speech.jpg",
#  "1992 Venezuelan coup d'état attempts Miraflores.jpg",
#  "1992 Venezuelan coup d'état attempts collage.png",
#  '1993 Rusya anayasa krizi sırasında Parlamento yanlısı göstericiler.jpg',
#  '1993 Tanks before Russian White house.jpg',
#  "2002 Venezuelan coup d'état attempt collage.jpg",
#  "2002 Venezuelan coup d'état attempt uprising.jpg",
#  '2006 09 12 sarkozy 600.jpg',
#  '2006 Thailand Coup 006.jpg',
#  '2006-06-22 12-36-38 Seychelles Cascade Cascade.jpg',
#  '2009 Honduran demonstration against Zelaya and Chavez 1.jpg',
#  '2009 Honduras political crisis 11.jpg',
#  '2009 Honduras political crisis 2.jpg',
#  '2009 Honduras political crisis 3.jpg',
#  '2009 Honduras political crisis 4.jpg',
#  '2009 Honduras political crisis 5.jpg',
#  '2009 Honduras political crisis 9.jpg',
#  '2013 Taksim Gezi Park protests (15th June).jpg',
#  '2014 0526 Thailand coup Chang Phueak Gate Chiang Mai 01.jpg',
#  '2014 0526 Thailand coup Chang Phueak Gate Chiang Mai 02.jpg',
#  '2014 0526 Thailand coup Chang Phueak Gate Chiang Mai 03.jpg',
#  '2014 0527 Thailand coup Thaphae Gate.jpg',
#  '2014 Suchum, Siedziba rządu i prezydenta Republiki Abchazji (04).jpg',
#  '2014-02-02 Silom protest site 01.jpg',
#  '2015 Asia Pacific Parliamentary Forum (1).jpg',
#  '2016 Türkiye Darbe Girişimi - Ankara.jpg',
#  "20th anniversary of 1953 Iranian coup d'état.jpg",
#  '21438 010.jpg',
#  '24 жніўня 1991.jpg',
#  '24. Rupturas al cese al fuego.png',
#  '247783721 10e33ed8c9 o.jpg',
#  '25 Abril 1983 Porto by Henrique Matos 01.jpg',
#  '25 de Abril sempre Henrique Matos.jpg',
#  '27 Mayıs Darbesi sembolü.png',
#  '28Amordad1332 Toopkhaneh.jpg',
#  '28mordad1332.jpg',
#  '34-o Aniversário Revolução dos Cravos, Lisboa.jpg',
#  '4 Ekim 1993 Rusya Parlamento binası alevler içinde.jpg',
#  '4.19 혁명.jpg',
#  '4TD4-500x250.jpg',
#  '5.16 Coup Park Chung-hee.jpg',
#  '5011-0004-reverse.png',
#  '59mossadeghprime minister1951.jpg',
#  '757landing-toncontin.jpg',
#  'A. Pinochet Stamp.jpg',
#  'ABI100 KingFerdinandMuseum.jpg',
#  'AIOC741330.jpg',
#  'AUT Hadersdorf-Kammern COA.jpg',
#  'Abadanraffinerie.jpg',
#  'Abd al-Karim death.jpg',
#  'Abd al-Wahab Shawaf.png',
#  'Abdul Fatah Khalil Al-Sisi 2013-03-03.jpg',
#  'Abdul Rahman Arif.jpg',
#  'Abdul-salam-arif.jpg',
#  'Abolghasem Kashani.jpg',
#  'Ad-Duri.jpg',
#  'Adib al-Shishakli.jpg',
#  'Adnan Menderes VI. Yasama Dönemi.jpg',
#  'Africa satellite orthographic.jpg',
#  'After burning the Muslim brotherhood stage in front of the mosque.jpg',
#  'After coup nightly demonstartion of president Erdogan supporters. Istanbul, Turkey, Eastern Europe and Western Asia. 22 July,2016.jpg',
#  'Ahmad Hassan el Bakr.jpg',
#  'AhmadGhavam2.jpg',
#  'Ahmed el-Tayeb May 2015 (17963337671).jpg',
#  'Air Commodore Kaiser Tufail receiving a memento from Commander of the Turkish Air Force General Akin Ozturk (cropped).jpg',
#  'Air Commodore Kaiser Tufail receiving a memento from Commander of the Turkish Air Force General Akin Ozturk.jpg',
#  'Al Fujimori.jpg',
#  'Alatoo.jpg',
#  'Alegria rafael.jpg',
#  'Alejandro Agustín Lanusse.jpg',
#  'Alexander Ankvab - 06.10.2011.jpg',
#  'Algiers putsch 1961.jpg',
#  'Ali salih.jpg',
#  'Alix Pasquet.jpg',
#  'Allen w dulles.jpg',
#  'Allende son.jpg',
#  'Allende supporters.jpg',
#  'Allende.jpg',
#  'Alte. Carlos G. N. Coda.jpg',
#  'Alte. Pedro Gnavi.jpg',
#  'Amadou Toumani Touré 30 November 2011.jpg',
#  'Amadou Toumani Touré 30 नवम्बर 2011.jpg',
#  'AmauryKruel.jpg',
#  'Angkor Wat W-Seite.jpg',
#  'AngkorWat Delaporte1880.jpg',
#  'Anti Morsi protest march at 28th June 2013.jpg',
#  'Anti coup Mauritania.jpg',
#  'Anti-Coup Demokrasi Nöbeti Kızılay Square.jpg',
#  'Anti-Morsi poster in a car.jpg',
#  'Anti-Morsi protester june 2013.jpg',
#  'Anti-Morsi protests June 2013 in Egypt.jpg',
#  'Anti-coup sit-in at Rabaa Adiweya mosque 2013.jpg',
#  'António de Oliveira Salazar, drawing.jpg',
#  'Apollo 11.jpg',
#  'Araya-Allende.jpg',
#  'Aref abderazak.jpg',
#  'Aref with Qasim.png',
#  'Arif.jpg',
#  'Arms of Fiji 2.png',
#  'Arturo Illia.jpg',
#  'Asia map.jpg',
#  'Askar Akaev MoscowRia 08-2016.jpg',
#  'Askar Akayev.jpg',
#  'Assad Tlass war 1973.jpg',
#  'AssaltonaMatadaSanga....jpg',
#  'Assemblee Nationale Burkina Faso.jpg',
#  'August 1991 Kalininski prospect.jpg',
#  'Augusto Pinochet - 1995.jpg',
#  'Augusto Pinochet 1986.jpg',
#  'Augusto Pinochet foto oficial.jpg',
#  'Augusto Pinochet.jpg',
#  'Awqati1.jpg',
#  'Ayatmohagheghi.jpg',
#  'BBC Asian Network Studio The Mailbox Birmingham 20041228.jpg',
#  'BKK21090604.jpg',
#  'BKK22090601.jpg',
#  'BKK24090601.jpg',
#  'BKK24090602.jpg',
#  'BKK24090603.jpg',
#  'BKK24090612.jpg',
#  'BKK24090613.jpg',
#  'BKK24090615.jpg',
#  'BKK24090616.jpg',
#  'BKK24090618.jpg',
#  'BP200906-2.jpg',
#  'BTR 25 april.jpg',
#  'Baath National Command.jpg',
#  'Baath Party founder Michel Aflaq with Iraqi President Ahmad Hasan al-Bakr in Baghdad in 1968.jpg',
#  'Bakkir.jpg',
#  'Bakr.jpg',
#  'Bangkokplaces.png',
#  'Barack Obama at Cairo University cropped.jpg',
#  'Barzani & Qasim.jpg',
#  'Bashar al-Assad (cropped).jpg',
#  'BenzinBon-1.jpg',
#  'Binali Yıldırım headshot.jpg',
#  'Blaise Compaoré 2014 White House.png',
#  'Blargos1.jpg',
#  'Blok wschodni pl.png',
#  'Boeing 727-2B6, Royal Air Maroc - RAM AN1217763.jpg',
#  'Bokassa portrait.jpg',
#  'Bophuthatswana coup Execution.jpg',
#  'Boris Yeltsin 19 August 1991-1.jpg',
#  'Boris Yeltsin 1993.jpg',
#  'Boris Yeltsin 21 February 1989-1.jpg',
#  'Boris Yeltsin 22 August 1991-1.jpg',
#  'Boris Yeltsin-2.jpg',
#  'Boğazın tek yönlü kapatılması.png',
#  'Bucur Obor (1986).jpg',
#  'BuiQuangThan.jpg',
#  'Bundesarchiv B 145 Bild-F013047-0040, München, Staatsbesuch Präsident von Zypern.jpg',
#  'Bundesarchiv Bild 183-1989-1120-036, Berlin, Schweigemarsch für Rumänien.jpg',
#  'Bundesarchiv Bild 183-1989-1215-038, Berlin, Demonstration für Rumänien.jpg',
#  'Bundesarchiv Bild 183-1989-1220-032, Berlin, Demonstration für Rumänien, Mahnwache.jpg',
#  'Bundesarchiv Bild 183-1989-1221-032, Berlin, Demonstration für Rumänien.jpg',
#  'Bundesarchiv Bild 183-1989-1223-006, Berlin, Brandenburger Tor, Transparte zu Rumänien.jpg',
#  'Bundesarchiv Bild 183-55823-0005, Berlin, Karl-Marx-Allee, "Deutsche Sporthalle".jpg',
#  'Burkina Faso Protests.png',
#  'Burkina Faso carte.png',
#  'Burkinabe Col. Gilbert Diendéré, 2010.jpg',
#  'Burkinabé uprising at Place de la Nation.jpg',
#  'Burnt out buildings on nothern edge of Revolution Square, Bucharest.jpg',
#  'Bush Gorba P15623-25A.jpg',
#  'By-map.png',
#  'Bülent Ecevit Cropped.jpg',
#  'CFSN Revolution Roumaine.jpg',
#  'Cairo pro-Mursi-protests July-August 2013 ARAB2.jpg',
#  'CamGen.jpg',
#  'Car of history.jpg',
#  'Cardinal Jaime Sin in 1988.jpg',
#  'Carlos Gomes Junior.jpg',
#  'Carte gabon.png',
#  'Castelo de Guimarães (Portugal).jpg',
#  'Castelobranco.jpg',
#  'Ceausescu, Nicolae.jpg',
#  'Central african republic sm04.png',
#  'Central african republic sm04ESP.jpg',
#  'Centro SB.jpg',
#  'Chan o cha Portrait.jpg',
#  'Chancery.jpg',
#  "Chang Myon 194804'.png",
#  'Chavez başarısız darbeden sonra göreve dönerken 13 Nisan 2002.jpg',
#  'Chavez-WSF2005.jpg',
#  'ChenGuatemala.jpg',
#  'Chest badge Guards Russian Federation.png',
#  'Chile - Palácio de La Moneda - by Sérgio Schmiegelow.jpg',
#  'Chile Junta001.jpg',
#  'Chile- el pueblo vencera cropped.jpg',
#  'Choi Kyu Ha.png',
#  'Civilian with PM Md. 1963 during the Romanian Revolution of 1989.jpg',
#  'Color Revolutions Map.png',
#  'Colosseum-2003-07-09.jpg',
#  'CongressBuilding SEATO.jpg',
#  'Conmemoración 40 años Museo de la Memoria 2.jpg',
#  'Conmemoración de 40 años del Golpe Militar 1.jpg',
#  'Corazon Aquino 1986.jpg',
#  'Corazon Aquino inauguration.jpg',
#  'Cordobazo.jpg',
#  'Coruche mural 25 Abril.jpg',
#  'Cory Aquino during a ceremony honoring US Air Force.jpg',
#  "Coup-d'etat-11-web-cnni.jpg",
#  "Coup-d'etat-14-web-cnni.jpg",
#  "Coup-d'etat-15-web-cnni.jpg",
#  "Coup-d'etat-17.jpg",
#  "Coup-d'etat-2-web-cnni.jpg",
#  "Coup-d'etat-24-web-cnni.jpg",
#  "Coup-d'etat-3-web-cnni.jpg",
#  "Coup-d'etat-5-web-cnni.jpg",
#  "Coup-d'etat-6-web-cnni.jpg",
#  "Coup-d'etat-9-web-cnni.jpg",
#  'CriseConstitucionalRussaDe1993.png',
#  'Cristina y Patricia Rodas.jpg',
#  'Crop-Nicolae Ceaucescu 1978.jpg',
#  'Curfew08142013.png',
#  'DF-SC-83-08526.jpg',
#  'DYazov1989.jpg',
#  'Damietta protests.jpg',
#  'Darbe karşıtı protesto Tokat.jpg',
#  'David Ben Gurion - General Ne Win PM of Burma 1959.jpg',
#  'David Dacko 1962 crop.jpg',
#  'David Haba Guinean army 2005-199.jpg',
#  'Day after Saur revolution in Kabul (773).jpg',
#  'De Gaulle-OWI.jpg',
#  'Dead No Coup 2016.jpg',
#  'Dead bodies in RABIA Massacre (3).jpg',
#  'Defence.jpg',
#  'Defense.gov News Photo 040304-F-2828D-065.jpg',
#  'Desi Bouterse.jpg',
#  'Diem dead.jpg',
#  'Dinh doc lap bi doi bom.jpg',
#  'Dioncounda Traore photo officielle de campagne 3 Mali 2012.jpg',
#  'Division20.jpg',
#  'Dzerzhinsky Statue, which once dominated Lyubianka Square.jpg',
#  'E preciso salvar Abril Henrique Matos.jpg',
#  'EB Haiti.jpg',
#  'EDSA People Power historical marker.jpg',
#  'EDSA Revolution pic1.jpg',
#  'Edmond Jouhaud 1961.jpg',
#  'Egyptian Minister of Defense Abdel Fatah Al Sisi.jpg',
#  'El Tres de Mayo, by Francisco de Goya, from Prado in Google Earth.jpg',
#  'El presidente Rafael Correa escoltado en el 30S.jpg',
#  'ElBaradei 030110.jpg',
#  'Elena Ceausescu portrait.jpg',
#  'Erdoğan, 2012 (cropped).jpg',
#  'Estadio nacional-Chile.jpg',
#  'Eugène Delacroix - La liberté guidant le peuple.jpg',
#  'Evstafiev-Valentin Varennikov 11AUG94.jpg',
#  'Evstafiev-alexander-rutskoy-w.jpg',
#  'Ex General Efrain Rios Montt testifying during the trial.jpg',
#  'FETO attack EGM Building.jpg',
#  'FJP.png',
#  'FUA manifestación 70s-2.jpg',
#  'Faisal 4.jpg',
#  'Faisal hussein.jpg',
#  'Fatin Rüştü Zorlu.jpg',
#  'Fazlollah zahedi.jpg',
#  'Ferdinand & Imelda Marcos in Leyte 1984-10-20.jpg',
#  'Fethullah Army EGM attack.jpg',
#  'Fethullah Gülen 2016.jpg',
#  'Fethullah Gülen cropped (cropped) (cropped).jpg',
#  'Fethullah Gülen cropped (cropped).jpg',
#  'Fethullah Gülen cropped.jpg',
#  'Fijitimes-120706.jpg',
#  'File',
#  'Fireworks at Anti-Morsi protests.jpg',
#  'First Majlis MPs.jpg',
#  'Francisco-Macias-Nguema personality cult photo.jpg',
#  'Francois Duvalier during 1958 coup attempt.jpg',
#  'Frank Bainimarama September 2014.jpg',
#  'Freedom and Justice Party (Egypt).jpg',
#  'Gabinete allende 2 1024.jpg',
#  'Gailani.jpg',
#  'Gandhi Salt March.jpg',
#  'Gaziosmanpaşa meydanı protesto.jpg',
#  'Gebze Square No Coup protests.jpg',
#  'Gen William C Westmoreland.jpg',
#  'General Al Sisi.jpg',
#  'General Al-Sisi, announcing the removal of President Morsi.png',
#  'General Hafez al-Assad in 1970, during the Syrian Corrective Revolution.jpg',
#  'General Salah Jadid.jpg',
#  'General Shamim Alam Khan receiving the Hilal-i-Imtiaz.jpg',
#  'General el Sisi Mursiyi görevden alındığını açıklarken.png',
#  'Genesis FUBELT.jpg',
#  'George H. W. Bush and Boris Yeltsin 1993.jpg',
#  'Germame Neway.jpg',
#  'Gloria Macapagal Arroyo.jpg',
#  'Gloria Macapagal-Arroyo, Davos.jpg',
#  'Gloriosa victoria.jpg',
#  'Gnassingbe Eyadema detail1 DF-SC-84-10025.jpg',
#  'Golpe Estado Tailandia.jpg',
#  'Golpe de 1964.jpg',
#  'Golpe de Estado 1973.jpg',
#  'Goulartcentral.jpg',
#  'Grave of Nicolae Ceausescu - Ghencea Civil Cemetery - Bucharest - Romania.jpg',
#  'Guanabarasandbag.jpg',
#  'Guatemala-CIA WFB Map.png',
#  'Guinea Bissaus interim President Raimundo Pereira (cropped).jpg',
#  'Guinea bissau sm03.png',
#  'GulagulLaRomani.jpg',
#  "Général de corps d'armée Salou Djibo.jpg",
#  'H.E. Mr. Mothetjoa Metsing, Deputy Prime Minister, Kingdom of Lesotho (8008839925) (cropped).jpg',
#  'HN999sRamon 2obreros-.jpg',
#  'Habs un headquarters.jpg',
#  'Hakar (28338755964).jpg',
#  'Hameed.png',
#  'Harold Wilson Number 10 official.jpg',
#  'Hasan Polatkan.jpg',
#  "Hashem al Atta, 1971 Sudanese coup d'état.jpg",
#  "Hashem al Atta, Khalid Hassan Abbas, 1971 Sudanese coup d'état.jpg",
#  'Hastear da bandeira da Guiné Bissau após o arrear da de Portugal.jpg',
#  'Hazem Beblawy.jpg',
#  'Hazim jiwad.jpg',
#  'Henry Kissinger.png',
#  'Heo Jeong.png',
#  'Hiillary Clinton and Manuel Zelaya.jpg',
#  'Honduras golpe protesta.jpg',
#  'Horace Vernet-Barricade rue Soufflot.jpg',
#  'Hossein Fatemi Body.jpg',
#  'HosseinFatemi2.jpg',
#  'Hugo Chavez in Guatemala.jpg',
#  'Hugo Chávez (02-04-2010).jpg',
#  'Hulusi Akar (cropped version).jpg',
#  'Hulusi Akar (cropped).jpg',
#  'Hémicycle 2 Palais Bourbon scropped and smaller.jpg',
#  'Ikhwan-logo.jpg',
#  'Iliescu si Bush.jpg',
#  'Image0 ST.jpg',
#  'Inonu Ismet.jpg',
#  'Insigne Romanicum II.png',
#  'Iran NF.jpg',
#  'Iraq, Saddam Hussein (222).jpg',
#  'Iraq14.jpg',
#  'Iskander Mirza.jpg',
#  'Istanbul -Hürriyet- 2000 by RaBoe 02.jpg',
#  'Istor portal.png',
#  'Ivato Intl Airport Antananarivo Madagascar.jpg',
#  'Ja3far askari.jpg',
#  'Janio Quadros.png',
#  'Jassem Alwan.jpg',
#  'Jean Ping 080202-F-1644L-081 0YWDF.jpg',
#  'Joao IV proclaimed king.jpg',
#  'Joe baxter.jpg',
#  'John L Throckmorton.jpg',
#  'Jorge Videla 1976.jpg',
#  'Joseph estrada 2000.jpg',
#  'José Afonso by Henrique Matos 001.jpg',
#  'José Toribio Merino Castro cropped.jpg',
#  'João Goulart NYWTS.jpg',
#  'João Goulart nos Estados Unidos em 1962.jpg',
#  'Juan Maria Bordaberry.jpg',
#  'July1.jpg',
#  'Juntagobierno1944.jpg',
#  'Juntagovernativa1969.png',
#  'KYK 15 Temmuz sergisi.jpg',
#  'Kairo Pro-Mursi-Proteste Juli-August 2013.jpg',
#  'Karim01 small.jpg',
#  'Kennedy and Goulart review troops 1962.jpg',
#  'King CDRM L.jpg',
#  'King Hassan II.jpg',
#  'Kingdom of Fez.jpg',
#  'Kirgizija.jpg',
#  'Kongress in valparaiso.jpg',
#  'Konstitucionālais likums Par Latvijas Republikas valstisko statusu.jpg',
#  'Kurmanbek Bakiyev.jpg',
#  'Kızılay - democracy and tanks.png',
#  'LBJ nhu.jpg',
#  'LRAP un MP 1991. gada 19. augusta paziņojums.jpg',
#  'La Mano memory 40 years Chile dictatorship 1.jpg',
#  'Lansana Conte 27 July 2001a.jpg',
#  'Last day qasim.jpg',
#  'Lbj mnhu.jpg',
#  'Ldpr.png',
#  'Leaders of July 14 1958 Revolution.jpg',
#  'Lechfeld Elite 2008 144 (2663713634).jpg',
#  'Lee Han-lim.jpg',
#  'Les alliés dal-Qaida détruisent un tombeau sacré à Tombouctou (8142142738).jpg',
#  'Lisboa Monumento 25 Abril.jpg',
#  'Lissabon 25 april.jpg',
#  'Location of Abkhazia in Europe2.png',
#  'LocationKyrgyzstan.png',
#  'LocationPortugal.png',
#  'Logo for Liberal Democratic Party of Russia.png',
#  'Lon Nol, Sisowath Sirik Matak, In Tam.jpg',
#  'LonNol.jpg',
#  'Lt-map.png',
#  'Lucio Gutiérrez.jpg',
#  "Léon M'ba 1964.jpg",
#  'MBKTürkeş.jpg',
#  'Madame Ngô Đình Nhu and Lyndon Baines Johnson.jpg',
#  'Maflaq.jpg',
#  'Mahamadou Issoufou VOA 150 4dec04.jpg',
#  'Major-general-lansdale.jpg',
#  'Makarios III and Robert F. Wagner NYWTS cropped.jpg',
#  'Malian Soldiers.jpg',
#  'Manifest revolutie 1989.jpg',
#  'Manifestation à Nouadhibou-2008.jpg',
#  'Manuel Zelaya detail, ABR August 07, 2007.jpg',
#  'Mao Sihanouk.jpg',
#  'Marcello caetano.jpg',
#  'Marche sel.jpg',
#  'Marcos visit Reagan 1982.jpg',
#  'Maria Corina Machado (Sumate) meets George W. Bush (2002).jpg',
#  'Mariinsky Palace Saint Petersburg.jpg',
#  'Masacre de Ezeiza - persona subiendo al palco.jpg',
#  'Maslak 15 July Occupy residential.jpg',
#  'Mass on the street 1989.jpg',
#  'Mauritania gov ould taya 210 eng 30apr05.jpg',
#  "Mauritanie-Coup d'Etat 2008.jpg",
#  'Maxwell D Taylor official portrait.jpg',
#  'May 16th Coup dEtat (1961) 5.16 군사혁명 (5591601384).jpg',
#  "Mayıs 1981 Kenan Evren Ankaragücü kaptanı Adil Eriç'e Türkiye Kupası'nı veriyor.jpg",
#  'Md2002 kramar.jpg',
#  'Mengistu & Merid.jpg',
#  'Mengistu Neway.jpg',
#  'Mengistu and germame Neway.jpg',
#  'Mercator Africa 037.jpg',
#  'Mhdawi.jpg',
#  'MichaelKafando.jpg',
#  'Michel Aflaq and Salah Jadid in 1963.jpg',
#  'Military Committee celebrates 1963 coup.jpg',
#  'Mohamad Reza Shah Pahlavi in hospital 1949 jpeg.jpg',
#  'Mohamed Morsi-05-2013.jpg',
#  'Mohammad Mosaddeq, Ahmadabad 1965.jpg',
#  'Mohammad-reza-shah.jpg',
#  'MohammadMossadeqAdibBoroumand.jpg',
#  'Morande 80 11 septiembre 2009.jpg',
#  'Moroccan Air Force.png',
#  'Morsi supporter after mass killings of 27-July-2013.jpg',
#  "Morsi's ouster celebrations Tahrir 20130707-4.jpg",
#  'Mosaddegh Kashani123.jpg',
#  'Mossadeghmohammad.jpg',
#  'Mossadeghmohammadrezashah.jpg',
#  'Muammar al-Gaddafi 1-1.jpg',
#  'Muhammad Zia-ul-Haq 1982.jpg',
#  'Muhammad al-Rubaiai.jpg',
#  'Mural2.jpg',
#  'MuricyMourao.jpg',
#  'Museo Aeronáutico 2.jpg',
#  'Mustafa Kemal Atatürk.jpg',
#  'Mwambutsa 1962.jpg',
#  'Naguib.jpg',
#  'Nasser Gaddafi 1969.jpg',
#  'Nasser Qaddafi Atassi 1969.jpg',
#  'Nasser, al-Bakr and Atassi, 1963.jpg',
#  'National Revolutionary Command Council (Sudan).jpg',
#  'Naval Battle of Navarino by Garneray.jpg',
#  'Newsweek 22 Eylül 1980 kapak.jpg',
#  'Ngo Dinh Diem - Thumbnail - ARC 542189.png',
#  'Nguyen Cao Ky.jpg',
#  'Nguyen Van Thieu with map (cropped).jpg',
#  'Nguyễn Khánh 1964.jpg',
#  'Nhà thờ Cha Tam.jpg',
#  'Nicolae Ceaucescu 1978.jpg',
#  'Nicolae Ceausescu.jpg',
#  'Nicolae Ceaușescu Mormant.jpg',
#  'Niger mk.jpg',
#  'Ninoy Aquino\'s "Testament from Prison Cell" signed by Cory Aquino in 1983.jpg',
#  'Niwatthamrong Boonsongpaisan at Ministerial Conference 2013 crop.jpg',
#  'Nixon 30-0316a.jpg',
#  'Nochavezortega.jpg',
#  'Northrop F-5B (SN 63-8438, the first production -B model) 060905-F-1234S-005.jpg',
#  'Northrop F-5E (Tail No. 11419) (cropped).jpg',
#  'Northrop YF-5A (SN 59-4987) with a full load of bombs 060905-F-1234S-002.jpg',
#  'Nouakchott-mosquee.jpg',
#  'Nuamthong.jpg',
#  'Obama meets with coalition Chiefs of Defense 141014-D-KC128-186.jpg',
#  'Omar Bongo crop.jpg',
#  'Onganía-Levingston-Lanusse (Revolución Argentina).jpg',
#  'Operacio marverde.jpg',
#  'Operationajax.jpg',
#  'Operação Vagô - memorial no Cemitério dos Prazeres.jpg',
#  'Order of Saur Revolution1979.jpg',
#  'Order of the Red Banner.png',
#  'Otelo.jpg',
#  'Oubangui-Chari.jpg',
#  'P Russia.png',
#  'P history.png',
#  'P technology.png',
#  'PAIGC posto de controlo.jpg',
#  'PSRS Valsts padomes lēmums par Latvijas Republikas neatkarības atzīšanu.jpg',
#  'Palacio Carondelet en la noche.jpg',
#  'Palacio Nacional de la Cultura.jpg',
#  'Palacio de La Moneda.png',
#  'Park Chung hee.jpg',
#  'Park Chung-hee, 1961-August-21.jpg',
#  'Parlamentspalast in Bukarest.jpg',
#  'Pedro Carmona 2002 darbesinden sonra yemin töreninde.jpg',
#  'People Power Revolution commemorative 10-peso coin obverse and reverse.png',
#  'Pepe Lobo 2010-01-27.jpg',
#  'Pervez Musharraf 2004.jpg',
#  'PervezMusharraf.jpg',
#  'Philippine History Collage.jpg',
#  'Php bill 200 back.jpg',
#  'Picture 032.jpg',
#  'Pinochet en 1974.jpg',
#  'Pisagua3.jpg',
#  'PithHelmetTruman.jpg',
#  'Plevne Marşı pul.jpg',
#  'Ponte25Abril1.jpg',
#  'Port-au-Prince med.jpg',
#  'Portail Armée française.png',
#  'Portrait Habib Bourguiba.jpg',
#  'Portrait officiel Bourguiba.png',
#  'Portugallia et Algarbia.jpg',
#  'Povo mfa.jpg',
#  'PozeRevolutia1989clujByRazvanRotta02.jpg',
#  'PozeRevolutia1989clujByRazvanRotta13.jpg',
#  'Prayuth Jan-ocha 2010-06-17 Cropped.jpg',
#  'Praça 25 de Abril.jpg',
#  'President Abd al-Salam Arif.jpg',
#  'President Barack Obama meets with members of his national security team, including Defense Secretary Chuck Hagel, to discuss the situation in Egypt, in the Situation Room of the White House, July 3, 2013.jpg',
#  'President Direct Election Movement Ming-te Shih Yi-hsiung Lin and Hsin-liang Hsu.jpg',
#  'President Eisenhower and John Foster Dulles in 1956.jpg',
#  'President Nguyen Van Thieu.jpg',
#  'President Obama on the phone in the Oval Office with Secretary Kerry regarding the situation in Turkey (27716300004).jpg',
#  'President Obiang.jpg',
#  'President of Kyrgyzstan, Kurmanbek Bakiyev crop.jpg',
#  'Presidential Standard of South Vietnam (1955-1963).png',
#  'Prime Minister of Turkey Recep Tayyip Erdogan cropped.jpg',
#  'PrimeMinisterNawazSharif.jpg',
#  'Project 571 Outline.jpg',
#  'Propaganda del govierno en años posteriores.jpg',
#  'Propaganda poster Ceausescu.jpg',
#  'Protestors issues Morsi a red card..jpg',
#  'Protests No Coup 2016.jpg',
#  'Protests in Egypt January 2013.jpg',
#  'Puente LLaguno.jpg',
#  'Qasim arif.jpg',
#  'Qasim2.jpg',
#  'Quema de libros.jpg',
#  'Quetzaltenango farm highlands 2009.jpg',
#  'R4bia sign used in solidarity with victims of Rabaa crackdown 23-Aug-2013.jpg',
#  'RIAN archive 848095 Signing the Agreement to eliminate the USSR and establish the Commonwealth of Independent States.jpg',
#  'RO B University square rally.jpg',
#  'Rabaa al-Adawiya.png',
#  'Rafael Correa presidenciagovar 15ENE07.jpg',
#  'Rafaelcorrea08122006.jpg',
#  'Rafiq1.jpg',
#  'RafiqArif.jpg',
#  'Rama IX on his Throne.jpg',
#  'RangoonStreetView.jpg',
#  "Rapport droits de l'homme 1989 01.jpg",
#  'Reagan and Gorbachev signing.jpg',
#  'Recep Tayyip Erdoğan.jpg',
#  'RecepTayyipErdoğan (cropped).jpg',
#  'Reform the Armed Forces Movement logo circa 1990s.png',
#  'Regimiento Tacna No1.jpg',
#  'Revolutie-strada-multime.jpg',
#  'Reza Pahlavi I.jpg',
#  'RichardNixon.jpg',
#  'Rifle AKS MON.jpg',
#  'Rikabi.jpg',
#  'Roberto micheletti 01.jpg',
#  'Rodrigo de Rato y Figaredo.jpg',
#  'Romania, Transylvania, Timisoara Fortepan 31879.jpg',
#  'Romanian Revlution 1989 2.jpg',
#  'Romanian Revolution 1989 1.jpg',
#  'Romanian Revolution 1989 4.jpg',
#  'Romanian Revolution 1989 5.jpg',
#  'Romanian Revolution 1989 Corpses.jpg',
#  'Romanian Revolution 1989 Demonstrators.jpg',
#  'Romanian Revolution 1989 WeWillWin.jpg',
#  'Romanian ration-card for bread, 1989.jpg',
#  'Román Nemzeti Színház és Operaház, T-55 harckocsi. Romániai forradalom. Fortepan 31905.jpg',
#  'Royal Palace, Rabat.jpg',
#  'Rumo a liberdade Henrique Matos.jpg',
#  'Russian Congressional Fractions 1992.png',
#  'Russian Congressional Fractions 1993.png',
#  'SD visits Turkey 1000w q95.jpg',
#  'Saadi.jpg',
#  'Salah Bitar.jpg',
#  'Salammq.png',
#  'Sallama.png',
#  'Salvador Alyendenin son foto şəkili.jpg',
#  'Samuel K. Doe During the 1980 Coup.png',
#  'San Carlos military stockade - Venezuela.jpg',
#  'Satellite image of Cyprus, cropped.jpg',
#  'Secalbright.jpg',
#  'Secretary Kerry Bids Farewell To Egyptian Minister of Defense General al-Sisi.jpg',
#  'Secretary Kerry and Pakistani Advisor Aziz Address Reporters.jpg',
#  'Secretary of Defense Chuck Hagel meets with Egyptian President Mohamed Morsy in Cairo, Egypt, April 24, 2013.jpg',
#  'Sekou Toure usgov-83-08641.jpg',
#  'Selassie restored.jpg',
#  'Sempreatentos...aoperigo!.jpg',
#  'Senior officials in the Baath Party in a rare un-official photograph with Salah Jadid from 1969.jpg',
#  'Separate division operational use.jpg',
#  'Serie Portugal, verkiezingsstrijd in Lissabon (begin 1975); straatbeelden met verkiezingsaffiches.jpg',
#  'Set20060921.jpg',
#  'Shaabanbimokh.jpg',
#  'ShahSorayaPM.jpg',
#  'Shahanshah1333.jpg',
#  'Shield of the Kingdom of Portugal (1481-1910).png',
#  'Siam Paragon Bangkok 1.jpg',
#  'Sibiu - Piata Mare - 1989 memorial.jpg',
#  'Sidi Mohamed Ould Cheikh Abdallahi.jpg',
#  'Silk-film.png',
#  'Siri3.jpg',
#  'Soldados en la calle Chile-1973.png',
#  'Soldier in Tahrir.jpg',
#  'Soviet Guards badge.png',
#  'Soviet Union Administrative Divisions 1989.jpg',
#  'Sputnik asm.jpg',
#  'Stamp Fiji 1959 2 6 Nadi Airport.jpg',
#  'Stamp Salvador Allende.jpg',
#  'Stamp of Afghanistan (1979) - Saur Revolution.jpg',
#  'Statul Major General.jpg',
#  'Stema Statului Major al Fortelor Terestre.jpg',
#  'Strait of gibraltar-rightee.jpg',
#  'Supreme Court of Pakistan,Islamabad by Usman Ghani.jpg',
#  'Supreme Soviet of Russia meeting (1993).png',
#  'Sylvanus Olympio.jpg',
#  'Syria.BasharAlAssad.02.jpg',
#  'Syrian Baath Logo.jpg',
#  'Syrien 1961 0003.jpg',
#  'T-72 tank in Moscow, August 1991.jpg',
#  'TBMM coup attempt 15 June 2016.png',
#  'TPAjax.jpg',
#  'TRT Ankara.jpg',
#  'Tabaqchali1.jpg',
#  'Taher yahya.jpg',
#  'Tahrir Square on November 27 2012 (Morning).jpg',
#  'Taman.png',
#  'Tandja in Nigeria June 2007.jpg',
#  'Tanks approach the Ataturk airport.jpg',
#  'Tanks before Russian White house.jpg',
#  'Tanques Venezuela 1958.jpg',
#  'Tawadros II of Alexandria.jpg',
#  'Teniente General(R)PistariniPascual.jpg',
#  'Tentativa de golpe de Estado na Turquia.jpg',
#  'Thai coup soldier.jpg',
#  'Thai-coup-detat-2014-social-media-banner.jpg',
#  'Thailand Army(9-24-2006).jpg',
#  'Thailand Ministry of Information and Communication Technology 2014 Censorship Image.jpg',
#  'Thaksin crop.jpg',
#  'Thaksin.jpg',
#  'The Bangkok Post, September 20, 2006.jpg',
#  'The Four Voyages of Columbus 1492-1503 - Project Gutenberg etext 18571.jpg',
#  'The nation 200506.jpg',
#  'The philosopher Zaki al-Arsuzi.jpg',
#  'Thi and thieu.jpg',
#  'TimbruNicolaeCeausescu.png',
#  'TimbruRevolutie.png',
#  'TimisoaraCatedrala.jpg',
#  'Togoland.png',
#  'Tokat darbe karşıtları.png',
#  'Tom Thabane cropped.jpg',
#  'Tom Thabane.jpg',
#  'Toure-folklife.jpg',
#  'Toure-folklife2.jpg',
#  'Translation2.png',
#  'Trial iraq.jpg',
#  'Truman initiating Korean involvement.jpg',
#  'Tsn-1962.jpg',
#  'Tte.Gral. (R) J. Videla.jpg',
#  'Tulip 2.jpg',
#  'Tulip.jpg',
#  'Turcja, 15-16.07.2016r. Próba zamachu.png',
#  'Turgut Özal cropped.jpg',
#  'Turkey - Air Force Lockheed C-130E Hercules Bakema.jpg',
#  'Turkey topo.jpg',
#  'Turkish CoastMAK.png',
#  'Turkish protesters in Istanbul.jpg',
#  'TőkésL.jpg',
#  'US Air Force C-22B (727-100).jpg',
#  'US Marine charges through Japanese machine gun fire on Okinawa.jpg',
#  'USS Jesse L. Brown (FF-1089) off Maine.jpg',
#  'UXP Unidad Popular.png',
#  'Un-guatemala.png',
#  'Un-pakistan.png',
#  'Unasur BsAs Crisis Ecuador.jpg',
#  'Unidad Popular 1973.png',
#  'V. Landsbergis. Viešoji informacija.jpg',
#  'Videla Sociedad Rural.jpg',
#  'Viennese Illuminated Chronicle Posada.jpg',
#  'Vista-kmixdocked.png',
#  'Viva a liberdade Henrique Matos.jpg',
#  'Vladimir Putin and Recep Tayyip Erdoğan (2015-06-13) 3.jpg',
#  'Vympel special forces.png',
#  'W.gl.GolpeEstadoIran1953.png',
#  'Watanyin.jpg',
#  'Weeks featured article.png',
#  'WikiLettera.png',
#  "William Knox D'Arcy.jpg",
#  'Won Democracy Turkey.jpg',
#  'World Factbook (1982) Seychelles.jpg',
#  'Yalta summit 1945 with Churchill, Roosevelt, Stalin.jpg',
#  'Yameogo stamp 1960.png',
#  'Yanaon.jpg',
#  'Yankee go home graffiti.png',
#  'Yeltsin 1993 cropped.jpg',
#  'Yun Bo1.jpg',
#  'Zahedifirman.jpg',
#  'Zelaya con sombrero.jpg',
#  'Zelaya in Brazil.jpg',
#  'Zine El Abidine Ben Ali cropped.jpg',
#  'Zine El Abidine Ben Ali.jpg',
#  'Zulfikar Ali Bhutto.jpg',
#  'Álvaro Cunhal Henrique Matos 02.jpg',
#  'Óscar Arias (2009).jpg',
#  'Ülkü Ocakları Eğitim ve Kültür Vakfı Logosu.png',
#  'Şanlıurfa 2016.jpg',
#  'Νικος Σαμψών.jpg',
#  'Борис Николаевич Ельцин.jpg',
#  'Бішкек 28 березня 2005.jpg',
#  'Гвардия.png',
#  'Защитнки Белого Дома 1.jpg',
#  'Казнь Касема.jpg',
#  'Кокарда рядового и сержантского состава Советской Армии.jpg',
#  'Расстрел белого дома в 1993 году.jpg',
#  'Русское Национальное Единство.jpg',
#  'Шеврон 4-й гвардейской танковой дивизии.jpg',
#  'اعدام عبد الكريم قاسم وصحبه في دار الاذاعة.jpg',
#  'حزب الحرية والعدالة.png',
#  'حزب النور.png',
#  'صورة دبابات الإنقلابيين العسكريين التركيين.jpg',
#  'صورة ذبابات الإنقلابيين العسكريين التركيين.jpg',
#  'مذيعة قناة تي آر تي.jpg',
#  'کودتاچیان.jpg',
#  'พลเอกประยุทธ์ประกาศยึดอํานาจ22 พฤษภาคม 2557.png',
#  'სამხედრო გადატრიალების მცდელობა.png',
#  'ベールイドーム.jpg',
#  '臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (GreenIsland) of Taiwan.jpg',
#  '윤치영 1961.jpg',
#  '장도영, 박정희 1961년 5.16 군사정변.jpg',
#  '장도영.jpg'}

# %%
len(list(set(image_tags_dict.keys()))), len(list(set([f for lang,files in lang_images.items() for f in files])))
# Out:
# (774, 747)

# %% [markdown]
# ## Revision network

# %%
lang_user_rev_edgelist.head()
# Out:
#   lang            user  revid
# 0   af      Aliwal2012      7
# 1   af          Wwikix      1
# 2   am  109.151.136.89      1
# 3   am          Addbot      1
# 4   am         Bulgew1     23

# %%
lang_user_rev_edgelist = rev_df.groupby(['lang','user']).agg({'revid':pd.Series.nunique}).reset_index()
lang_user_rev_g = nx.from_pandas_dataframe(lang_user_rev_edgelist,source='user',target='lang',edge_attr=True)

for lang in lang_user_rev_edgelist['lang'].unique():
    lang_user_rev_g.add_node(lang,kind='lang')

for lang in lang_user_rev_edgelist['user'].unique():
    lang_user_rev_g.add_node(lang,kind='user')

print("There are {0:,} languages, {1:,} users, and {2:,} edges in the network".format(len(lang_user_rev_edgelist['lang'].unique()),
                                                                                      len(lang_user_rev_edgelist['user'].unique()),
                                                                                      lang_user_rev_g.number_of_edges()))

nx.write_gexf(lang_user_rev_g,'lang_user_revisions.gexf')
# Out:
# There are 97 languages, 21,657 users, and 24,319 edges in the network

# %%
rev_langs = list(lang_user_rev_edgelist['lang'].unique())
proj_lang_rev_g = nx.bipartite.weighted_projected_graph(lang_user_rev_g.to_undirected(),nodes=rev_langs)

print("There are {0:,} nodes and {1:,} edges in the network".format(proj_lang_rev_g.number_of_nodes(),
                                                                    proj_lang_rev_g.number_of_edges()))
# Out:
# There are 97 nodes and 2,855 edges in the network

# %% [markdown]
# ## Image usage

# %%
with open('all_coups_file_image_usage.json','r') as f:
    all_coups_image_usage = json.load(f)

# %%
lang_topic_df = pd.DataFrame({article:{lang:len(lang_d) for lang,lang_d in d.items()} for article,d in all_coups_image_usage.items()}).T
#lang_topic_df = lang_topic_df.fillna(0)
lang_topic_df.mean().sort_values(ascending=False).head()
# Out:
# cv     7.000000
# arz    4.000000
# mn     4.000000
# gl     2.833333
# ar     2.536585
# dtype: float64

# %%
all_coups_image_usage["17 July Revolution"]
# Out:
# {'ar': {},
#  'bn': {},
#  'en': {},
#  'es': {},
#  'ja': {},
#  'pl': {'Ahmad Hassan el Bakr.jpg': ['Premierzy Iraku',
#    'Ahmad Hasan al-Bakr',
#    'Partia Baas (Irak)',
#    'Zamach stanu w Iraku (1968)']},
#  'pt': {},
#  'zh': {}}

# %%
full_image_list = list()
for article, article_payload in all_coups_image_usage.items():
    for lang,file_payload in article_payload.items():
        for filename,pagelist in file_payload.items():
            if filename not in full_image_list:
                full_image_list.append(filename)
                
print("There are {0} images in the full_image_list".format(len(full_image_list)))

full_image_list[:5]
# Out:
# There are 739 images in the full_image_list
# ['Project 571 Outline.jpg',
#  'President Abd al-Salam Arif.jpg',
#  'Maflaq.jpg',
#  'Ahmad Hassan el Bakr.jpg',
#  'Abdul-salam-arif.jpg']

# %% [markdown]
# ### Image-language network

# %%
image_lang_g = nx.DiGraph()

for topic, topic_d in all_coups_image_usage.items():
    for lang, file_d in topic_d.items():
        for filename, pagelist in file_d.items():
            f = filename.split(':')[1]
            image_lang_g.add_edge(f, lang)
            image_lang_g.add_node(f, kind='file')
            image_lang_g.add_node(lang, kind='lang')

# %% [markdown]
# ### Image-page network

# %%
image_page_usage_g = nx.DiGraph()
for topic, topic_d in all_coups_image_usage.items():
    for lang, file_d  in topic_d.items():
        for filename, pagelist in file_d.items():
            if len(pagelist) < 10:
                for page in pagelist:
                    image_page_usage_g.add_node(page,lang=lang,kind='article')
                    image_page_usage_g.add_node(filename,lang='image',kind='image')
                    image_page_usage_g.add_edge(page,filename)

print("There are {0:,} nodes and {1:,} edges in the network".format(image_page_usage_g.number_of_nodes(),image_page_usage_g.number_of_edges()))
nx.write_gexf(image_page_usage_g,'image_page_usage_g.gexf')
# Out:
# There are 2,464 nodes and 2,884 edges in the network

# %% [markdown]
# ### Image-language network

# %%
image_lang_g = nx.DiGraph()
for topic, topic_d in all_coups_image_usage.items():
    for lang, file_d  in topic_d.items():
        for filename, pagelist in file_d.items():
            if len(pagelist) < 10:
                f = filename.split(':')[1]
                image_lang_g.add_node(f,kind='image')
                image_lang_g.add_node(lang,kind='lang')
                if image_lang_g.has_edge(f,lang):
                    image_lang_g[lang][f]['weight'] += 1
                else:
                    image_lang_g.add_edge(lang,f,weight=1)

image_lang_langs = [n for n,d in image_lang_g.nodes(data=True) if d['kind'] == 'lang']
image_lang_images = [n for n,d in image_lang_g.nodes(data=True) if d['kind'] == 'image']

print("There are {0:,} languages, {1:,} images, and {2:,} edges in the network".format(len(image_lang_langs),
                                                                                       len(image_lang_images),
                                                                                       image_lang_g.number_of_edges()))
nx.write_gexf(image_lang_g,'image_lang_usage.gexf')
# Out:
# There are 77 languages, 686 images, and 1,531 edges in the network

# %%
image_lang_usage_langs = [n for n,d in image_lang_usage_g.nodes(data=True) if d['kind'] == 'lang']
clustering = nx.bipartite.clustering(image_lang_usage_g.to_undirected(),nodes=image_lang_usage_langs,mode='dot')
pd.Series(clustering).sort_values(ascending=False).head()
# Out:
# oc          0.258333
# be-x-old    0.258197
# is          0.120494
# azb         0.120494
# lb          0.104938
# dtype: float64

# %%
proj_image_lang_usage_g = nx.bipartite.weighted_projected_graph(image_lang_usage_g.to_undirected(),nodes=image_lang_usage_langs)
weight_1_edges = [(i,j) for i,j,d in proj_image_lang_usage_g.edges(data=True) if d['weight'] > 1]
#proj_image_lang_usage_g.remove_edges_from(weight_1_edges)
pd.Series(nx.degree_centrality(proj_image_lang_usage_g)).sort_values(ascending=False)
# Out:
# es          0.868421
# he          0.776316
# de          0.763158
# pt          0.736842
# en          0.736842
# zh          0.736842
# ja          0.736842
# ar          0.723684
# tr          0.671053
# no          0.657895
# fr          0.657895
# pl          0.644737
# ca          0.644737
# ro          0.644737
# th          0.644737
# ko          0.644737
# gl          0.631579
# ru          0.618421
# sr          0.618421
# fi          0.605263
# it          0.605263
# hr          0.592105
# nl          0.592105
# vi          0.592105
# bg          0.578947
# sv          0.578947
# id          0.565789
# el          0.552632
# cs          0.552632
# ka          0.539474
#               ...
# lb          0.263158
# si          0.263158
# sco         0.250000
# mk          0.236842
# bn          0.236842
# sk          0.210526
# sq          0.197368
# ku          0.197368
# cv          0.184211
# arz         0.184211
# ga          0.171053
# lt          0.157895
# is          0.144737
# azb         0.144737
# simple      0.144737
# zh-yue      0.131579
# br          0.118421
# bs          0.105263
# ckb         0.092105
# tg          0.092105
# be-x-old    0.026316
# oc          0.026316
# ur          0.026316
# cy          0.013158
# hy          0.013158
# ta          0.013158
# af          0.013158
# hi          0.000000
# kk          0.000000
# am          0.000000
# dtype: float64

# %% [markdown]
# ### Image-lang-tag tripartite network

# %%
tag_d = tag_file_el.groupby('file').agg({'tag':lambda x:list(x)})['tag'].to_dict()
tag_d
# Out:
# {'"De Historische Strijd" Herdenkingsmonument revolutie 25 februari 1980 - Nieuw-Amsterdam - 20418126 - RCE.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Memorials',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  '-De_Historische_Strijd-_Herdenkingsmonument_revolutie_25_februari_1980_-_Nieuw-Amsterdam_-_20418127_-_RCE.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Memorials',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  '11 septiembre 1976- manifestacion pro Pinochet.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'FE-Smile',
#   'GT-Celebration',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '14 July revolution - mutilated corpse.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'FE-Frown',
#   'GT-Alleged Atrocities',
#   'IF-Individual',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'VI-Violent Image'],
#  '15 July-Erdoğan SMS.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Documents/Communications',
#   'VI-Non-violent Image'],
#  '15 Temmuz Şehitler Parkı tabelası.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Memorials',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  '1920UnitedFruitCompanyEntrance.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'VI-Non-violent Image'],
#  "1962 Burmese coup d'état.jpg": ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Group',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  "1962 Burmese coup d'état2.jpg": ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Group',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '1973Babadinca0048.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '1989 December 16. sugárút és a Tudor Vladimirescu út kereszteződése. Fortepan 31892.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Protest/Demonstration',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '1989 Iliescu television.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Police',
#   'VI-Non-violent Image'],
#  '1991 CPA 6367.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Documents/Communications',
#   'GT-Memorials',
#   'GT-Signs/Symbols',
#   'IF-Individual',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '1991 CPA 6368.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Documents/Communications',
#   'GT-Memorials',
#   'GT-Signs/Symbols',
#   'IF-Individual',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '1991 CPA 6369.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Documents/Communications',
#   'GT-Portrait',
#   'GT-Signs/Symbols',
#   'IF-Individual',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '1991 CPA 6370.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'GT-Documents/Communications',
#   'GT-Locations/Maps/Infographics',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  '1991 coup attempt1.jpg': ['IT-Active Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '1991 coup attempt4.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '1991 coup attempt5.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual',
#   'TOP-Civilians',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '1991-August-Moscow.jpg': ['IT-Passive Image',
#   'GT-Protest/Demonstration',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '1991-Barrikad-BelyDom.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Military Actions',
#   'GT-Policing',
#   'IF-Individual in Relation to the Group',
#   'TOP-Journalists',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '1991_coup_yeltsin.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  "1992 Venezuelan coup d'état attempts Hugo Chávez speech.jpg": ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Journalists',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  "1992 Venezuelan coup d'état attempts Miraflores.jpg": ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Military Actions',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  "1992 Venezuelan coup d'état attempts collage.png": ['IT-Active Image',
#   'D-Adult Male',
#   'FE-Frown',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'GT-Policing',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'TOP-Police',
#   'VI-Violent Image'],
#  '1993_Rusya_anayasa_krizi_sırasında_Parlamento_yanlısı_göstericiler.jpg': ['IT-Active Image',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '1993_Tanks_before_Russian_White_house.jpg': ['IT-Active Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'GT-Destruction',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'VI-Violent Image'],
#  '1_Mart_1997_-_Cumhuriyet.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Documents/Communications',
#   'IF-Individual in Relation to the Group',
#   'TOP-Journalists',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  "2002 Venezuelan coup d'état attempt collage.jpg": ['FPI-Foriegn Symbols',
#   'GT-Protest/Demonstration',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Group',
#   'TOP-Civilians',
#   'TOP-Military Personnel',
#   'TOP-Police',
#   'VI-Violent Image'],
#  "2002 Venezuelan coup d'état attempt uprising.jpg": ['IT-Active Image',
#   'D-Adult Male',
#   'FE-Frown',
#   'GT-Protest/Demonstration',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '200535.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  '2006 09 12 sarkozy 600.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'FE-Smile',
#   'FPI-Foriegn Leaders',
#   'FPI-Foriegn Symbols',
#   'GT-Buildings',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  '2006 Thailand Coup 006.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '2006-06-22 12-36-38 Seychelles Cascade Cascade.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  '2007ManilaPenSiegeMap.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  '2009 Honduran demonstration against Zelaya and Chavez 1.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'FE-Frown',
#   'FE-Smile',
#   'GT-Protest/Demonstration',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Journalists',
#   'VI-Non-violent Image'],
#  '2009 Honduras political crisis 11.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Protest/Demonstration',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '2009 Honduras political crisis 2.jpg': ['IT-Active Image',
#   'GT-Buildings',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '2009 Honduras political crisis 3.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Protest/Demonstration',
#   'IF-Non-human',
#   'TOP-Civilians',
#   'VI-Violent Image'],
#  '2009 Honduras political crisis 4.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'D-Child Female',
#   'FE-Frown',
#   'GT-Buildings',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '2009 Honduras political crisis 5.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Buildings',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'GT-Policing',
#   'IF-Individual',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '2009 Honduras political crisis 9.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Buildings',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '2013 Taksim Gezi Park protests (15th June).jpg': ['IT-Active Image',
#   'GT-Buildings',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '2014 0526 Thailand coup Chang Phueak Gate Chiang Mai 01.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Policing',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '2014 0526 Thailand coup Chang Phueak Gate Chiang Mai 02.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  '2014 0526 Thailand coup Chang Phueak Gate Chiang Mai 03.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'GT-Policing',
#   'IF-Group',
#   'TOP-Military Personnel',
#   'TOP-Police',
#   'VI-Non-violent Image'],
#  '2014 0527 Thailand coup Thaphae Gate.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'GT-Policing',
#   'IF-Individual',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  '2014 Suchum, Siedziba rządu i prezydenta Republiki Abchazji (04).jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '2014-02-02 Silom protest site 01.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Celebration',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  '2015 Asia Pacific Parliamentary Forum (1).jpg': ['IT-Passive Image',
#   'FPI-Foriegn Leaders',
#   'FPI-Foriegn Symbols',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Group',
#   'TOP-Journalists',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  '2016 Türkiye Darbe Girişimi - Ankara.jpg': ['IT-Active Image',
#   'D-Non-human',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  "20th anniversary of 1953 Iranian coup d'état.jpg": ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Celebration',
#   'GT-Documents/Communications',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '21438_010.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Diplomatic and Other Official Actions',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  '24. Rupturas al cese al fuego.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'VI-Non-violent Image'],
#  '247783721 10e33ed8c9 o.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  '24_жніўня_1991.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Diplomatic and Other Official Actions',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  '25 Abril 1983 Porto by Henrique Matos 01.jpg': ['IT-Active Image',
#   'D-Adult Female',
#   'GT-Celebration',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '25 de Abril sempre Henrique Matos.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Celebration',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  '27_Mayıs_Darbesi_sembolü.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  '28Amordad1332 Toopkhaneh.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Protest/Demonstration',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '28mordad1332.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Child Male',
#   'GT-Buildings',
#   'GT-Memorials',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Group',
#   'TOP-Civilians',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '34-o Aniversário Revolução dos Cravos, Lisboa.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Buildings',
#   'GT-Celebration',
#   'GT-Protest/Demonstration',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '4.19 혁명.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  '4TD4-500x250.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  '4_Ekim_1993_Rusya_Parlamento_binası_alevler_içinde.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Destruction',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  '5.16 Coup Park Chung-hee.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Frown',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '5011-0004-reverse.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  '59mossadeghprime_minister1951.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  '757landing-toncontin.jpg': ['IT-Active Image',
#   'D-Non-human',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'A. Pinochet Stamp.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'ABI100 KingFerdinandMuseum.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'AIOC741330.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Protest/Demonstration',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'AUT Hadersdorf-Kammern COA.jpg': ['IT-Passive Image',
#   'D-Child Male',
#   'FE-Smile',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'VI-Non-violent Image'],
#  'Abadanraffinerie.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Abd Rabbuh Mansur Hadi 2013.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Abd al-Karim death.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Alleged Atrocities',
#   'GT-Suffering',
#   'IF-Individual',
#   'TOP-Civilians',
#   'VI-Violent Image'],
#  'Abd al-Wahab Shawaf.png': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Abdul Fatah Khalil Al-Sisi 2013-03-03.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Abdul Rahman Arif.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Abdul-salam-arif.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Abolghasem Kashani.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Ad-Duri.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FPI-Foriegn Leaders',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Adib al-Shishakli.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Adnan Menderes VI. Yasama Dönemi.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Africa satellite orthographic.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'After burning the Muslim brotherhood stage in front of the mosque.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Destruction',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'TOP-Civilians',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'After coup nightly demonstartion of president Erdogan supporters. Istanbul, Turkey, Eastern Europe and Western Asia. 22 July,2016.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'FE-Smile',
#   'GT-Celebration',
#   'GT-Portrait',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Ahmad Hassan el Bakr.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'AhmadGhavam2.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Ahmed el-Tayeb May 2015 (17963337671).jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Air Commodore Kaiser Tufail receiving a memento from Commander of the Turkish Air Force General Akin Ozturk (cropped).jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Air Commodore Kaiser Tufail receiving a memento from Commander of the Turkish Air Force General Akin Ozturk.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FPI-Foriegn Leaders',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Al Fujimori.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Frown',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Alatoo.jpg': ['IT-Active Image',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Alegria rafael.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Frown',
#   'GT-Protest/Demonstration',
#   'GT-Portrait',
#   'GT-Signs/Symbols',
#   'IF-Individual',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Alejandro Agustín Lanusse.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Frown',
#   'GT-Diplomatic and Other Official Actions',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Alexander Ankvab - 06.10.2011.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Algiers_putsch_1961.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Ali salih.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Alix Pasquet.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Allen w dulles.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FPI-Foriegn Leaders',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Allende supporters.jpg': ['IT-Active Image',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Allende.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Memorials',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Allende_son.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Violent Image',
#   'IT-Active Image',
#   'D-Adult Male',
#   'FE-Frown',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  'Alte. Carlos G. N. Coda.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Documents/Communications',
#   'GT-Portrait',
#   'GT-Signs/Symbols',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Alte. Pedro Gnavi.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Amadou Toumani Touré 30 November 2011.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'AmauryKruel.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Angkor Wat W-Seite.jpg': ['IT-Passive Image',
#   'GT-Buildings',
#   'GT-Memorials',
#   'IF-Non-human',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'AngkorWat Delaporte1880.jpg': ['IT-Passive Image',
#   'GT-Buildings',
#   'GT-Documents/Communications',
#   'GT-Memorials',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Anti Morsi protest march at 28th June 2013.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Protest/Demonstration',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Anti coup Mauritania.jpg': ['IT-Active Image',
#   'D-Adult Female',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Anti-Coup Demokrasi Nöbeti Kızılay Square.jpg': ['IT-Active Image',
#   'GT-Protest/Demonstration',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Anti-Morsi poster in a car.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Protest/Demonstration',
#   'GT-Documents/Communications',
#   'GT-Portrait',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Anti-Morsi protester june 2013.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Anti-Morsi protests June 2013 in Egypt.jpg': ['IT-Active Image',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Anti-coup sit-in at Rabaa Adiweya mosque 2013.jpg': ['IT-Active Image',
#   'GT-Buildings',
#   'GT-Protest/Demonstration',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'António de Oliveira Salazar, drawing.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Documents/Communications',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Apollo 11.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'FPI-Foriegn Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Arafat Darwish Habash.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Arafat in Jordan.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Frown',
#   'FE-Smile',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Araya-Allende.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'Aref with Qasim.png': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'Arif.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Arturo Illia.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Asia map.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Askar Akaev MoscowRia 08-2016.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Askar Akayev.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Assad Tlass war 1973.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Frown',
#   'GT-Military Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'AssaltonaMatadaSanga....jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  'Assemblee Nationale Burkina Faso.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'VI-Non-violent Image'],
#  'August 1991 Kalininski prospect.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Augusto Pinochet - 1995.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Augusto Pinochet 1986.jpg': ['D-Adult Male',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'Augusto Pinochet foto oficial.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Augusto Pinochet.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Diplomatic and Other Official Actions',
#   'GT-Military Actions',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Awqati1.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Ayatmohagheghi.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Álvaro Cunhal Henrique Matos 02.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'BBC Asian Network Studio The Mailbox Birmingham 20041228.jpg': ['IT-Passive Image',
#   'GT-Buildings',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'TOP-Journalists',
#   'VI-Non-violent Image'],
#  'BKK21090604.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'BKK22090601.jpg': ['IT-Active Image',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'BKK24090601.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'D-Child Female',
#   'GT-Protest/Demonstration',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Journalists',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'BKK24090602.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Protest/Demonstration',
#   'GT-Humanitarian Aid',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'GT-Policing',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'TOP-Civilians',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'BKK24090603.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'D-Child Male',
#   'D-Child Female',
#   'FPI-Foriegn Symbols',
#   'GT-Protest/Demonstration',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'BKK24090612.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'BKK24090613.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'BKK24090615.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Protest/Demonstration',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Group',
#   'TOP-Civilians',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'BKK24090616.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Protest/Demonstration',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'BKK24090618.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'BP200906-2.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Documents/Communications',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'VI-Violent Image'],
#  'BTR-60PB DA-ST-89-06597.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'BTR_25_april.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Celebration',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Group',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  'Baath National Command.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Baath Party founder Michel Aflaq with Iraqi President Ahmad Hasan al-Bakr in Baghdad in 1968.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'FPI-Foriegn Leaders',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Bakkir.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Bangkokplaces.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Barack Obama at Cairo University cropped.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FPI-Foriegn Leaders',
#   'GT-Diplomatic and Other Official Actions',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Bashar al-Assad (cropped).jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'BenzinBon-1.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Binali Yıldırım headshot.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'GT-Signs/Symbols',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Black May 1992.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Protest/Demonstration',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'GT-Policing',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'TOP-Military Personnel'],
#  'Black_May_Thailand.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Blaise Compaoré 2014 White House.png': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Blargos1.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'GT-POWs',
#   'GT-Policing',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  'Blok wschodni pl.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Boeing 727-2B6, Royal Air Maroc - RAM AN1217763.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Boğazın tek yönlü kapatılması.png': ['IT-Passive Image',
#   'D-Non-human',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Bokassa portrait.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Bophuthatswana_coup_Execution.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Alleged Atrocities',
#   'GT-POWs',
#   'GT-Suffering',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'VI-Violent Image'],
#  'Boris Yeltsin 19 August 1991-1.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Diplomatic and Other Official Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Group',
#   'TOP-Civilians',
#   'TOP-Journalists',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Boris Yeltsin 1993.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Boris Yeltsin 21 February 1989-1.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Boris Yeltsin 22 August 1991-1.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Celebration',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Police',
#   'VI-Non-violent Image'],
#  'Boris Yeltsin-2.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Frown',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Bucur Obor (1986).jpg': ['IT-Active Image',
#   'GT-Protest/Demonstration',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'BuiQuangThan.jpg': ['IT-Active Image',
#   'D-Non-human',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'VI-Violent Image'],
#  'Bundesarchiv B 145 Bild-F013047-0040, München, Staatsbesuch Präsident von Zypern.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Bundesarchiv Bild 183-1989-1120-036, Berlin, Schweigemarsch für Rumänien.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Bundesarchiv Bild 183-1989-1215-038, Berlin, Demonstration für Rumänien.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Bundesarchiv Bild 183-1989-1220-032, Berlin, Demonstration für Rumänien, Mahnwache.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Bundesarchiv Bild 183-1989-1221-032, Berlin, Demonstration für Rumänien.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Bundesarchiv Bild 183-1989-1223-006, Berlin, Brandenburger Tor, Transparte zu Rumänien.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'GT-Signs/Symbols',
#   'VI-Non-violent Image'],
#  'Bundesarchiv_Bild_183-55823-0005,_Berlin,_Karl-Marx-Allee,_-Deutsche_Sporthalle-.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Buildings',
#   'GT-Protest/Demonstration',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Burkina Faso Protests.png': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Burkina Faso carte.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'VI-Non-violent Image'],
#  'Burkinabe Col. Gilbert Diendéré, 2010.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Burkinabé_uprising_at_Place_de_la_Nation.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Protest/Demonstration',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Burnt out buildings on nothern edge of Revolution Square, Bucharest.jpg': ['IT-Passive Image',
#   'D-Adult Female',
#   'GT-Buildings',
#   'GT-Destruction',
#   'IF-Non-human',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Bush Gorba P15623-25A.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FPI-Foriegn Leaders',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Bülent Ecevit Cropped.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'By-map.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'VI-Non-violent Image'],
#  'CFSN Revolution Roumaine.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Cairo pro-Mursi-protests July-August 2013 ARAB2.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'CamGen.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FPI-Foriegn Leaders',
#   'GT-Diplomatic and Other Official Actions',
#   'GT-Military Actions',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'Car of history.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Cardinal Jaime Sin in 1988.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Carlos Gomes Junior.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Carte gabon.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Castelo de Guimarães (Portugal).jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Castelobranco.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Ceausescu, Nicolae.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Central african republic sm04.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'VI-Non-violent Image'],
#  'Central african republic sm04ESP.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Centro SB.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'IF-Non-human',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Chamlong Srimuang 2008-12-27.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'VI-Non-violent Image'],
#  'Chan o cha Portrait.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Chan_o_cha_Portrait.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'GT-Signs/Symbols',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Chancery.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  "Chang Myon 194804'.png": ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Chavez-WSF2005.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'Chavez_başarısız_darbeden_sonra_göreve_dönerken_13_Nisan_2002.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Celebration',
#   'GT-Military Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'ChenGuatemala.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Memorials',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Chest badge Guards Russian Federation.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Documents/Communications',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Chile - Palácio de La Moneda - by Sérgio Schmiegelow.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Chile- el pueblo vencera cropped.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  'Chile_Junta001.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Choi Kyu Ha.png': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Civilian with PM Md. 1963 during the Romanian Revolution of 1989.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  'Color Revolutions Map.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'CongressBuilding SEATO.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'FPI-Foriegn Leaders',
#   'FPI-Foriegn Symbols',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Conmemoración 40 años Museo de la Memoria 2.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Conmemoración de 40 años del Golpe Militar 1.jpg': ['IT-Passive Image',
#   'GT-Celebration',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Corazon Aquino 1986.jpg': ['IT-Passive Image',
#   'D-Adult Female',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Corazon Aquino inauguration.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Journalists',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Cordobazo.jpg': ['IT-Passive Image',
#   'GT-Alleged Atrocities',
#   'GT-Protest/Demonstration',
#   'GT-Destruction',
#   'IF-Group',
#   'VI-Violent Image'],
#  'Coruche mural 25 Abril.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'VI-Non-violent Image'],
#  'Cory Aquino during a ceremony honoring US Air Force.jpg': ['IT-Passive Image',
#   'D-Adult Female',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  "Coup-d'etat-11-web-cnni.jpg": ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  "Coup-d'etat-14-web-cnni.jpg": ['IT-Passive Image',
#   'D-Adult Male',
#   'D-Child Male',
#   'FE-Smile',
#   'GT-Celebration',
#   'IF-Individual',
#   'TOP-Civilians',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  "Coup-d'etat-15-web-cnni.jpg": ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Buildings',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  "Coup-d'etat-17.jpg": ['IT-Passive Image',
#   'D-Adult Female',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Police',
#   'VI-Non-violent Image'],
#  "Coup-d'etat-2-web-cnni.jpg": ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'GT-Policing',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  "Coup-d'etat-24-web-cnni.jpg": ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  "Coup-d'etat-3-web-cnni.jpg": ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Protest/Demonstration',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Journalists',
#   'VI-Non-violent Image'],
#  "Coup-d'etat-5-web-cnni.jpg": ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
# ...
#   'D-Adult Female',
#   'GT-Signs/Symbols',
#   'IF-Individual',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Thailand Army（9-24-2006）.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'D-Child Male',
#   'FE-Smile',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'Thailand Ministry of Information and Communication Technology 2014 Censorship Image.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Thaksin crop.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Thaksin.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'The Four Voyages of Columbus 1492-1503 - Project Gutenberg etext 18571.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'The philosopher Zaki al-Arsuzi.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'The_Bangkok_Post,_September_20,_2006.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Documents/Communications',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'VI-Violent Image'],
#  'The_nation_200506.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Documents/Communications',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Thi and thieu.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Military Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'TimbruNicolaeCeausescu.png': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Documents/Communications',
#   'GT-Portrait',
#   'GT-Signs/Symbols',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'TimbruRevolutie.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Documents/Communications',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'TimisoaraCatedrala.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Togoland.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Tokat darbe karşıtları.png': ['IT-Active Image',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Tom Thabane cropped.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Tom Thabane.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Toure-folklife.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Diplomatic and Other Official Actions',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Toure-folklife2.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'FE-Smile',
#   'GT-Celebration',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'TőkésL.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Documents/Communications',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Translation2.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Trial_iraq.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'Truman initiating Korean involvement.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FPI-Foriegn Leaders',
#   'GT-Diplomatic and Other Official Actions',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Tsn-1962.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'GT-Military Technology and Weaponry',
#   'VI-Non-violent Image'],
#  'Tte.Gral. (R) J. Videla.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Tulip 2.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Tulip.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Turcja, 15-16.07.2016r. Próba zamachu.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Turgut Özal cropped.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Turkey - Air Force Lockheed C-130E Hercules Bakema.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Military Technology and Weaponry',
#   'VI-Non-violent Image'],
#  'Turkey topo.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Turkish CoastMAK.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'VI-Non-violent Image'],
#  'Turkish protesters in Istanbul.jpg': ['IT-Active Image',
#   'GT-Protest/Demonstration',
#   'GT-Signs/Symbols',
#   'IF-Group',
#   'TOP-Civilians',
#   'VI-Violent Image'],
#  'US Air Force C-22B (727-100).jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'US Marine charges through Japanese machine gun fire on Okinawa.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'FPI-Foriegn Symbols',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  'USS Jesse L. Brown (FF-1089) off Maine.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'UXP Unidad Popular.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Un-guatemala.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Un-pakistan.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Unasur BsAs Crisis Ecuador.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'FPI-Foriegn Symbols',
#   'GT-Diplomatic and Other Official Actions',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Unidad Popular 1973.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Ülkü Ocakları Eğitim ve Kültür Vakfı Logosu.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'V._Landsbergis._Viešoji_informacija.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Videla Sociedad Rural.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'Viennese Illuminated Chronicle Posada.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Alleged Atrocities',
#   'GT-Military Actions',
#   'GT-Suffering',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  'Viva a liberdade Henrique Matos.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'GT-Signs/Symbols',
#   'IF-Individual in Relation to the Group',
#   'VI-Violent Image'],
#  'Vladimir Putin and Recep Tayyip Erdoğan (2015-06-13) 3.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Frown',
#   'FPI-Foriegn Leaders',
#   'GT-Portrait',
#   'GT-Signs/Symbols',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Vympel special forces.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'VI-Non-violent Image'],
#  'Watanyin.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  "William Knox D'Arcy.jpg": ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'World Factbook (1982) Seychelles.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Yalta summit 1945 with Churchill, Roosevelt, Stalin.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FPI-Foriegn Leaders',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  'Yameogo stamp 1960.png': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Documents/Communications',
#   'GT-Portrait',
#   'GT-Signs/Symbols',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Yanaon.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'VI-Non-violent Image'],
#  'Yankee go home graffiti.png': ['IT-Passive Image',
#   'D-Adult Male',
#   'FPI-Foriegn Symbols',
#   'GT-Signs/Symbols',
#   'IF-Individual',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Yeltsin 1993 cropped.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Diplomatic and Other Official Actions',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Yemen war detailed map.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Locations/Maps/Infographics',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Yun Bo1.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'ZSU-23-4-Camp-Pendleton.jpg': ['IT-Active Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  'Zahedifirman.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Documents/Communications',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Zelaya con sombrero.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Zelaya in Brazil.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'TOP-Police',
#   'VI-Non-violent Image'],
#  'Zine El Abidine Ben Ali cropped.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Zulfikar Ali Bhutto.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Diplomatic and Other Official Actions',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Νικος Σαμψών.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Борис Николаевич Ельцин.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'FE-Smile',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Бішкек 28 березня 2005.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'GT-Destruction',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Гвардия.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Дворец со стороны правого крыла 27 12 79.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'D-Adult Female',
#   'GT-Buildings',
#   'TOP-Civilians',
#   'VI-Non-violent Image'],
#  'Защитнки Белого Дома 1.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Memorials',
#   'IF-Non-human',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'Казнь_Касема.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Alleged Atrocities',
#   'GT-Military Actions',
#   'GT-Suffering',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  'Кокарда рядового и сержантского состава Советской Армии.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Расстрел_белого_дома_в_1993_году.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'GT-Destruction',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'VI-Violent Image'],
#  'Русское Национальное Единство.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'Шеврон 4-й гвардейской танковой дивизии.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'اعدام عبد الكريم قاسم وصحبه في دار الاذاعة.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Alleged Atrocities',
#   'GT-Suffering',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military Personnel',
#   'VI-Violent Image'],
#  'التجمع_اليمني_للاصلاح.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image'],
#  'حزب_الحرية_والعدالة.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Signs/Symbols',
#   'VI-Non-violent Image'],
#  'صورة_دبابات_الإنقلابيين_العسكريين_التركيين.jpg': ['IT-Active Image',
#   'D-Non-human',
#   'GT-Military Actions',
#   'GT-Military Technology and Weaponry',
#   'IF-Non-human',
#   'VI-Violent Image'],
#  'مذيعة_قناة_تي_آر_تي.jpg': ['IT-Passive Image',
#   'D-Adult Female',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Journalists',
#   'VI-Non-violent Image'],
#  'کودتاچیان.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'พลเอกประยุทธ์ประกาศยึดอำนาจ22_พฤษภาคม_2557.png': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Diplomatic and Other Official Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'სამხედრო_გადატრიალების_მცდელობა.png': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Documents/Communications',
#   'VI-Non-violent Image'],
#  '윤치영 1961.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  '장도영, 박정희 1961년 5.16 군사정변.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Military Actions',
#   'IF-Individual in Relation to the Group',
#   'TOP-Civilians',
#   'TOP-Journalists',
#   'TOP-Military Personnel',
#   'VI-Non-violent Image'],
#  '장도영.jpg': ['IT-Passive Image',
#   'D-Adult Male',
#   'GT-Portrait',
#   'IF-Individual',
#   'TOP-Military or Political Leaders',
#   'VI-Non-violent Image'],
#  'ベールイドーム.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Buildings',
#   'GT-Destruction',
#   'IF-Non-human',
#   'VI-Violent Image'],
#  '臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (GreenIsland) of Taiwan.jpg': ['IT-Passive Image',
#   'D-Non-human',
#   'GT-Memorials',
#   'GT-Signs/Symbols',
#   'IF-Non-human',
#   'VI-Non-violent Image']}

# %%
filenames = []
for topic, topic_d in all_coups_image_usage.items():
    for lang, file_d  in topic_d.items():
        for filename, pagelist in file_d.items():
            if len(pagelist) < 10:
                f = filename.split(':')
                if any(e in f[0] for e in ['.png','.jpg']):
                    filenames.append(f[0])
                else:
                    filenames.append(f[1])
len(set(filenames))
# Out:
# 686

# %%
egypt_tp_g = nx.DiGraph()

for lang, lang_d in all_coups_image_usage["2013 Egyptian coup d'état"].items():
    for file, file_l in lang_d.items():
        f = file.split(':')[1]
        egypt_tp_g.add_edge(lang,f,kind='lang-file')
        egypt_tp_g.add_node(lang,kind='lang')
        egypt_tp_g.add_node(f,kind='file')
        try:
            for tag in tag_d[f]:
                egypt_tp_g.add_edge(tag,f,kind="tag-file")
                egypt_tp_g.add_node(tag,kind='tag')
        except KeyError:
            print("No tag for {0}".format(f))
            pass

egypt_tp_tags = [n for n,d in egypt_tp_g.nodes(data=True) if d['kind'] == 'tag']
egypt_tp_langs = [n for n,d in egypt_tp_g.nodes(data=True) if d['kind'] == 'lang']
egypt_tp_files = [n for n,d in egypt_tp_g.nodes(data=True) if d['kind'] == 'file']

print("""There are {0:,} tags, {1:,} languages, {2:,} files, and {3:,} edges in the network
""".format(len(egypt_tp_tags),
           len(egypt_tp_langs),
           len(egypt_tp_files),
           egypt_tp_g.number_of_edges()))

nx.write_gexf(egypt_tp_g,'egypt_tripartite.gexf')
# Out:
# No tag for General el Sisi Mursiyi görevden alındığını açıklarken.png
# No tag for FJP.png
# No tag for General Al-Sisi, announcing the removal of President Morsi.png
# No tag for General Al-Sisi, announcing the removal of President Morsi.png
# No tag for حزب النور.png
# No tag for حزب الحرية والعدالة.png
# No tag for Freedom and Justice Party (Egypt).jpg
# There are 30 tags, 25 languages, 40 files, and 303 edges in the network

# %%
soviet_tp_g = nx.DiGraph()

for lang, lang_d in all_coups_image_usage["1991 Soviet coup d'état attempt"].items():
    for file, file_l in lang_d.items():
        f = file.split(':')[1]
        soviet_tp_g.add_edge(lang,f,kind='lang-file')
        soviet_tp_g.add_node(lang,kind='lang')
        soviet_tp_g.add_node(f,kind='file')
        try:
            for tag in tag_d[f]:
                soviet_tp_g.add_edge(tag,f,kind="tag-file")
                soviet_tp_g.add_node(tag,kind='tag')
        except KeyError:
            print("No tag for {0}".format(f))
            pass

soviet_tp_tags = [n for n,d in soviet_tp_g.nodes(data=True) if d['kind'] == 'tag']
soviet_tp_langs = [n for n,d in soviet_tp_g.nodes(data=True) if d['kind'] == 'lang']
soviet_tp_files = [n for n,d in soviet_tp_g.nodes(data=True) if d['kind'] == 'file']

print("""There are {0:,} tags, {1:,} languages, {2:,} files, and {3:,} edges in the network
""".format(len(soviet_tp_tags),
           len(soviet_tp_langs),
           len(soviet_tp_files),
           soviet_tp_g.number_of_edges()))

nx.write_gexf(soviet_tp_g,'soviet_tripartite.gexf')
# Out:
# No tag for Кокарда рядового и сержантского состава Советской Армии.jpg
# No tag for 1991 coup yeltsin.jpg
# No tag for Dzerzhinsky Statue, which once dominated Lyubianka Square.jpg
# No tag for 1991 coup yeltsin.jpg
# No tag for P Russia.png
# No tag for Logo for Liberal Democratic Party of Russia.png
# No tag for Logo for Liberal Democratic Party of Russia.png
# No tag for File
# No tag for Logo for Liberal Democratic Party of Russia.png
# No tag for 24 жніўня 1991.jpg
# No tag for LRAP un MP 1991. gada 19. augusta paziņojums.jpg
# No tag for PSRS Valsts padomes lēmums par Latvijas Republikas neatkarības atzīšanu.jpg
# No tag for Konstitucionālais likums Par Latvijas Republikas valstisko statusu.jpg
# There are 30 tags, 35 languages, 42 files, and 358 edges in the network

# %%
tag_d['Konstitucionālais_likums_Par_Latvijas_Republikas_valstisko_statusu.jpg']
# Out:
# ['IT-Passive Image',
#  'D-Non-human',
#  'GT-Documents/Communications',
#  'IF-Non-human',
#  'VI-Non-violent Image']

# %% [markdown]
# ### Image-lang-tag after all the unicode non-sense

# %%
all_coups_image_usage['1991 Soviet coup d\'état attempt']['en']
# Out:
# {'File:1991 coup attempt1.jpg': ['1991',
#   'Cold War',
#   "1991 Soviet coup d'état attempt",
#   'Dissolution of the Soviet Union'],
#  'File:1991 coup attempt4.jpg': ['T-80', "1991 Soviet coup d'état attempt"],
#  'File:Boris Yeltsin 19 August 1991-1.jpg': ['Russia',
#   'Soviet Union',
#   'White House (Moscow)',
#   "1991 Soviet coup d'état attempt",
#   'Alexander Korzhakov',
#   'Civil resistance',
#   'Boris Yeltsin',
#   'Dissolution of the Soviet Union'],
#  'File:Bush Gorba P15623-25A.jpg': ['George H. W. Bush',
#   'Cold War',
#   "1991 Soviet coup d'état attempt",
#   'Presidency of George H. W. Bush',
#   'List of Soviet Union–United States summits'],
#  'File:Logo for Liberal Democratic Party of Russia.png': ["1991 Soviet coup d'état attempt"]}

# %%
with open('image_tags.json','r') as f:
    tag_d = json.load(f)
    
for file,label_d in list(tag_d.items()):
    concated_file = unicodedata.normalize('NFKC',file)#.encode('utf8')
    tag_d[concated_file] = label_d
    #del tag_d[file]

# %%
len(tag_d)
# Out:
# 890

# %%
unicodedata.normalize('NFKC','Ülkü Ocakları Eğitim ve Kültür Vakfı Logosu.png')#.encode('utf8')
# Out:
# 'Ülkü Ocakları Eğitim ve Kültür Vakfı Logosu.png'

# %%
tag_d.keys()
# Out:
# dict_keys(['PozeRevolutia1989clujByRazvanRotta13.jpg', 'Mengistu_and_germame_Neway.jpg', "Hashem al Atta, 1971 Sudanese coup d'état.jpg", 'Pinochet en 1974.jpg', 'T-72 tank in Moscow, August 1991.jpg', 'Necmettin Erbakan.jpg', 'Ülkü Ocakları Eğitim ve Kültür Vakfı Logosu.png', 'Truman initiating Korean involvement.jpg', 'Gloria Macapagal-Arroyo, Davos.jpg', 'Nuamthong.jpg', 'RichardNixon.jpg', '2014 Suchum, Siedziba rządu i prezydenta Republiki Abchazji (04).jpg', 'Juntagovernativa1969.png', '1989 Iliescu television.jpg', 'Shaabanbimokh.jpg', 'Grave of Nicolae Ceausescu - Ghencea Civil Cemetery - Bucharest - Romania.jpg', 'HosseinFatemi2.jpg', 'Nasser, al-Bakr and Atassi, 1963.jpg', 'General Hafez al-Assad in 1970, during the Syrian Corrective Revolution.jpg', 'John L Throckmorton.jpg', 'NF 1978 - 1980.jpg', 'Tandja in Nigeria June 2007.jpg', 'Ayatmohagheghi.jpg', 'Boris Yeltsin 1993.jpg', 'Otelo.jpg', 'Order of the Red Banner.png', 'Bakkir.jpg', 'Madame Ngô Đình Nhu and Lyndon Baines Johnson.jpg', 'Russian Congressional Fractions 1993.png', 'Nouakchott-mosquee.jpg', 'Tentativa_de_golpe_de_Estado_na_Turquia.jpg', 'Carte gabon.png', 'Onganía-Levingston-Lanusse (Revolución Argentina).jpg', '1991-Barrikad-BelyDom.jpg', 'Military Committee celebrates 1963 coup.jpg', 'Iliescu si Bush.jpg', 'Day after Saur revolution in Kabul (773).jpg', 'Alejandro Agustín Lanusse.jpg', 'Elena Ceausescu portrait.jpg', 'Rifle AKS MON.jpg', 'CongressBuilding SEATO.jpg', 'Statul Major General.jpg', 'Samuel_K._Doe_During_the_1980_Coup.png', 'Air Commodore Kaiser Tufail receiving a memento from Commander of the Turkish Air Force General Akin Ozturk.jpg', 'Thai coup soldier.jpg', 'Boeing 727-2B6, Royal Air Maroc - RAM AN1217763.jpg', 'PFLP-group-1969.jpg', 'Alte. Pedro Gnavi.jpg', 'Secretary Kerry and Pakistani Advisor Aziz Address Reporters.jpg', 'Morande 80 11 septiembre 2009.jpg', 'Alte. Carlos G. N. Coda.jpg', 'Tom Thabane.jpg', 'The philosopher Zaki al-Arsuzi.jpg', 'Yeltsin 1993 cropped.jpg', 'Stamp of Afghanistan (1979) - Saur Revolution.jpg', 'BTR-60PB DA-ST-89-06597.jpg', 'Shield of the Kingdom of Portugal (1481-1910).png', 'Hun Sen crop.jpg', 'اعدام عبد الكريم قاسم وصحبه في دار الاذاعة.jpg', '28mordad1332.jpg', 'Fethullah Gülen cropped.jpg', 'Bundesarchiv Bild 183-1989-1221-032, Berlin, Demonstration für Rumänien.jpg', 'Chest badge Guards Russian Federation.png', 'Unidad Popular 1973.png', 'Romanian Revolution 1989 WeWillWin.jpg', 'Parlamentspalast_in_Bukarest.jpg', 'Chamlong Srimuang 2008-12-27.jpg', 'H.E. Mr. Mothetjoa Metsing, Deputy Prime Minister, Kingdom of Lesotho (8008839925) (cropped).jpg', 'Kirgizija.jpg', "Coup-d'etat-17.jpg", 'Zulfikar Ali Bhutto.jpg', 'حزب_الحرية_والعدالة.png', 'Гвардия.png', 'Northrop YF-5A (SN 59-4987) with a full load of bombs 060905-F-1234S-002.jpg', 'Africa satellite orthographic.jpg', 'Castelo de Guimarães (Portugal).jpg', '24_жніўня_1991.jpg', 'Togoland.png', 'Operationajax.jpg', 'Sidi Mohamed Ould Cheikh Abdallahi.jpg', 'Romanian Revolution 1989 Corpses.jpg', 'Makatisiege_ajescreenshot.jpg', 'David Ben Gurion - General Ne Win PM of Burma 1959.jpg', 'Teniente General(R)PistariniPascual.jpg', 'Mao Sihanouk.jpg', 'DYazov1989.jpg', 'MBKTürkeş.jpg', 'Niwatthamrong Boonsongpaisan at Ministerial Conference 2013 crop.jpg', 'BTR_25_april.jpg', 'Sallama.png', 'Praça 25 de Abril.jpg', 'Hugo Chávez (02-04-2010).jpg', 'TBMM coup attempt 15 June 2016.png', 'La Mano memory 40 years Chile dictatorship 1.jpg', 'BuiQuangThan.jpg', 'Νικος Σαμψών.jpg', 'Mohammad-reza-shah.jpg', 'Md2002 kramar.jpg', 'Guanabarasandbag.jpg', 'Soldier in Tahrir.jpg', 'Naguib.jpg', 'Morsi supporter after mass killings of 27-July-2013.jpg', "Sincan'dan_geçen_tanklar.jpg", 'San Carlos military stockade - Venezuela.jpg', 'Tokat darbe karşıtları.png', 'Burnt out buildings on nothern edge of Revolution Square, Bucharest.jpg', 'Tanks_approach_the_Ataturk_airport.jpg', 'Bundesarchiv B 145 Bild-F013047-0040, München, Staatsbesuch Pra ...

# %%
all_coup_g = nx.DiGraph()

for coup, coup_d in all_coups_image_usage.items():
    for lang, lang_d in coup_d.items():
        for file, file_l in lang_d.items():
            f = file.split(':')[1]
            all_coup_g.add_edge(lang,f,kind='lang-file')
            all_coup_g.add_node(lang,kind='lang')
            all_coup_g.add_node(f,kind='file')
            try:
                for tag in tag_d[f]:
                    all_coup_g.add_edge(tag,f,kind="tag-file")
                    all_coup_g.add_node(tag,kind='tag')
            except KeyError:
                print("No tag for {0}".format(f))
                pass

all_coup_tags = [n for n,d in all_coup_g.nodes(data=True) if d['kind'] == 'tag']
all_coup_langs = [n for n,d in all_coup_g.nodes(data=True) if d['kind'] == 'lang']
all_coup_files = [n for n,d in all_coup_g.nodes(data=True) if d['kind'] == 'file']

print("""There are {0:,} tags, {1:,} languages, {2:,} files, and {3:,} edges in the network
""".format(len(all_coup_tags),
           len(all_coup_langs),
           len(all_coup_files),
           all_coup_g.number_of_edges()))

nx.write_gexf(all_coup_g,'all_coups.gexf')
# Out:
# No tag for Bakr.jpg
# No tag for Aref abderazak.jpg
# No tag for Last day qasim.jpg
# No tag for Taher yahya.jpg
# No tag for Казнь Касема.jpg
# No tag for Burkinabé uprising at Place de la Nation.jpg
# No tag for The Bangkok Post, September 20, 2006.jpg
# No tag for The nation 200506.jpg
# No tag for King CDRM L.jpg
# No tag for 21438 010.jpg
# No tag for Plevne Marşı pul.jpg
# No tag for 27 Mayıs Darbesi sembolü.png
# No tag for Bundesarchiv Bild 183-55823-0005, Berlin, Karl-Marx-Allee, "Deutsche Sporthalle".jpg
# No tag for Bundesarchiv Bild 183-55823-0005, Berlin, Karl-Marx-Allee, "Deutsche Sporthalle".jpg
# No tag for Bundesarchiv Bild 183-55823-0005, Berlin, Karl-Marx-Allee, "Deutsche Sporthalle".jpg
# No tag for 1 Turkish lira-Deads in 15 July.jpg
# No tag for Won Democracy Turkey.jpg
# No tag for KYK 15 Temmuz sergisi.jpg
# No tag for Maslak 15 July Occupy residential.jpg
# No tag for مذيعة قناة تي آر تي.jpg
# No tag for صورة دبابات الإنقلابيين العسكريين التركيين.jpg
# No tag for صورة ذبابات الإنقلابيين العسكريين التركيين.jpg
# No tag for Tanks approach the Ataturk airport.jpg
# No tag for სამხედრო გადატრიალების მცდელობა.png
# No tag for Tanks approach the Ataturk airport.jpg
# No tag for Tentativa de golpe de Estado na Turquia.jpg
# No tag for Samuel K. Doe During the 1980 Coup.png
# No tag for Weeks featured article.png
# No tag for Arms of Fiji 2.png
# No tag for P technology.png
# No tag for Iran NF.jpg
# No tag for 59mossadeghprime minister1951.jpg
# No tag for W.gl.GolpeEstadoIran1953.png
# No tag for Chile Junta001.jpg
# No tag for Chile Junta001.jpg
# No tag for Salvador Alyendenin son foto şəkili.jpg
# No tag for Allende son.jpg
# No tag for Genesis FUBELT.jpg
# No tag for Francois Duvalier during 1958 coup attempt.jpg
# No tag for Algiers putsch 1961.jpg
# No tag for Algiers putsch 1961.jpg
# No tag for Arms of Fiji 2.png
# No tag for Qasim arif.jpg
# No tag for Defence.jpg
# No tag for Barzani & Qasim.jpg
# No tag for Colosseum-2003-07-09.jpg
# No tag for Lon Nol, Sisowath Sirik Matak, In Tam.jpg
# No tag for People Power Revolution commemorative 10-peso coin obverse and reverse.png
# No tag for EDSA Revolution pic1.jpg
# No tag for EDSA Revolution pic1.jpg
# No tag for Ninoy Aquino's "Testament from Prison Cell" signed by Cory Aquino in 1983.jpg
# No tag for EDSA Revolution pic1.jpg
# No tag for EDSA Revolution pic1.jpg
# No tag for حزب النور.png
# No tag for General Al-Sisi, announcing the removal of President Morsi.png
# No tag for حزب الحرية والعدالة.png
# No tag for Freedom and Justice Party (Egypt).jpg
# No tag for General Al-Sisi, announcing the removal of President Morsi.png
# No tag for FJP.png
# No tag for General el Sisi Mursiyi görevden alındığını açıklarken.png
# No tag for Chavez başarısız darbeden sonra göreve dönerken 13 Nisan 2002.jpg
# No tag for Pedro Carmona 2002 darbesinden sonra yemin töreninde.jpg
# No tag for Arms of Fiji 2.png
# No tag for Presidential Standard of South Vietnam (1955-1963).png
# No tag for V. Landsbergis. Viešoji informacija.jpg
# No tag for Gloriosa victoria.jpg
# No tag for Mayıs 1981 Kenan Evren Ankaragücü kaptanı Adil Eriç'e Türkiye Kupası'nı veriyor.jpg
# No tag for Newsweek 22 Eylül 1980 kapak.jpg
# No tag for Povo mfa.jpg
# No tag for P history.png
# No tag for P history.png
# No tag for BTR 25 april.jpg
# No tag for Lissabon 25 april.jpg
# No tag for Bophuthatswana coup Execution.jpg
# No tag for Reform the Armed Forces Movement logo circa 1990s.png
# No tag for Operacio marverde.jpg
# No tag for Nasser Gaddafi 1969.jpg
# No tag for Insigne Romanicum II.png
# No tag for Manifest revolutie 1989.jpg
# No tag for Parlamentspalast in Bukarest.jpg
# No tag for WikiLettera.png
# No tag for พลเอกประยุทธ์ประกาศยึดอำนาจ22 พฤษภาคม 2557.png
# No tag for P Russia.png
# No tag for Logo for Liberal Democratic Party of Russia.png
# No tag for 24 жніўня 1991.jpg
# No tag for Logo for Liberal Democratic Party of Russia.png
# No tag for 1991 coup yeltsin.jpg
# No tag for Dzerzhinsky Statue, which once dominated Lyubianka Square.jpg
# No tag for File
# No tag for Logo for Liberal Democratic Party of Russia.png
# No tag for PSRS Valsts padomes lēmums par Latvijas Republikas neatkarības atzīšanu.jpg
# No tag for LRAP un MP 1991. gada 19. augusta paziņojums.jpg
# No tag for Konstitucionālais likums Par Latvijas Republikas valstisko statusu.jpg
# No tag for 1991 coup yeltsin.jpg
# No tag for Amadou Toumani Touré 30 नवम्बर 2011.jpg
# No tag for Tanques Venezuela 1958.jpg
# No tag for Mengistu & Merid.jpg
# No tag for Mengistu and germame Neway.jpg
# No tag for Portrait Habib Bourguiba.jpg
# No tag for Zine El Abidine Ben Ali.jpg
# No tag for Golpe de 1964.jpg
# No tag for Golpe de 1964.jpg
# No tag for Vista-kmixdocked.png
# No tag for Trial iraq.jpg
# No tag for 1993 Tanks before Russian White house.jpg
# No tag for Supreme Soviet of Russia meeting (1993).png
# No tag for Tanks before Russian White house.jpg
# No tag for Tanks before Russian White house.jpg
# No tag for P Russia.png
# No tag for Расстрел белого дома в 1993 году.jpg
# No tag for Silk-film.png
# No tag for 1993 Rusya anayasa krizi sırasında Parlamento yanlısı göstericiler.jpg
# No tag for 4 Ekim 1993 Rusya Parlamento binası alevler içinde.jpg
# There are 39 tags, 78 languages, 747 files, and 27,052 edges in the network

# %% [markdown]
# ### Clustering

# %%
top_langs_proj_image_lang_usage_adj = np.log(nx.adj_matrix(proj_image_lang_usage_g,nodelist=top_languages).todense()+1)
top_languages = ['en','de','fr','ja','es','ru','it','zh','pt','pl','nl','uk','fa','he','ko','ar','sv','cs','tr']
top_langs_proj_image_lang_usage_df = pd.DataFrame(data=top_langs_proj_image_lang_usage_adj, index=top_languages, columns=top_languages)
sb.clustermap(top_langs_proj_image_lang_usage_df,cmap='coolwarm')
#plt.tight_layout()
plt.savefig('lang_image_similarity.pdf')

# %%
multiindexable_d = {}
for topic, topic_d in all_coups_image_usage.items():
    for lang, file_d  in topic_d.items():
        multiindexable_d[(topic, lang)] = len(file_d)

# %%
creation_year_s = rev_df.groupby(['parent_topic','lang']).agg({'year':np.min})['year']
creation_year_df = pd.DataFrame({'Year':creation_year_s,'Images':pd.Series(multiindexable_d)})
creation_year_df.reset_index(inplace=True)
creation_year_df.rename(columns={'level_0':'Topic','level_1':'Language'},inplace=True)
lang_subset_creation_year_df = creation_year_df[creation_year_df['Language'].isin(['en','de','fr','ja','es','ru','it','zh','pt','pl','nl','uk','fa','he','ko','ar','sv','cs','tr'])]

# %%
lang_subset_ct = pd.crosstab(index = lang_subset_creation_year_df['Language'],
                             columns = lang_subset_creation_year_df['Year'],
                             values = lang_subset_creation_year_df['Images'],
                             aggfunc = np.sum)
lang_subset_ct = lang_subset_ct.fillna(0).ix[['en','de','fr','ja','es','ru','it','zh','pt','pl','nl','uk','fa','he','ko','ar','sv','cs','tr']]
lang_subset_ct.columns = range(2002,2018)
sb.heatmap(lang_subset_ct,square=True,cmap='coolwarm')

# %% [markdown]
# ## Interlanguage links

# %%
with open("all_coups_interlanguage_links.json",'r') as f:
    coup_interlanguage_links = json.load(f)

# %%
lang_link_g = nx.Graph()

for event, lang_d in coup_interlanguage_links.items():
    for lang1, link_d in lang_d.items():
        for link, langlink_d in link_d.items():
            for lang2, langlink in langlink_d.items():
                if lang_link_g.has_edge(lang1,lang2) and lang1 != lang2:
                    lang_link_g[lang1][lang2]['weight'] += 1
                elif lang1 != lang2:
                    lang_link_g.add_edge(lang1,lang2,weight=1)
                
print("There are {0:,} nodes and {1:,} edges in the network".format(lang_link_g.number_of_nodes(),lang_link_g.number_of_edges()))
# Out:
# There are 291 nodes and 20,939 edges in the network

# %%
lang_link_g.to_undirected().edge['et']['ceb']
# Out:
# {'weight': 79}

# %% [markdown]
# ## External links

# %%
with open('all_coups_extlinks_usage.json','r') as f:
    external_links_usage = json.load(f)

# %%
lang_ext_link_g = nx.DiGraph()
language_list = []

for event, lang_d in external_links_usage.items():
    for lang, url_d in lang_d.items():
        language_list.append(lang)
        for url, count in url_d.items():
            if lang_ext_link_g.has_edge(lang,url):
                lang_ext_link_g[lang][url]['weight'] += count
            else:
                lang_ext_link_g.add_edge(lang,url,weight=count)
                
print("There are {0:,} nodes and {1:,} edges in the network".format(lang_ext_link_g.number_of_nodes(),lang_ext_link_g.number_of_edges()))

proj_lang_ext_link_g = nx.bipartite.weighted_projected_graph(lang_ext_link_g.to_undirected(),nodes=list(set(language_list)))
print("There are {0:,} nodes and {1:,} edges in the network".format(proj_lang_ext_link_g.number_of_nodes(),
                                                                    proj_lang_ext_link_g.number_of_edges()))
# Out:
# There are 2,867 nodes and 6,600 edges in the network
# There are 81 nodes and 2,345 edges in the network

# %% [markdown]
# ## Combine graphs

# %%
def to_pandas_edgelist(G):
    edges_d = G.edges(data=True)
    _df = pd.DataFrame(edges_d)
    _df[2] = _df[2].apply(lambda x:x['weight'])
    _df.rename(columns={0:'lang1',1:'lang2',2:'weight'},inplace=True)
    _df.set_index(['lang1','lang2'],inplace=True)
    return _df

# %%
ext_link_el_s = to_pandas_edgelist(proj_lang_ext_link_g)['weight']
iwiki_link_el_s = to_pandas_edgelist(lang_link_g)['weight']
image_usage_el_s = to_pandas_edgelist(proj_image_lang_usage_g)['weight']
editor_revs_el_s = to_pandas_edgelist(proj_lang_rev_g)['weight']

link_strength_df = pd.DataFrame({'External':ext_link_el_s,'Internal':iwiki_link_el_s,'Images':image_usage_el_s,'Editors':editor_revs_el_s})
link_strength_df.dropna(subset=['Images'],inplace=True)
link_strength_df.fillna(0,inplace=True)
link_strength_df.reset_index(inplace=True)
link_strength_df.to_csv('link_strength.csv',index=False)
print(len(link_strength_df))
link_strength_df.head()
# Out:
# 1141
#   lang1 lang2  Editors  External  Images  Internal
# 0    af    en      0.0       1.0     1.0       0.0
# 1    ar    da     20.0      12.0     2.0     912.0
# 2    ar    de      0.0      38.0    14.0       0.0
# 3    ar    eo      0.0       4.0     1.0       0.0
# 4    ar    es     31.0      48.0    16.0    3763.0

# %% [markdown]
# ## Image tag clustering

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools

#from __future__ import print_function

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import seaborn as sn
from kmodes.kmodes import KModes
from sklearn.cluster import DBSCAN
from sklearn import metrics

# %%
# Read in file
image_tags_df = pd.read_excel('!image_tags.xls')

# Only include columns with "Code"
_cols = ['Title'] + [c for c in image_tags_df.columns if 'Code:' in c]
image_tags_df = image_tags_df[_cols]

# Exclude columns where there are no coded values
bad_cols = image_tags_df.sum()[image_tags_df.sum() == 0].index
image_tags_df = image_tags_df[[c for c in image_tags_df.columns if c not in bad_cols]]

# Only include tags where both coders agree
#image_tags_df = image_tags_df.replace({1:0}).replace({2:1})

# Rename columns
image_tags_df.columns = [c[6:] for c in image_tags_df.columns]

# Set index
image_tags_df.rename(columns={'':'image'},inplace=True)
image_tags_df.set_index('image',inplace=True)

len(image_tags_df)
# Out:
# 766

# %%
# with open('image_tags.json','r') as f:
#     image_tags = json.load(f)
    
# image_tags_df = pd.DataFrame(image_tags).T
# image_tags_ri_df = image_tags_df.reset_index()
# len(image_tags_df)
# Out:
# 774

# %%
image_tags_df.to_csv('!EP_tags_cleaned.csv',encoding='utf8')

# %% [markdown]
# ## KMode

# %%
#little buddy test plots 

X_scaled=image_tags_df
plot_thing = []

for n_clusters in range(2,6):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)
    print ('!!**Trial Number '+ str(n_clusters))

  # The 1st subplot is the silhouette plot
  # The silhouette coefficient can range from -1, 1 but in this example all
  # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
  # The (n_clusters+1)*10 is for inserting blank space between silhouette
  # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X_scaled) + (n_clusters + 1) * 10])
    
    clusterer = KModes(n_clusters=n_clusters, init='Cao', n_init=5, verbose=1)

    cluster_labels = clusterer.fit_predict(X_scaled)
    
    # The silhouette_score gives the average value for all the samples.
  # This gives a perspective into the density and separation of the formed
  # clusters
    silhouette_avg = silhouette_score(X_scaled, cluster_labels)
    
    plot_thing.append("For n_clusters =" + str(n_clusters)+
        " and the average silhouette_score is :"+ str(silhouette_avg))
    
  # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X_scaled, cluster_labels)
    
    
   
    y_lower = 10
    for i in range(n_clusters):
      # Aggregate the silhouette scores for samples belonging to
      # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.Spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                        0, ith_cluster_silhouette_values,
                        facecolor=color, edgecolor=color, alpha=0.7)
        
        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        
        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples
        
    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")
    
    # The vertical line for average silhoutte score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

  # 2nd Plot showing the actual clusters formed
    colors = cm.Spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X_scaled.values[:, 0], X_scaled.values[:, 1], marker='.', s=30, lw=0, alpha=0.7,
              c=colors)

    # Labeling the clusters
    centers = clusterer.cluster_centroids_
  # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1],
              marker='o', c="white", alpha=1, s=200)
    
    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1, s=50)
        
    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                "with n_clusters = %d" % n_clusters),
               fontsize=14, fontweight='bold')
    
    plt.show()

print(plot_thing)
# Out:
# !!**Trial Number 2
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 38, cost: 5097.0
# Run 1, iteration: 2/100, moves: 0, cost: 5097.0
# !!**Trial Number 3
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 87, cost: 4494.0
# Run 1, iteration: 2/100, moves: 28, cost: 4494.0
# !!**Trial Number 4
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 93, cost: 4366.0
# Run 1, iteration: 2/100, moves: 10, cost: 4366.0
# !!**Trial Number 5
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 109, cost: 4343.0
# Run 1, iteration: 2/100, moves: 10, cost: 4343.0
# ['For n_clusters =2 and the average silhouette_score is :0.2836222959388101', 'For n_clusters =3 and the average silhouette_score is :0.2852094653125477', 'For n_clusters =4 and the average silhouette_score is :0.3116871157648232', 'For n_clusters =5 and the average silhouette_score is :0.29064169524593286']

# %%
# Step 1: Choose your model class(es)
from sklearn.decomposition import PCA

# Step 2: Instantiate your model class(es)
pca = PCA(n_components=2)

# Step 3: Arrange data into features matrices
#image_tags_df

# Step 4: Fit the data and transform
X_pca = pca.fit_transform(image_tags_df)

# Plot the data
f,ax = plt.subplots(1,1,figsize=(9,6))
ax.scatter(X_pca[:,0],X_pca[:,1])

# for i,txt in enumerate(whr_2017_df['country'].values):
#     if txt == 'United States':
#         ax.annotate(txt,(X_pca[i,0],X_pca[i,1]),color='red',fontweight='bold')
#     else:
#         ax.annotate(txt,(X_mds[i,0],X_mds[i,1]))

# %%
# Step 1: Choose your model class(es)
from sklearn.manifold import MDS

# Step 2: Instantiate your model class(es)
mds = MDS(n_components=2)

# Step 3: Arrange data into features matrices
# Done!

# Step 4: Fit the data and transform
X_mds = mds.fit_transform(image_tags_df)

# Plot the data
f,ax = plt.subplots(1,1,figsize=(9,6))
ax.scatter(X_mds[:,0],X_mds[:,1])

# for i,txt in enumerate(whr_2017_df['country'].values):
#     if txt == 'United States':
#         ax.annotate(txt,(X_mds[i,0],X_mds[i,1]),color='red',fontweight='bold')
#     else:
#         ax.annotate(txt,(X_mds[i,0],X_mds[i,1]))

# %%
# Step 1: Choose your model class(es)
from sklearn.manifold import Isomap

# Step 2: Instantiate your model class(es)
iso = Isomap(n_neighbors = 5, n_components = 2)

# Step 3: Arrange data into features matrices
# Done!

# Step 4: Fit the data and transform
X_iso = iso.fit_transform(image_tags_df)


# Plot the data
f,ax = plt.subplots(1,1,figsize=(9,6))
ax.scatter(X_iso[:,0],X_iso[:,1])


# for i,txt in enumerate(whr_2017_df['country'].values):
#     if txt == 'United States':
#         ax.annotate(txt,(X_iso[i,0],X_iso[i,1]),color='red',fontweight='bold')
#     else:
#         ax.annotate(txt,(X_iso[i,0],X_iso[i,1]))

# %%
# Step 1: Choose your model class(es)
from sklearn.manifold import SpectralEmbedding

# Step 2: Instantiate your model class(es)
se = SpectralEmbedding(n_components = 2)

# Step 3: Arrange data into features matrices
# Done!

# Step 4: Fit the data and transform
X_se = se.fit_transform(image_tags_df)


# Plot the data
f,ax = plt.subplots(1,1,figsize=(9,6))
ax.scatter(X_se[:,0],X_se[:,1])

# for i,txt in enumerate(whr_2017_df['country'].values):
#     if txt == 'United States':
#         ax.annotate(txt,(X_se[i,0],X_se[i,1]),color='red',fontweight='bold')
#     else:
#         ax.annotate(txt,(X_se[i,0],X_se[i,1]))

# %%
# Step 1: Choose your model class(es)
from sklearn.manifold import TSNE

# Step 2: Instantiate your model class(es)
tsne = TSNE(n_components = 2, perplexity=30, n_iter=5000,learning_rate =30, random_state=42)
#tsne = TSNE(n_components = 2, metric='euclidean', init='pca')#, random_state=42)

# Step 3: Arrange data into features matrices
# Done!

# Step 4: Fit the data and transform
X_tsne = tsne.fit_transform(image_tags_df)

# %%
num_classes = len(np.unique(colors))
palette = np.array(sns.color_palette("hls", num_classes))
f,ax = plt.subplots(1,1,figsize=(9,6))
ax.scatter(X_tsne[:, 0], X_tsne[:, 1], c=palette[colors.astype(np.int)], cmap='nipy_spectral',alpha=1)
ax.grid(None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-1b08e67750ec> in <module>()
#       1
# ----> 2 palette = np.array(sns.color_palette("hls", num_classes))
#       3 f,ax = plt.subplots(1,1,figsize=(9,6))
#       4 ax.scatter(X_tsne[:, 0], X_tsne[:, 1], c=palette[colors.astype(np.int)], cmap='nipy_spectral',alpha=1)
#       5 ax.grid(None)
#
# NameError: name 'num_classes' is not defined

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

sil_score = {}

for n in range(2,21):
    _model = KMeans(n_clusters=n)
    y = _model.fit_predict(X_tsne)
    sil_score[n] = silhouette_score(X_tsne,y)
    
ax = pd.Series(sil_score).plot()
ax.set_xticks(range(2,21));
ax.set_ylim((.4,1))
# Out:
# /Users/emilyporter/anaconda3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py:257: RuntimeWarning:
#
# invalid value encountered in sqrt
# (0.4, 1)

# %%
# Compute clusters
kmeans_clusters = KMeans(n_clusters=15)
kmeans_clusters.fit(X_tsne)
y_kmeans_clusters = kmeans_clusters.predict(X_tsne)
#image_tags_df['cluster'] = y_kmeans_clusters

repeated_image_tags_df = image_tags_df.reset_index()
repeated_image_tags_df['cluster'] = y_kmeans_clusters
repeated_image_tags_df['tsne_0'] = X_tsne[:,0]
repeated_image_tags_df['tsne_1'] = X_tsne[:,1]

# Visualize
f,ax = plt.subplots(1,1,figsize=(9,6))
ax.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y_kmeans_clusters, cmap='nipy_spectral',alpha=1)
ax.grid(None)

for cluster in range(kmeans_clusters.n_clusters):
    plt.annotate(str(cluster), 
                 (kmeans_clusters.cluster_centers_[cluster, 0], kmeans_clusters.cluster_centers_[cluster, 1]),
                 size=50
                );
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
#ax.set_ylim((-50,60))
f.tight_layout()
f.savefig('tsne.pdf')

# %%
repeated_image_tags_df.groupby('cluster').agg({'image':len})
# Out:
#          image
# cluster
# 0           23
# 1           44
# 2           33
# 3           85
# 4           84
# 5          122
# 6           19
# 7           59
# 8           76
# 9           55
# 10          50
# 11          59
# 12          13
# 13          19
# 14          25

# %%
def df_euclidean(x):
    return euclidean([x['tsne_0'],x['tsne_1']],kmeans_clusters.cluster_centers_[x['cluster']])

repeated_image_tags_df['distance'] = repeated_image_tags_df.apply(lambda x:df_euclidean(x),axis=1)
representative_images = repeated_image_tags_df.loc[repeated_image_tags_df.groupby('cluster')['distance'].idxmin(),'image'].values
representative_images
# Out:
# array(['Location of Abkhazia in Europe2.png',
#        'Romanian Revolution 1989 Corpses.jpg',
#        'AngkorWat Delaporte1880.jpg',
#        'Civilian with PM Md. 1963 during the Romanian....jpg',
#        'Çevik Bir DD-SD-00-01007.jpg', 'David Dacko 1962 crop.jpg',
#        'Oubangui-Chari.jpg',
#        'George H. W. Bush and Boris Yeltsin 1993.jpg',
#        '1991-Barrikad-BelyDom.jpg',
#        'Presidential Standard of South Vietnam (1955-1963).png',
#        "Coup-d'etat-9-web-cnni.jpg", 'Sputnik asm.jpg',
#        'صورة دبابات الإنقلابيين العسكريين التركيين.jpg',
#        'Tandja in Nigeria June 2007.jpg', 'Yameogo stamp 1960.png'],
#       dtype=object)

# %%
f,axs = plt.subplots(2,3,figsize=(9,6))

pos = 0

for r,row in enumerate(axs):
    for i,item in enumerate(row):
        try:
            im = plt.imread(_dir + 'Images/{0}'.format(representative_images[pos]))
            axs[r,i].imshow(im)
            axs[r,i].grid(None)
            axs[r,i].xaxis.set_visible(False)
            axs[r,i].yaxis.set_visible(False)
            axs[r,i].set_title(pos,size=25)
            pos += 1
        except:
            im = plt.imread(_dir + 'Images/image_0.jpg')
            axs[r,i].imshow(im)
            axs[r,i].grid(None)
            axs[r,i].xaxis.set_visible(False)
            axs[r,i].yaxis.set_visible(False)
            axs[r,i].set_title(pos,size=25)
            pos += 1
            pass
        
f.tight_layout()
f.savefig('tsne_cluster_images.pdf',dpi=600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-146-ecb51e6da38f> in <module>()
#       7         try:
# ----> 8             im = plt.imread(_dir + 'Images/{0}'.format(representative_images[pos]))
#       9             axs[r,i].imshow(im)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in imread(*args, **kwargs)
#    2253 def imread(*args, **kwargs):
# -> 2254     return _imread(*args, **kwargs)
#    2255
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in imread(fname, format)
#    1301     if ext not in handlers:
# -> 1302         im = pilread(fname)
#    1303         if im is None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in pilread(fname)
#    1279             return None
# -> 1280         with Image.open(fname) as image:
#    1281             return pil_to_array(image)
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2542     if filename:
# -> 2543         fp = builtins.open(filename, "rb")
#    2544         exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:/Dropbox/Workspace/Wikipedia_images/Images/Portugallia et Algarbia.jpg'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-146-ecb51e6da38f> in <module>()
#      14             pos += 1
#      15         except:
# ---> 16             im = plt.imread(_dir + 'Images/image_0.jpg')
#      17             axs[r,i].imshow(im)
#      18             axs[r,i].grid(None)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in imread(*args, **kwargs)
#    2252 @docstring.copy_dedent(_imread)
#    2253 def imread(*args, **kwargs):
# -> 2254     return _imread(*args, **kwargs)
#    2255
#    2256
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in imread(fname, format)
#    1300
#    1301     if ext not in handlers:
# -> 1302         im = pilread(fname)
#    1303         if im is None:
#    1304             raise ValueError('Only know how to handle extensions: %s; '
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in pilread(fname)
#    1278         except ImportError:
#    1279             return None
# -> 1280         with Image.open(fname) as image:
#    1281             return pil_to_array(image)
#    1282
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2541
#    2542     if filename:
# -> 2543         fp = builtins.open(filename, "rb")
#    2544         exclusive_fp = True
#    2545
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:/Dropbox/Workspace/Wikipedia_images/Images/image_0.jpg'

# %% [markdown]
# ## Image usage

# %%
with open('all_coups_extlinks_usage.json','r') as f:
    external_links_usage = json.load(f)
    
with open('all_coups_file_image_usage.json','r') as f:
    all_coups_image_usage = json.load(f)
    
with open("all_coups_interlanguage_links.json",'r') as f:
    coup_interlanguage_links = json.load(f)

event_year_df = pd.read_csv('event_year.csv',encoding='utf8')

cols = ['IT-Active Image', 'IT-Passive Image',
        'D-Adult Male', 'D-Adult Female', 'D-Child Male', 'D-Child Female', 'D-Non-human', 
        'FE-Frown', 'FE-Smile', 
        'FPI-Foriegn Leaders', 'FPI-Foriegn Symbols',
        'GT-Alleged Atrocities', 'GT-Buildings', 'GT-Celebration', 'GT-Protest/Demonstration', 'GT-Destruction', 'GT-Diplomatic and Other Official Actions', 'GT-Documents/Communications', 'GT-Humanitarian Aid', 'GT-Locations/Maps/Infographics', 'GT-Memorials', 'GT-Military Actions', 'GT-Military Technology and Weaponry', 'GT-POWs', 'GT-Policing', 'GT-Portrait', 'GT-Signs/Symbols', 'GT-Suffering',
        'IF-Individual', 'IF-Group', 'IF-Individual in Relation to the Group', 'IF-Non-human',
        'TOP-Civilians', 'TOP-Journalists', 'TOP-Military or Political Leaders', 'TOP-Military Personnel', 'TOP-Police',
        'VI-Non-violent Image', 'VI-Violent Image']

# %%
topic_external_link_count_d = {}
for topic,topic_d in external_links_usage.items():
    for lang,lang_d in topic_d.items():
        topic_external_link_count_d[(topic,lang)] = len(lang_d)
        
topic_images_count_d = {}
for topic,topic_d in all_coups_image_usage.items():
    for lang,lang_d in topic_d.items():
        topic_images_count_d[(topic,lang)] = len(lang_d)
        
topic_internal_links_count_d = {}
for topic,topic_d in coup_interlanguage_links.items():
    for lang,lang_d in topic_d.items():
        topic_internal_links_count_d[(topic,lang)] = len(lang_d)

# %%
topic_external_link_count_df = pd.Series(topic_external_link_count_d).reset_index()
topic_external_link_count_df.columns = ['parent_topic','lang','external_links']

topic_images_count_df = pd.Series(topic_images_count_d).reset_index()
topic_images_count_df.columns = ['parent_topic','lang','images']

topic_internal_links_count_df = pd.Series(topic_images_count_d).reset_index()
topic_internal_links_count_df.columns = ['parent_topic','lang','internal_links']

# %%
_agg_func = {'user':pd.Series.nunique,'sha1':pd.Series.nunique,'size':np.max,'year':np.min}
topic_lang_activity_df = rev_df.groupby(['parent_topic','lang']).agg(_agg_func).reset_index()

image_usage_df = pd.merge(topic_lang_activity_df,topic_external_link_count_df,
                          left_on=['parent_topic','lang'],right_on=['parent_topic','lang'],how='outer')
image_usage_df = pd.merge(image_usage_df,topic_images_count_df,
                          left_on=['parent_topic','lang'],right_on=['parent_topic','lang'],how='outer')
image_usage_df = pd.merge(image_usage_df,topic_internal_links_count_df,
                          left_on=['parent_topic','lang'],right_on=['parent_topic','lang'],how='outer')
image_usage_df = pd.merge(image_usage_df,event_year_df,
                          left_on=['parent_topic'],right_on=['parent_topic'],how='outer')

image_usage_df.fillna(0,inplace=True)
#image_usage_df['event_year'] = image_usage_df['parent_topic'].str.extract(r'(\d{4})')
image_usage_df.columns = ['topic','lang','editors','revisions','size','created','external','images','internal','event']
image_usage_df['delay'] = image_usage_df['created'] - image_usage_df['event']
image_usage_df['has_image'] = (image_usage_df['images'] > 0).apply(int)
image_usage_df.head()
# Out:
#                 topic lang  editors  revisions    size  created  external  \
# 0  17 July Revolution   ar     29.0       54.0  7128.0   2007.0       0.0
# 1  17 July Revolution   bn      2.0        3.0  5521.0   2015.0       1.0
# 2  17 July Revolution   en     39.0       91.0  7593.0   2011.0       2.0
# 3  17 July Revolution   es      3.0        4.0  2442.0   2014.0       2.0
# 4  17 July Revolution   ja      5.0        5.0  4118.0   2013.0       1.0
#
#    images  internal  event  delay  has_image
# 0     0.0       0.0   1968   39.0          0
# 1     0.0       0.0   1968   47.0          0
# 2     0.0       0.0   1968   43.0          0
# 3     0.0       0.0   1968   46.0          0
# 4     0.0       0.0   1968   45.0          0

# %%
all_coups_image_usage['1991 Soviet coup d\'état attempt']['en'].keys()
# Out:
# dict_keys(['File:Boris Yeltsin 19 August 1991-1.jpg', 'File:Logo for Liberal Democratic Party of Russia.png', 'File:Bush Gorba P15623-25A.jpg', 'File:1991 coup attempt4.jpg', 'File:1991 coup attempt1.jpg'])

# %%
image_tags
# Out:
# {'Salah Bitar.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'Desi Bouterse.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 1,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 1,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'National Revolutionary Command Council (Sudan).jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 1,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 1,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  '2009 Honduras political crisis 9.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 0,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 1,
#   'GT-Policing': 0,
#   'IT-Active Image': 1,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 1,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 1,
#   'IF-Group': 1,
#   'GT-Buildings': 1,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'By-map.png': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 1,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Iskander Mirza.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'EDSA_Revolution_pic1.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 0,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 1,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 1,
#   'IF-Group': 1,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Iraq14.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 1,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Assemblee Nationale Burkina Faso.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 1,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Nguyễn Khánh 1964.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'BKK24090602.jpg': {'GT-Military Technology and Weaponry': 1,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 1,
#   'GT-Policing': 1,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 1,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 1,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 1,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 1,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Bundesarchiv_Bild_183-55823-0005,_Berlin,_Karl-Marx-Allee,_-Deutsche_Sporthalle-.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 0,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 1,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 1,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 1,
#   'IF-Group': 0,
#   'GT-Buildings': 1,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Thaksin.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 1,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'TBMM coup attempt 15 June 2016.png': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 0,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 1,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 1,
#   'IF-Group': 1,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Major-general-lansdale.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'Turkish protesters in Istanbul.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 0,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 1,
#   'GT-Policing': 0,
#   'IT-Active Image': 1,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 0,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 1,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 1,
#   'IF-Group': 1,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Central african republic sm04ESP.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 1,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Расстрел_белого_дома_в_1993_году.jpg': {'GT-Military Technology and Weaponry': 1,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 0,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 1,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 1,
#   'GT-Military Actions': 1,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 1,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Un-pakistan.png': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 1,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Ponte25Abril1.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 1,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Mercator Africa 037.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 1,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Hulusi Akar (cropped).jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'Stamp Fiji 1959 2 6 Nadi Airport.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 1,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 1,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 1,
#   'GT-Portrait': 0},
#  'Estadio nacional-Chile.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 1,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Chamlong Srimuang 2008-12-27.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 1,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  "Coup-d'etat-14-web-cnni.jpg": {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 1,
#   'GT-Celebration': 1,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 1,
#   'TOP-Military Personnel': 1,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'President Eisenhower and John Foster Dulles in 1956.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 1,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 1,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Onganía-Levingston-Lanusse (Revolución Argentina).jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'Dvorec 27 12 79.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 1,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Ahmed el-Tayeb May 2015 (17963337671).jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'Tulip 2.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Syrien 1961 0003.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 1,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  '2014 Suchum, Siedziba rządu i prezydenta Republiki Abchazji (04).jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 1,
#   'IF-Individual in Relation to the Group': 1,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Shahanshah1333.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'The Four Voyages of Columbus 1492-1503 - Project Gutenberg etext 18571.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 1,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'RafiqArif.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'Tanques_Venezuela_1958.jpg': {'GT-Military Technology and Weaponry': 1,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 0,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 1,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 0,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 1,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 1,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 1,
#   'IF-Group': 1,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Freedom_and_Justice_Party_(Egypt).jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 1,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Lechfeld Elite 2008 144 (2663713634).jpg': {'GT-Military Technology and Weaponry': 1,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'TRT Ankara.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 1,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 1,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'Mengistu_and_germame_Neway.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 1,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 1,
#   'GT-Portrait': 1},
#  'Faisal hussein.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 1,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 1,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  '4.19 혁명.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 0,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 1,
#   'GT-Policing': 0,
#   'IT-Active Image': 1,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 1,
#   'IF-Group': 1,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  '장도영.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'LRAP_un_MP_1991._gada_19._augusta_paziņojums.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 1,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 1,
#   'GT-Portrait': 0},
#  'Konstitucionālais_likums_Par_Latvijas_Republikas_valstisko_statusu.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
# ...
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'Satellite image of Cyprus, cropped.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 1,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Dead No Coup 2016.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 0,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 1,
#   'GT-Policing': 0,
#   'IT-Active Image': 1,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 1,
#   'IF-Group': 1,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  '"De Historische Strijd" Herdenkingsmonument revolutie 25 februari 1980 - Nieuw-Amsterdam - 20418126 - RCE.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 1,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'President of Kyrgyzstan, Kurmanbek Bakiyev crop.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'Augusto Pinochet - 1995.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 1,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'Stamp of Afghanistan (1979) - Saur Revolution.jpg': {'GT-Military Technology and Weaponry': 1,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 1,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 1,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Parlamentspalast_in_Bukarest.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 1,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 1,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Hussein 1978.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 0,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 1,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 1,
#   'GT-Celebration': 1,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 1,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 1,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'Mao Sihanouk.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 1,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 1,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 1,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'António de Oliveira Salazar, drawing.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 1,
#   'GT-Portrait': 1},
#  'Ldpr.png': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 0,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 1,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 0,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 1,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 0},
#  'President Nguyen Van Thieu.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'Frank Bainimarama September 2014.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 1,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'کودتاچیان.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 1,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 0,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 1,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1},
#  'Necmettin Erbakan.jpg': {'GT-Military Technology and Weaponry': 0,
#   'GT-Locations/Maps/Infographics': 0,
#   'GT-Memorials': 0,
#   'IT-Passive Image': 1,
#   'D-Adult Male': 1,
#   'GT-POWs': 0,
#   'GT-Signs/Symbols': 0,
#   'GT-Policing': 0,
#   'IT-Active Image': 0,
#   'GT-Diplomatic and Other Official Actions': 0,
#   'TOP-Police': 0,
#   'GT-Alleged Atrocities': 0,
#   'GT-Humanitarian Aid': 0,
#   'FPI-Foriegn Leaders': 0,
#   'D-Child Female': 0,
#   'VI-Non-violent Image': 0,
#   'IF-Non-human': 0,
#   'TOP-Military or Political Leaders': 1,
#   'VI-Violent Image': 0,
#   'D-Adult Female': 0,
#   'FE-Smile': 0,
#   'GT-Celebration': 0,
#   'D-Non-human': 0,
#   'GT-Suffering': 0,
#   'GT-Destruction': 0,
#   'GT-Military Actions': 0,
#   'FE-Frown': 0,
#   'TOP-Journalists': 0,
#   'IF-Individual': 1,
#   'FPI-Foriegn Symbols': 0,
#   'GT-Protest/Demonstration': 0,
#   'IF-Group': 0,
#   'GT-Buildings': 0,
#   'IF-Individual in Relation to the Group': 0,
#   'D-Child Male': 0,
#   'TOP-Military Personnel': 0,
#   'TOP-Civilians': 0,
#   'GT-Documents/Communications': 0,
#   'GT-Portrait': 1}}

# %%
[i for i in image_tags_df.index if "Pedro Carmona" in i]
# Out:
# []

# %%
bad_filename_mapping = {}
bad_filename_mapping['"De Historische Strijd" Herdenkingsmonument revolutie 25 februari 1980 - Nieuw-Amsterdam - 20418126 - RCE.jpg'] = '_De Historische Strijd_ Herdenkingsmonument....jpg'
bad_filename_mapping['1989 December 16. sugárút és a Tudor Vladimirescu út kereszteződése. Fortepan 31892.jpg'] = '1989 December 16. sugárút és a Tudor...kereszteződése. Fortepan 31892.jpg'
bad_filename_mapping['After coup nightly demonstartion of president Erdogan supporters. Istanbul, Turkey, Eastern Europe and Western Asia. 22 July,2016.jpg'] = 'After coup nightly demonstartion of presiden...Western Asia. 22 July,2016.jpg'
bad_filename_mapping['Air Commodore Kaiser Tufail receiving a memento from Commander of the Turkish Air Force General Akin Ozturk (cropped).jpg'] = 'Air Commodore Kaiser Tufail receiving a memento....jpg'
bad_filename_mapping['Air Commodore Kaiser Tufail receiving a memento from Commander of the Turkish Air Force General Akin Ozturk.jpg'] = 'Air Commodore Kaiser Tufail receiving....jpg'
bad_filename_mapping['Baath Party founder Michel Aflaq with Iraqi President Ahmad Hasan al-Bakr in Baghdad in 1968.jpg'] = 'Baath Party founder Michel Aflaq with Iraqi President....jpg'
bad_filename_mapping['Bundesarchiv B 145 Bild-F013047-0040, München, Staatsbesuch Präsident von Zypern.jpg'] = 'Bundesarchiv B 145 Bild-F013047-0040, München, ....jpg'
bad_filename_mapping['Bundesarchiv Bild 183-1989-1215-038, Berlin, Demonstration für Rumänien.jpg'] = 'Bundesarchiv Bild 183-1989-1215-038, Berlin, ....jpg'
bad_filename_mapping['Bundesarchiv Bild 183-1989-1220-032, Berlin, Demonstration für Rumänien, Mahnwache.jpg'] = 'Bundesarchiv Bild 183-1989-1220-032, Berlin, Demonstration....jpg'
bad_filename_mapping['Bundesarchiv Bild 183-1989-1221-032, Berlin, Demonstration für Rumänien.jpg'] = 'Bundesarchiv Bild 183-1989-1221-032, Berlin, Demonstration....jpg'
bad_filename_mapping['Bundesarchiv Bild 183-1989-1223-006, Berlin, Brandenburger Tor, Transparte zu Rumänien.jpg'] = 'Bundesarchiv Bild 183-1989-1223-006, Berlin, ....jpg'
bad_filename_mapping['Bundesarchiv Bild 183-1989-1120-036, Berlin, Schweigemarsch für Rumänien.jpg'] = 'Bundesarchiv Bild 183-1989-1120-036,....jpg'
bad_filename_mapping['Bundesarchiv Bild 183-55823-0005, Berlin, Karl-Marx-Allee, "Deutsche Sporthalle".jpg'] = 'Bundesarchiv Bild 183-55823-0005, Berlin, ....jpg'
bad_filename_mapping['Civilian with PM Md. 1963 during the Romanian Revolution of 1989.jpg'] = 'Civilian with PM Md. 1963 during the Romanian....jpg'
bad_filename_mapping['H.E. Mr. Mothetjoa Metsing, Deputy Prime Minister, Kingdom of Lesotho (8008839925) (cropped).jpg'] = 'H.E. Mr. Mothetjoa Metsing, Deputy Prime Minister....jpg'
bad_filename_mapping["Hashem al Atta, Khalid Hassan Abbas, 1971 Sudanese coup d'état.jpg"] = 'Hashem al Atta, Khalid Hassan Abbas, ....jpg'
bad_filename_mapping["Mayıs 1981 Kenan Evren Ankaragücü kaptanı Adil Eriç'e Türkiye Kupası'nı veriyor.jpg"] = 'Mayıs 1981 Kenan Evren Ankaragücü kaptanı....jpg'
bad_filename_mapping['Ninoy Aquino\'s "Testament from Prison Cell" signed by Cory Aquino in 1983.jpg'] = "Ninoy Aquino's _Testament from Prison Cell_ ....jpg"
bad_filename_mapping['Niwatthamrong Boonsongpaisan at Ministerial Conference 2013 crop.jpg'] = 'Niwatthamrong Boonsongpaisan at Ministerial....jpg'
bad_filename_mapping['Northrop YF-5A (SN 59-4987) with a full load of bombs 060905-F-1234S-002.jpg'] = 'Northrop YF-5A (SN 59-4987) with a full load....jpg'
bad_filename_mapping['People Power Revolution commemorative 10-peso coin obverse and reverse.png'] = 'People Power Revolution commemorative 10-peso coin....png'
bad_filename_mapping['President Barack Obama meets with members of his national security team, including Defense Secretary Chuck Hagel, to discuss the situation in Egypt, in the Situation Room of the White House, July 3, 2013.jpg'] = 'President Barack Obama meets with... July 3, 2013.jpg'
bad_filename_mapping['President Obama on the phone in the Oval Office with Secretary Kerry regarding the situation in Turkey (27716300004).jpg'] = 'President Obama on the phone in the Oval Office with... Turkey (27716300004).jpg'
bad_filename_mapping['RIAN archive 848095 Signing the Agreement to eliminate the USSR and establish the Commonwealth of Independent States.jpg'] = 'RIAN archive 848095 Signing the...Commonwealth of Independent States.jpg'
bad_filename_mapping['Secretary of Defense Chuck Hagel meets with Egyptian President Mohamed Morsy in Cairo, Egypt, April 24, 2013.jpg'] = 'Secretary of Defense Chuck Hagel meets with Egyptian....jpg'
bad_filename_mapping['Senior officials in the Baath Party in a rare un-official photograph with Salah Jadid from 1969.jpg'] = 'Senior officials in the Baath Party in a rare un-official....jpg'
bad_filename_mapping['Serie Portugal, verkiezingsstrijd in Lissabon (begin 1975); straatbeelden met verkiezingsaffiches.jpg'] = 'Serie Portugal, verkiezingsstrijd in Lissabon (begin 1975); ....jpg'
bad_filename_mapping['Thailand Ministry of Information and Communication Technology 2014 Censorship Image.jpg'] = 'Thailand Ministry of Information and ....jpg'
bad_filename_mapping['US Marine charges through Japanese machine gun fire on Okinawa.jpg'] = 'US Marine charges through Japanese machine....jpg'

# %%
topic_lang_image_tags_d = {}

bad_filenames = []

for topic, topic_d in all_coups_image_usage.items():
    for lang, lang_d in topic_d.items():
        _d = {}
        for image in lang_d.keys():
            filename = image.split(':')[-1]
            try:
                _d[filename] = image_tags_df.loc[filename]
            except KeyError:
                try:
                    revised_filename = bad_filename_mapping[filename]
                    _d[filename] = image_tags_df.loc[revised_filename]
                except:
                    bad_filenames.append(filename)
                pass
        topic_lang_image_tags_d[(topic,lang)] = pd.DataFrame(_d).sum(1)

set(bad_filenames)
# Out:
# {'BP200906-2.jpg',
#  'Bakr.jpg',
#  'Defence.jpg',
#  'Genesis FUBELT.jpg',
#  'Hameed.png',
#  'July1.jpg',
#  'Last day qasim.jpg',
#  'Mhdawi.jpg',
#  'Operacio marverde.jpg',
#  'Pedro Carmona 2002 darbesinden sonra yemin töreninde.jpg',
#  'Plevne Marşı pul.jpg',
#  'Qasim arif.jpg',
#  'Qasim2.jpg',
#  'Rafiq1.jpg',
#  'RafiqArif.jpg',
#  'Revolutie-strada-multime.jpg',
#  'Sallama.png',
#  'Taher yahya.jpg',
#  'The nation 200506.jpg',
#  'Trial iraq.jpg',
#  'Watanyin.jpg',
#  'Казнь Касема.jpg'}

# %%
topic_lang_image_tags_df = pd.DataFrame(topic_lang_image_tags_d).T.fillna(0).reset_index()
topic_lang_image_tags_df.rename(columns={'level_0':'topic','level_1':'lang'},inplace=True)

#topic_lang_image_tags_df = pd.merge(image_usage_df,topic_lang_image_tags_df,
#                                    left_on=['topic','lang'],right_on=['topic','lang'],how='outer')

#nonzero_topic_lang_image_tags_df = topic_lang_image_tags_df[topic_lang_image_tags_df['images'] > 0]

#topic_lang_image_tags_df.to_csv('topic_lang_image_tags.csv',index=False,encoding='utf8')
#nonzero_topic_lang_image_tags_df.to_csv('topic_lang_image_tags_nonzero.csv',index=False,encoding='utf8')

# %%
topic_lang_image_tags_df.columns[2:]
# Out:
# Index(['Active', 'Adult Male', 'Adult female', 'Alleged atrocities',
#        'Buildings', 'Celebrations', 'Child female', 'Child male', 'Civilians',
#        'Demographics - Cannot discern*', 'Demographics - Non-human ',
#        'Demonstrations', 'Deplomacy', 'Destruction', 'Documents',
#        'Facial Expression - N/A', 'Facial expression - Unclear*',
#        'Foreign Influence - N/A', 'Foreign flag', 'Foreign leaders', 'Frown',
#        'GT - Other*', 'Group ', 'Humanitarian aid', 'Image focus - Non-human',
#        'Image focus - Unclear* ', 'Individual', 'Individual in group',
#        'Infographics/maps', 'Journalists', 'Memorials', 'Military Actions',
#        'Military personnel', 'Military technology',
#        'Military/political leaders', 'Non-violent', 'Passive', 'Police',
#        'Portraits', 'Prisoners/arrest', 'Signs/symbols', 'Smile', 'Suffering',
#        'Type of people - Unclear*', 'Types of people - N/A', 'Violent'],
#       dtype='object')

# %%
sum_lang_image_tags_df = topic_lang_image_tags_df.groupby('lang').agg({c:np.sum for c in topic_lang_image_tags_df.columns[2:]})
sum_lang_image_tags_df = sum_lang_image_tags_df[sum_lang_image_tags_df.sum(1) > 1]
#sum_lang_image_tags_df = sum_lang_image_tags_df.apply(np.log1p)
#sum_lang_image_tags_df = sum_lang_image_tags_df.gt(0)

# %%
# Step 1: Choose your model class(es)
#from sklearn.manifold import TSNE

# Step 2: Instantiate your model class(es)
lang_tsne = TSNE(n_components = 2, method='exact', init='pca')#, perplexity=10)

# Step 3: Arrange data into features matrices
# Done!

# Step 4: Fit the data and transform
X_lang_tsne = lang_tsne.fit_transform(sum_lang_image_tags_df)

# %%
sil_score = {}

for n in range(2,21):
    _model = KMeans(n_clusters=n)
    y_lang = _model.fit_predict(X_lang_tsne)
    sil_score[n] = silhouette_score(X_lang_tsne,y_lang)
    
ax = pd.Series(sil_score).plot()
ax.set_xticks(range(2,21));
ax.set_ylim((.3,1))
# Out:
# (0.3, 1)

# %%
# Compute clusters
lang_kmeans_clusters = KMeans(n_clusters=9)
lang_kmeans_clusters.fit(X_lang_tsne)
y_lang_kmeans_clusters = lang_kmeans_clusters.predict(X_lang_tsne)
#image_tags_df['cluster'] = y_lang_kmeans_clusters

repeated_sum_lang_image_tags_df = sum_lang_image_tags_df
repeated_sum_lang_image_tags_df['cluster'] = y_lang_kmeans_clusters
repeated_sum_lang_image_tags_df['tsne_0'] = X_lang_tsne[:,0]
repeated_sum_lang_image_tags_df['tsne_1'] = X_lang_tsne[:,1]

# Visualize
f,ax = plt.subplots(1,1,figsize=(9,6))
ax.scatter(X_lang_tsne[:, 0], X_lang_tsne[:, 1], c=y_lang_kmeans_clusters, cmap='nipy_spectral',alpha=1,s=100)
ax.grid(None)

for cluster in range(lang_kmeans_clusters.n_clusters):
    plt.annotate(str(cluster), 
                 (lang_kmeans_clusters.cluster_centers_[cluster, 0], lang_kmeans_clusters.cluster_centers_[cluster, 1]),
                 size=50
                );
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
#ax.set_ylim((-50,60))
f.tight_layout()
f.savefig('tsne_lang.pdf')

# %%
list(enumerate(repeated_sum_lang_image_tags_df.reset_index().groupby('cluster').agg({'lang':lambda x:list(x)})['lang'].values))
# Out:
# [(0, ['be-x-old', 'hr', 'lb', 'lv', 'nn', 'oc', 'simple', 'ta', 'tet']),
#  (1, ['ar', 'de', 'en', 'es', 'fr', 'ja', 'pl', 'pt', 'ru']),
#  (2, ['fa', 'ka', 'nl', 'no', 'ro']),
#  (3, ['br', 'fi', 'id', 'sv']),
#  (4,
#   ['af',
#    'azb',
#    'cy',
#    'et',
#    'is',
#    'lt',
#    'ms',
#    'sco',
#    'si',
#    'sk',
#    'sl',
#    'zh-yue']),
#  (5, ['ca', 'gl', 'he', 'it', 'ko', 'th', 'tr', 'uk', 'vi', 'zh']),
#  (6, ['bg', 'bn', 'da', 'hu', 'sr']),
#  (7, ['az', 'cs', 'el', 'eo', 'eu', 'sh', 'tl']),
#  (8, ['ckb', 'mk', 'tg'])]

# %% [markdown]
# ### 1991 Soviet case study

# %%
soviet_lang_image_tags_df = topic_lang_image_tags_df.set_index(['topic','lang']).loc["1991 Soviet coup d'état attempt"]

X_soviet_tsne = lang_tsne.fit_transform(soviet_lang_image_tags_df)

# %%
# Compute clusters
soviet_kmeans_clusters = KMeans(n_clusters=4)
soviet_kmeans_clusters.fit(X_soviet_tsne)
y_soviet_kmeans_clusters = soviet_kmeans_clusters.predict(X_soviet_tsne)

# Put clusters and embedding coordinates into a DF
repeated_soviet_lang_image_tags_df = soviet_lang_image_tags_df
repeated_soviet_lang_image_tags_df['cluster'] = y_soviet_kmeans_clusters
repeated_soviet_lang_image_tags_df['tsne_0'] = X_soviet_tsne[:,0]
repeated_soviet_lang_image_tags_df['tsne_1'] = X_soviet_tsne[:,1]

# Visualize
f,ax = plt.subplots(1,1,figsize=(9,6))
ax.scatter(X_soviet_tsne[:, 0], X_soviet_tsne[:, 1], c=y_soviet_kmeans_clusters, cmap='nipy_spectral',alpha=1,s=200)
ax.grid(None)

for cluster in range(soviet_kmeans_clusters.n_clusters):
    plt.annotate(str(cluster), 
                 (soviet_kmeans_clusters.cluster_centers_[cluster, 0], soviet_kmeans_clusters.cluster_centers_[cluster, 1]),
                 size=50
                );
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
#ax.set_ylim((-50,60))
f.tight_layout()
f.savefig('tsne_soviet.pdf')

# %%
len(['de', 'lmo', 'sr', 'mk', 'ro', 'pl', 'cv', 'lv', 'da', 'hr', 'it', 'ky', 'et', 'mn', 'ko', 'he', 'bg', 'eo', 'tt', 'fa', 'ar', 'ca', 'kk', 'th', 'en', 'zh', 'sv', 'id', 'eu', 'be', 'uk', 'cs', 'nl', 'zh-yue', 'be-x-old'])
# Out:
# 35

# %%
repeated_soviet_lang_image_tags_df.reset_index().groupby('cluster').agg({'lang':lambda x:list(x)})['lang'].values
# Out:
# array([list(['de', 'lmo', 'sr', 'mk', 'ro', 'pl', 'cv', 'lv', 'da', 'hr', 'it', 'ky', 'et', 'mn', 'ko', 'he', 'bg', 'eo', 'tt', 'fa', 'ar', 'ca', 'kk', 'th', 'en', 'zh', 'sv', 'id', 'eu', 'be', 'uk', 'cs', 'nl', 'zh-yue', 'be-x-old']),
#        list(['ru']), list(['ja', 'es']),
#        list(['tr', 'no', 'vi', 'fr', 'fi', 'pt'])], dtype=object)

# %% [markdown]
# ### 2013 Egyptian case study

# %%
egypt_lang_image_tags_df = topic_lang_image_tags_df.set_index(['topic','lang']).loc["2013 Egyptian coup d'état"]

X_egypt_tsne = lang_tsne.fit_transform(egypt_lang_image_tags_df)

# Compute clusters
egypt_kmeans_clusters = KMeans(n_clusters=6)
egypt_kmeans_clusters.fit(X_egypt_tsne)
y_egypt_kmeans_clusters = egypt_kmeans_clusters.predict(X_egypt_tsne)

# %%
# Put clusters and embedding coordinates into a DF
repeated_egypt_lang_image_tags_df = egypt_lang_image_tags_df
repeated_egypt_lang_image_tags_df['cluster'] = y_egypt_kmeans_clusters
repeated_egypt_lang_image_tags_df['tsne_0'] = X_egypt_tsne[:,0]
repeated_egypt_lang_image_tags_df['tsne_1'] = X_egypt_tsne[:,1]

# Visualize
f,ax = plt.subplots(1,1,figsize=(9,6))
ax.scatter(X_egypt_tsne[:, 0], X_egypt_tsne[:, 1], c=y_egypt_kmeans_clusters, cmap='nipy_spectral',alpha=1,s=200)
ax.grid(None)

for cluster in range(egypt_kmeans_clusters.n_clusters):
    plt.annotate(str(cluster), 
                 (egypt_kmeans_clusters.cluster_centers_[cluster, 0], egypt_kmeans_clusters.cluster_centers_[cluster, 1]),
                 size=50
                );
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
#ax.set_ylim((-50,60))
f.tight_layout()
f.savefig('tsne_egypt.pdf')

# %%
len(['tr', 'bg', 'de', 'el', 'nl', 'sr', 'ro', 'pl', 'az', 'ru', 'ca', 'vi', 'ckb', 'zh', 'it', 'id', 'es', 'uk', 'arz', 'af', 'pt', 'fi', 'ur', 'hi']),len(repeated_egypt_lang_image_tags_df)
# Out:
# (24, 32)

# %%
repeated_egypt_lang_image_tags_df.reset_index().groupby('cluster').agg({'lang':lambda x:list(x)})['lang'].values
# Out:
# array([list(['tr', 'bg', 'de', 'el', 'nl', 'sr', 'ro', 'pl', 'az', 'ru', 'ca', 'vi', 'ckb', 'zh', 'it', 'id', 'es', 'uk', 'arz', 'af', 'pt', 'fi', 'ur', 'hi']),
#        list(['fa', 'ar']), list(['he', 'ja', 'fr']), list(['en']),
#        list(['tg']), list(['ko'])], dtype=object)

# %% [markdown]
# ## Image tag similarity

# %%
good_tags = [i for i in image_tags_df.columns if i != 'cluster']

# %%
cosine_similiarty_d = dict()

for image1 in image_tags_df.index:
    cosine_similiarty_d[image1] = {}
    for image2 in image_tags_df.index:
        cosine_similiarty_d[image1][image2] = cosine(image_tags_df.loc[image1,good_tags],
                                                     image_tags_df.loc[image2,good_tags])

with open('image_tag_cosine_similarity.json','w') as f:
    json.dump(cosine_similiarty_d,f)

# %%
cosine_similiarty_df = pd.DataFrame(cosine_similiarty_d).stack().reset_index()
cosine_similiarty_df.groupby(['level_0','level_1']).head(5)
# Out:
#                                                   level_0  \
# 0       "De Historische Strijd" Herdenkingsmonument re...
# 1       "De Historische Strijd" Herdenkingsmonument re...
# 2       "De Historische Strijd" Herdenkingsmonument re...
# 3       "De Historische Strijd" Herdenkingsmonument re...
# 4       "De Historische Strijd" Herdenkingsmonument re...
# 5       "De Historische Strijd" Herdenkingsmonument re...
# 6       "De Historische Strijd" Herdenkingsmonument re...
# 7       "De Historische Strijd" Herdenkingsmonument re...
# 8       "De Historische Strijd" Herdenkingsmonument re...
# 9       "De Historische Strijd" Herdenkingsmonument re...
# 10      "De Historische Strijd" Herdenkingsmonument re...
# 11      "De Historische Strijd" Herdenkingsmonument re...
# 12      "De Historische Strijd" Herdenkingsmonument re...
# 13      "De Historische Strijd" Herdenkingsmonument re...
# 14      "De Historische Strijd" Herdenkingsmonument re...
# 15      "De Historische Strijd" Herdenkingsmonument re...
# 16      "De Historische Strijd" Herdenkingsmonument re...
# 17      "De Historische Strijd" Herdenkingsmonument re...
# 18      "De Historische Strijd" Herdenkingsmonument re...
# 19      "De Historische Strijd" Herdenkingsmonument re...
# 20      "De Historische Strijd" Herdenkingsmonument re...
# 21      "De Historische Strijd" Herdenkingsmonument re...
# 22      "De Historische Strijd" Herdenkingsmonument re...
# 23      "De Historische Strijd" Herdenkingsmonument re...
# 24      "De Historische Strijd" Herdenkingsmonument re...
# 25      "De Historische Strijd" Herdenkingsmonument re...
# 26      "De Historische Strijd" Herdenkingsmonument re...
# 27      "De Historische Strijd" Herdenkingsmonument re...
# 28      "De Historische Strijd" Herdenkingsmonument re...
# 29      "De Historische Strijd" Herdenkingsmonument re...
# ...                                                   ...
# 599046  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599047  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599048  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599049  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599050  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599051  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599052  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599053  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599054  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599055  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599056  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599057  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599058  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599059  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599060  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599061  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599062  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599063  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599064  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599065  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599066  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599067  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599068  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599069  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599070  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599071  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599072  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599073  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599074  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
# 599075  臺灣綠島人權紀念碑Monument for Human Rights on Lyudao (...
#
#                                                   level_1         0
# 0                                         Salah Bitar.jpg  0.634852
# 1                                       Desi Bouterse.jpg  0.661938
# 2       National Revolutionary Command Council (Sudan)...  0.661938
# 3                    2009 Honduras political crisis 9.jpg  0.850929
# 4                                              By-map.png  0.329180
# 5                                      Iskander Mirza.jpg  0.634852
# 6                                EDSA_Revolution_pic1.jpg  0.800000
# 7                                              Iraq14.jpg  0.200000
# 8                    Assemblee Nationale Burkina Faso.jpg  0.329180
# 9                                Nguyễn Khánh 1964.jpg  0.634852
# 10                                        BKK24090602.jpg  0.483602
# 11      Bundesarchiv_Bild_183-55823-0005,_Berlin,_Karl...  0.830969
# 12                                            Thaksin.jpg  0.661938
# 13                     TBMM coup attempt 15 June 2016.png  0.800000
# 14                             Major-general-lansdale.jpg  0.634852
# 15                     Turkish protesters in Istanbul.jpg  1.000000
# 16                   Central african republic sm04ESP.jpg  0.200000
# 17                   Расстрел_белого_дома_в_1993_году.jpg  0.525658
# 18                                        Un-pakistan.png  0.200000
# 19                                      Ponte25Abril1.jpg  0.200000
# 20                                Mercator Africa 037.jpg  0.200000
# 21                              Hulusi Akar (cropped).jpg  0.634852
# 22                   Stamp Fiji 1959 2 6 Nadi Airport.jpg  0.600000
# 23                             Estadio nacional-Chile.jpg  0.200000
# 24                       Chamlong Srimuang 2008-12-27.jpg  0.634852
# 25                            Coup-d'etat-14-web-cnni.jpg  0.701858
# 26      President Eisenhower and John Foster Dulles in...  0.661938
# 27      Onganía-Levingston-Lanusse (Revolución Argen...  0.634852
# 28                                    Dvorec 27 12 79.jpg  0.200000
# 29              Ahmed el-Tayeb May 2015 (17963337671).jpg  0.634852
# ...                                                   ...       ...
# 599046                     Sekou Toure usgov-83-08641.jpg  0.691393
# 599047                Rumo a liberdade Henrique Matos.jpg  0.183503
# 599048           Russian Congressional Fractions 1992.png  0.269703
# 599049                                   Arturo Illia.jpg  0.833333
# 599050                                     Marche sel.jpg  0.845697
# 599051  2014 0526 Thailand coup Chang Phueak Gate Chia...  0.845697
# 599052                  Русское Национальное Единство.jpg  0.087129
# 599053                                Hafizullah Amin.jpg  0.666667
# 599054                                   Hun Sen crop.jpg  0.691393
# 599055                    Mauritanie-Coup d'Etat 2008.jpg  0.691393
# 599056                                   Zahedifirman.jpg  0.166667
# 599057  11 septiembre 1976- manifestacion pro Pinochet...  0.855662
# 599058          Chest badge Guards Russian Federation.png  0.166667
# 599059                        AssaltonaMatadaSanga....jpg  1.000000
# 599060                              Alte. Pedro Gnavi.jpg  0.666667
# 599061             Satellite image of Cyprus, cropped.jpg  0.269703
# 599062                              Dead No Coup 2016.jpg  0.666667
# 599063  "De Historische Strijd" Herdenkingsmonument re...  0.087129
# 599064  President of Kyrgyzstan, Kurmanbek Bakiyev cro...  0.666667
# 599065                        Augusto Pinochet - 1995.jpg  0.691393
# 599066  Stamp of Afghanistan (1979) - Saur Revolution.jpg  0.228483
# 599067                   Parlamentspalast_in_Bukarest.jpg  0.269703
# 599068                                   Hussein 1978.jpg  0.855662
# 599069                                   Mao Sihanouk.jpg  0.691393
# 599070          António de Oliveira Salazar, drawing.jpg  0.691393
# 599071                                           Ldpr.png  0.183503
# 599072                     President Nguyen Van Thieu.jpg  0.666667
# 599073               Frank Bainimarama September 2014.jpg  0.691393
# 599074                                      کودتاچیان.jpg  0.666667
# 599075                              Necmettin Erbakan.jpg  0.817426
#
# [599076 rows x 3 columns]

# %% [markdown]
# ## Appendix

# %% [markdown]
# ### Trying to fix broken tags

# %%
lang_image_tags = {}
bad_files = list()

for lang, filelist in lang_images.items():
    lang_image_tags[lang] = []
    for file in filelist:
        try:
            tags = image_tags_dict[file]
        except KeyError:
            try:
                tags = image_tags_dict[file.replace(' ','_')]
            except KeyError:
                bad_files.append(file)
            
len(bad_files)
# Out:
# 239

# %%
def levenshtein(s1, s2):
    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1 # j+1 instead of j since previous_row and current_row are one character longer
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    
    return previous_row[-1]

# %%
edit_distance = {}
for f1 in list(set([f for lang,files in lang_images.items() for f in files])):
    edit_distance[f1] = {}
    for f2 in list(set(image_tags_dict.keys())):
        if abs(len(f1) - len(f2)) < 5 and f1 != f2:
            dist =  levenshtein(f1,f2)
            if dist < 5:
                edit_distance[f1][f2] = dist

# %%
with open('scraped_image_filenames.json','w') as f:
    json.dump(sorted(list(set([f for lang,files in lang_images.items() for f in files]))),f)
    
with open('tagged_image_filenames.json','w') as f:
    json.dump(sorted(list(set(image_tags_dict.keys()))),f)

# %%
len(list(set(image_tags_dict.keys()))), len(list(set([f for lang,files in lang_images.items() for f in files])))
# Out:
# (774, 747)

# %%
with open('tagged_scraped_disjoint_filenames.json','w') as f:
    json.dump(sorted(list(set([f for lang,files in lang_images.items() for f in files]) ^ set(image_tags_dict.keys()))),f)

# %%
set(image_tags_dict.keys()) - set([f for lang,files in lang_images.items() for f in files])
# Out:
# {'-De_Historische_Strijd-_Herdenkingsmonument_revolutie_25_februari_1980_-_Nieuw-Amsterdam_-_20418127_-_RCE.jpg',
#  '15 July-Erdoğan SMS.jpg',
#  '15 Temmuz Şehitler Parkı tabelası.jpg',
#  "1962 Burmese coup d'état.jpg",
#  "1962 Burmese coup d'état2.jpg",
#  '1989 December 16. sugárút és a Tudor Vladimirescu út kereszteződése. Fortepan 31892.jpg',
#  '1991_coup_yeltsin.jpg',
#  "1992 Venezuelan coup d'état attempts Hugo Chávez speech.jpg",
#  "1992 Venezuelan coup d'état attempts Miraflores.jpg",
#  "1992 Venezuelan coup d'état attempts collage.png",
#  '1993_Rusya_anayasa_krizi_sırasında_Parlamento_yanlısı_göstericiler.jpg',
#  '1993_Tanks_before_Russian_White_house.jpg',
#  '1_Mart_1997_-_Cumhuriyet.jpg',
#  "2002 Venezuelan coup d'état attempt collage.jpg",
#  "2002 Venezuelan coup d'état attempt uprising.jpg",
#  '200535.jpg',
#  '2007ManilaPenSiegeMap.jpg',
#  '2014 Suchum, Siedziba rządu i prezydenta Republiki Abchazji (04).jpg',
#  '2016 Türkiye Darbe Girişimi - Ankara.jpg',
#  "20th anniversary of 1953 Iranian coup d'état.jpg",
#  '21438_010.jpg',
#  '24_жніўня_1991.jpg',
#  '27_Mayıs_Darbesi_sembolü.png',
#  '34-o Aniversário Revolução dos Cravos, Lisboa.jpg',
#  '4.19 혁명.jpg',
#  '4_Ekim_1993_Rusya_Parlamento_binası_alevler_içinde.jpg',
#  '59mossadeghprime_minister1951.jpg',
#  'Abd Rabbuh Mansur Hadi 2013.jpg',
#  'Adnan Menderes VI. Yasama Dönemi.jpg',
#  'Alejandro Agustín Lanusse.jpg',
#  'Algiers_putsch_1961.jpg',
#  'Allende_son.jpg',
#  'Amadou Toumani Touré 30 November 2011.jpg',
#  'Anti-Coup Demokrasi Nöbeti Kızılay Square.jpg',
#  'António de Oliveira Salazar, drawing.jpg',
#  'Arafat Darwish Habash.jpg',
#  'Arafat in Jordan.jpg',
#  'Álvaro Cunhal Henrique Matos 02.jpg',
#  'BTR-60PB DA-ST-89-06597.jpg',
#  'BTR_25_april.jpg',
#  'Black May 1992.jpg',
#  'Black_May_Thailand.jpg',
#  'Blaise Compaoré 2014 White House.png',
#  'Boğazın tek yönlü kapatılması.png',
#  'Bophuthatswana_coup_Execution.jpg',
#  'Bundesarchiv B 145 Bild-F013047-0040, München, Staatsbesuch Präsident von Zypern.jpg',
#  'Bundesarchiv Bild 183-1989-1120-036, Berlin, Schweigemarsch für Rumänien.jpg',
#  'Bundesarchiv Bild 183-1989-1215-038, Berlin, Demonstration für Rumänien.jpg',
#  'Bundesarchiv Bild 183-1989-1220-032, Berlin, Demonstration für Rumänien, Mahnwache.jpg',
#  'Bundesarchiv Bild 183-1989-1221-032, Berlin, Demonstration für Rumänien.jpg',
#  'Bundesarchiv Bild 183-1989-1223-006, Berlin, Brandenburger Tor, Transparte zu Rumänien.jpg',
#  'Bundesarchiv_Bild_183-55823-0005,_Berlin,_Karl-Marx-Allee,_-Deutsche_Sporthalle-.jpg',
#  'Burkinabe Col. Gilbert Diendéré, 2010.jpg',
#  'Burkinabé_uprising_at_Place_de_la_Nation.jpg',
#  'Bülent Ecevit Cropped.jpg',
#  'Castelo de Guimarães (Portugal).jpg',
#  'Chamlong Srimuang 2008-12-27.jpg',
#  'Chan_o_cha_Portrait.jpg',
#  'Chavez_başarısız_darbeden_sonra_göreve_dönerken_13_Nisan_2002.jpg',
#  'Chile - Palácio de La Moneda - by Sérgio Schmiegelow.jpg',
#  'Chile_Junta001.jpg',
#  'Conmemoración 40 años Museo de la Memoria 2.jpg',
#  'Conmemoración de 40 años del Golpe Militar 1.jpg',
#  'CoupDarbe.jpg',
#  'Çevik Bir DD-SD-00-01007.jpg',
#  'Darbe karşıtı protesto Tokat.jpg',
#  'Dawsonfieldcamels.jpg',
#  'Demirel.jpg',
#  'Diego Rivera 1932 b.jpg',
#  'Dvorec 27 12 79.jpg',
#  'EDSA_Revolution_pic1.jpg',
#  'Erdoğan, 2012 (cropped).jpg',
#  'Eugène Delacroix - La liberté guidant le peuple.jpg',
#  'Evstafiev-40th army HQ-Amin-palace-Kabul.jpg',
#  'Evstafiev-spetsnaz-prepare-for-mission.jpg',
#  'FUA manifestación 70s-2.jpg',
#  'FUNCINPEC logo 2006-2015.jpg',
#  'Fatin Rüştü Zorlu.jpg',
#  'Fethullah Gülen 2016.jpg',
#  'Fethullah Gülen cropped (cropped) (cropped).jpg',
#  'Fethullah Gülen cropped (cropped).jpg',
#  'Fethullah Gülen cropped.jpg',
#  'Fifties jukebox.png',
#  'Francois_Duvalier_during_1958_coup_attempt.jpg',
#  'Freedom_and_Justice_Party_(Egypt).jpg',
#  'Gaziosmanpaşa meydanı protesto.jpg',
#  'General_Al-Sisi,_announcing_the_removal_of_President_Morsi.png',
#  'General_el_Sisi_Mursiyi_görevden_alındığını_açıklarken.png',
#  'Genesis_FUBELT.jpg',
#  "Général de corps d'armée Salou Djibo.jpg",
#  'Golpe_de_1964.jpg',
#  'Guarbadge.png',
#  'Hafizullah Amin.jpg',
#  "Hashem al Atta, 1971 Sudanese coup d'état.jpg",
#  "Hashem al Atta, Khalid Hassan Abbas, 1971 Sudanese coup d'état.jpg",
#  'Hastear da bandeira da Guiné Bissau após o arrear da de Portugal.jpg',
#  'Hémicycle 2 Palais Bourbon scropped and smaller.jpg',
#  'Houthi_Declaration_6-2-2015.png',
#  'Hugo Chávez (02-04-2010).jpg',
#  'Hun Sen crop.jpg',
#  'Hussein 1978.jpg',
#  "In_People's_Name.jpg",
#  'Iran_NF.jpg',
#  'Istanbul -Hürriyet- 2000 by RaBoe 02.jpg',
#  'Jo-map (German).png',
#  'João Goulart NYWTS.jpg',
#  'João Goulart nos Estados Unidos em 1962.jpg',
#  'José Afonso by Henrique Matos 001.jpg',
#  'José Toribio Merino Castro cropped.jpg',
#  'Juvénal Habyarimana (1980).jpg',
#  'Juvénal Habyarimana (Andrews Air Force Base, Maryland, USA - 1980).jpg',
#  'King_CDRM_L.jpg',
#  'Konstitucionālais_likums_Par_Latvijas_Republikas_valstisko_statusu.jpg',
#  'Kırklareli TSK crop.jpg',
#  'LRAP_un_MP_1991._gada_19._augusta_paziņojums.jpg',
#  'Ladgham_arafat.jpg',
#  'Last_day_qasim.jpg',
#  'Les alliés dal-Qaida détruisent un tombeau sacré à Tombouctou (8142142738).jpg',
#  "Léon M'ba 1964.jpg",
#  'Lissabon_25_april.jpg',
#  'Logo_for_Liberal_Democratic_Party_of_Russia.png',
#  'Lon_Nol,_Sisowath_Sirik_Matak,_In_Tam.jpg',
#  'Lucio Gutiérrez.jpg',
#  'MBKTürkeş.jpg',
#  'Madame Ngô Đình Nhu and Lyndon Baines Johnson.jpg',
#  'Makatisiege_ajescreenshot.jpg',
#  'Manifest_revolutie_1989.jpg',
#  'Manifestation à Nouadhibou-2008.jpg',
#  'ManilaPenn.jpg',
#  'May 16th Coup dEtat (1961) 5.16 군사혁명 (5591601384).jpg',
#  "Mayıs_1981_Kenan_Evren_Ankaragücü_kaptanı_Adil_Eriç'e_Türkiye_Kupası'nı_veriyor.jpg",
#  'Memorial to Jordanian soldiers (Karameh, Jordan).jpg',
#  'Mengistu_&_Merid.jpg',
#  'Mengistu_and_germame_Neway.jpg',
#  'Museo Aeronáutico 2.jpg',
#  'Mustafa Kemal Atatürk.jpg',
#  'NF 1978 - 1980.jpg',
#  'Nasser brokering ceasefire with Chairman Arafat and King Hussein.jpg',
#  'Nasser, Hussein and Amer before signing Egyptian-Jordanian defense pact.jpg',
#  'Nasser-Faisal-Arafat-1970.jpg',
#  'Necmettin Erbakan.jpg',
#  'Newsweek_22_Eylül_1980_kapak.jpg',
#  'Nguyễn Khánh 1964.jpg',
#  'Nhà thờ Cha Tam.jpg',
#  'Nick_Faeldon_2007.jpg',
#  'Nicolae Ceaușescu Mormant.jpg',
#  "Ninoy_Aquino's_-Testament_from_Prison_Cell-_signed_by_Cory_Aquino_in_1983.jpg",
#  'Oakwood, Makati, Glorietta - panoramio.jpg',
#  'Onganía-Levingston-Lanusse (Revolución Argentina).jpg',
#  'Operacio_marverde.jpg',
#  'Operação Vagô - memorial no Cemitério dos Prazeres.jpg',
#  'Order of the Red Banner.jpg',
#  'Óscar Arias (2009).jpg',
#  'PFLP-group-1969.jpg',
#  'PSRS_Valsts_padomes_lēmums_par_Latvijas_Republikas_neatkarības_atzīšanu.jpg',
#  'Parlamentspalast_in_Bukarest.jpg',
#  'Pedro_Carmona_2002_darbesinden_sonra_yemin_töreninde.jpg',
#  'People_Power_Revolution_commemorative_10-peso_coin_obverse_and_reverse.png',
#  'Plevne_Marşı_pul.jpg',
#  'Popular-Front-for-the-Liberation-of-Palestine-general-command.png',
#  'Portail Armée française.png',
#  'Povo_mfa.jpg',
#  'Praça 25 de Abril.jpg',
#  'President Ali Abdullah Saleh.jpg',
#  'Propaganda del govierno en años posteriores.jpg',
#  'Qasim_arif.jpg',
#  'Queens Palace (5300182685).jpg',
#  'Recep Tayyip Erdoğan.jpg',
#  'RecepTayyipErdoğan (cropped).jpg',
#  'Reform_the_Armed_Forces_Movement_logo_circa_1990s.png',
#  'Román Nemzeti Színház és Operaház, T-55 harckocsi. Romániai forradalom. Fortepan 31905.jpg',
#  'Salvador_Alyendenin_son_foto_şəkili.jpg',
#  'Samuel_K._Doe_During_the_1980_Coup.png',
#  'Sana.jpg',
#  'Sheikh mujibur rahman1950 140x190.jpg',
#  "Sincan'dan_geçen_tanklar.jpg",
#  'Sincan_tanks.jpg',
#  'SovietInvasionAfghanistanMap.png',
#  'Supreme_Soviet_of_Russia_meeting_(1993).png',
#  'Şanlıurfa 2016.jpg',
#  'Taher_yahya.jpg',
#  'Tanks_approach_the_Ataturk_airport.jpg',
#  'Tanks_before_Russian_White_house.jpg',
#  'Tanques_Venezuela_1958.jpg',
#  'Tentativa_de_golpe_de_Estado_na_Turquia.jpg',
#  'The_Bangkok_Post,_September_20,_2006.jpg',
#  'The_nation_200506.jpg',
#  'Tokat darbe karşıtları.png',
#  'TőkésL.jpg',
#  'Trial_iraq.jpg',
#  'Turcja, 15-16.07.2016r. Próba zamachu.png',
#  'Turgut Özal cropped.jpg',
#  'Ülkü Ocakları Eğitim ve Kültür Vakfı Logosu.png',
#  'V._Landsbergis._Viešoji_informacija.jpg',
#  'Vladimir Putin and Recep Tayyip Erdoğan (2015-06-13) 3.jpg',
#  'Yemen war detailed map.png',
#  'ZSU-23-4-Camp-Pendleton.jpg',
#  'Νικος Σαμψών.jpg',
#  'Дворец со стороны правого крыла 27 12 79.jpg',
#  'Казнь_Касема.jpg',
#  'Кокарда рядового и сержантского состава Советской Армии.jpg',
#  'Расстрел_белого_дома_в_1993_году.jpg',
#  'Шеврон 4-й гвардейской танковой дивизии.jpg',
#  'التجمع_اليمني_للاصلاح.jpg',
#  'حزب_الحرية_والعدالة.png',
#  'صورة_دبابات_الإنقلابيين_العسكريين_التركيين.jpg',
#  'مذيعة_قناة_تي_آر_تي.jpg',
#  'พลเอกประยุทธ์ประกาศยึดอำนาจ22_พฤษภาคม_2557.png',
#  'სამხედრო_გადატრიალების_მცდელობა.png',
#  '윤치영 1961.jpg',
#  '장도영, 박정희 1961년 5.16 군사정변.jpg',
#  '장도영.jpg',
#  'ベールイドーム.jpg'}
